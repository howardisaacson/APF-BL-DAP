# %%
# get_all_NDR.ipynb -- NOW SAVES THE SPECTRUM IN SAME INCREMENTS AS WL
# Script to save normalized, deblazed spectra and registered wavelength scales for input APF spectra.
# Last modified 8/12/20 by Anna Zuckerman

# %%
import import_ipynb 
import numpy as np
import astropy.io.fits as pf
from astropy.io import fits
from bstar_deblaze import bstar_deblazed2
import sys
import os
sys.path.append('specmatch-emp')
import specmatchemp.library
import specmatchemp.plots as smplot
from specmatchemp.spectrum import Spectrum
from specmatchemp.specmatch import SpecMatch
from rescale import get_rescaled_wave_soln
from rescale import resample

# %%
path_to_dir = '/datag/blpd0/datax/apf' # Breakthrough Listen APF database
filelist = sorted(os.listdir(path_to_dir))
filelist.remove('apf_log.txt') # remove log files
filelist.remove('apf_log_current.txt')
filelist.remove('apf_log_current_new.txt')
filelist.remove('apf_log_current_25mar2019.txt')
# for running a subset of files
filelist = filelist[5869:7353]


bad_files = []
for file_name in filelist: 
    print(file_name)
    if not(file_name.startswith('ucb')):        
        try:
            # deal with directories
            if file_name.startswith('HIP') or os.path.isdir('./'+ file_name): # is a directory of spectra
                path = ('./' + file_name)
                spectra = sorted(os.listdir(path))
                data = np.zeros((79, 4608))
                for spectrum in spectra:
                    file = pf.open(path + '/' + spectrum)
                    data_part = file[0].data
                    if (str(np.shape(data_part)) != '(79, 4608)'):
                        print(str(np.shape(data_part)) + ' is an incompatible data shape.')
                        print('Cannot perform shift-and-match process.')
                        sys.exit()
                    data += data_part
            else: # just one spectrum
                file = pf.open(path_to_dir + '/' + file_name)
                old_header = file[0].header
                data = file[0].data

            orders  = np.linspace(30,51,22).astype(int)
            norm_deblazed = np.zeros([len(orders), 4600])
            for order in orders:
                data[order,:4600]  = bstar_deblazed2(data, order)
                norm_deblazed[order-30] = data[order,:4600]

            # Use Specmatch-Emp to get registered wavelength scale
            # Get a wavelength solution rescaled onto the scale of the library
            wave_soln_ref = get_rescaled_wave_soln()

            # Resample the spectrum onto the new wavelength scale
            wave_soln = (pf.open('apf_wav.fits'))[0].data
            data_new = resample(wave_soln_ref, wave_soln, data)

            # Create spectrum object
            my_spectrum = Spectrum(np.asarray(wave_soln_ref), np.asarray(data_new))

            lib = specmatchemp.library.read_hdf()

            sm = SpecMatch(my_spectrum, lib)

            # Perform shift
            sm.shift()

            # get target and wavelength
            target = sm.target.s
            target_wl = sm.target.w   

            # save to fits file
            new_header = old_header
            new_header.set('NRD', 'YES','Normalized, registered, deblazed')
            # ADZ 6/29/21 shouldn't we actually save target not norm_deblazed?
            data_hdu = fits.PrimaryHDU(target, new_header) # could save 'data' instead if also want non-deblazed orders
            wl_hdu = fits.ImageHDU(target_wl)
            hdu = fits.HDUList([data_hdu, wl_hdu])

            save_name = file_name.split('.')[0] + '.' + file_name.split('.')[1] + '.NDR.' + file_name.split('.')[2]
            hdu.writeto('APF_spectra/NDR_corrected_wl_scale/' + save_name)
            print('Done: ' + save_name)
        except:
            print('Error occured processing file: ' + file_name)
            bad_files = bad_files + [file_name]
# Out:
# ucb-amp171.fits
# ucb-amp172.fits
# ucb-amp173.fits
# ucb-amp174.fits
# ucb-amp193.fits
# ucb-amp194.fits
# ucb-amq233.fits
# ucb-amq252.fits
# ucb-amr228.fits
# ucb-amu211.fits
# ucb-amu251.fits
# ucb-amu282.fits
# ucb-amu300.fits
# ucb-amv171.fits
# ucb-amv177.fits
# ucb-amw271.fits
# ucb-amx180.fits
# ucb-amx195.fits
# ucb-amx196.fits
# ucb-amx217.fits
# ucb-amx270.fits
# ucb-amx271.fits
# ucb-amz228.fits
# ucb-amz278.fits
# ucb-ana224.fits
# ucb-ana243.fits
# ucb-ann193.fits
# ucb-anq207.fits
# ucb-anq231.fits
# ucb-anr210.fits
# ucb-anr211.fits
# ucb-anr212.fits
# ucb-anr237.fits
# ucb-anr241.fits
# ucb-anr262.fits
# ucb-anr263.fits
# ucb-anr271.fits
# ucb-anr272.fits
# ucb-anr288.fits
# ucb-anr293.fits
# ucb-anr295.fits
# ucb-anr296.fits
# ucb-anr310.fits
# ucb-anu193.fits
# ucb-anu194.fits
# ucb-anu276.fits
# ucb-anu280.fits
# ucb-anu281.fits
# ucb-anu282.fits
# ucb-anu316.fits
# ucb-anv215.fits
# ucb-anv230.fits
# ucb-anv272.fits
# ucb-anv280.fits
# ucb-anv285.fits
# ucb-anv299.fits
# ucb-anv301.fits
# ucb-anv303.fits
# ucb-anv307.fits
# ucb-anv308.fits
# ucb-anv312.fits
# ucb-anv316.fits
# ucb-anv317.fits
# ucb-anv323.fits
# ucb-anv345.fits
# ucb-anw195.fits
# ucb-anw196.fits
# ucb-anw197.fits
# ucb-anw215.fits
# ucb-anw216.fits
# ucb-anw242.fits
# ucb-anw262.fits
# ucb-anw272.fits
# ucb-anw274.fits
# ucb-anw304.fits
# ucb-anw305.fits
# ucb-anw313.fits
# ucb-anw314.fits
# ucb-anw315.fits
# ucb-anw329.fits
# ucb-anw331.fits
# ucb-anw332.fits
# ucb-anw336.fits
# ucb-anw337.fits
# ucb-anx186.fits
# ucb-anx187.fits
# ucb-anx188.fits
# ucb-anx216.fits
# ucb-anx217.fits
# ucb-anx227.fits
# ucb-anx231.fits
# ucb-anx239.fits
# ucb-anx259.fits
# ucb-anx260.fits
# ucb-anx273.fits
# ucb-anx277.fits
# ucb-any189.fits
# ucb-any190.fits
# ucb-any191.fits
# ucb-any192.fits
# ucb-any193.fits
# ucb-any200.fits
# ucb-any213.fits
# ucb-any220.fits
# ucb-any228.fits
# ucb-any249.fits
# ucb-any271.fits
# ucb-any279.fits
# ucb-any280.fits
# ucb-any282.fits
# ucb-any285.fits
# ucb-any300.fits
# ucb-any301.fits
# ucb-anz162.fits
# ucb-anz163.fits
# ucb-anz164.fits
# ucb-anz165.fits
# ucb-anz166.fits
# ucb-anz167.fits
# ucb-anz168.fits
# ucb-aob211.fits
# ucb-aob231.fits
# ucb-aob235.fits
# ucb-aob239.fits
# ucb-aob240.fits
# ucb-aob246.fits
# ucb-aob250.fits
# ucb-aob251.fits
# ucb-aob252.fits
# ucb-aob253.fits
# ucb-apa237.fits
# ucb-apa249.fits
# ucb-apa252.fits
# ucb-apa263.fits
# ucb-apa264.fits
# ucb-apg203.fits
# ucb-apg209.fits
# ucb-apg212.fits
# ucb-apg214.fits
# ucb-apg227.fits
# ucb-apg228.fits
# ucb-apg233.fits
# ucb-apg236.fits
# ucb-aph201.fits
# ucb-aph205.fits
# ucb-aph207.fits
# ucb-aph209.fits
# ucb-aph275.fits
# ucb-api195.fits
# ucb-apk191.fits
# ucb-apl193.fits
# ucb-apl207.fits
# ucb-apm205.fits
# ucb-apm210.fits
# ucb-apn180.fits
# ucb-apn186.fits
# ucb-apn212.fits
# ucb-apn213.fits
# ucb-apr195.fits
# ucb-apr199.fits
# ucb-apw185.fits
# ucb-apw190.fits
# ucb-apw195.fits
# ucb-apx189.fits
# ucb-apx190.fits
# ucb-apx191.fits
# ucb-apx192.fits
# ucb-apx193.fits
# ucb-apx195.fits
# ucb-apx200.fits
# ucb-apx202.fits
# ucb-apy200.fits
# ucb-apy201.fits
# ucb-apy202.fits
# ucb-apy204.fits
# ucb-apy205.fits
# ucb-apy206.fits
# ucb-apy207.fits
# ucb-apy208.fits
# ucb-apy214.fits
# ucb-apy216.fits
# ucb-apy217.fits
# ucb-apy221.fits
# ucb-apz210.fits
# ucb-apz215.fits
# ucb-apz216.fits
# ucb-apz217.fits
# ucb-apz220.fits
# ucb-apz257.fits
# ucb-apz258.fits
# ucb-aqa197.fits
# ucb-aqa198.fits
# ucb-aqa199.fits
# ucb-aqa207.fits
# ucb-aqa209.fits
# ucb-aqa213.fits
# ucb-aqa215.fits
# ucb-aqa216.fits
# ucb-aqa217.fits
# ucb-aqa218.fits
# ucb-aqa219.fits
# ucb-aqa220.fits
# ucb-aqa221.fits
# ucb-aqa231.fits
# ucb-aqa236.fits
# ucb-aqa248.fits
# ucb-aqa252.fits
# ucb-aqb188.fits
# ucb-aqb189.fits
# ucb-aqb190.fits
# ucb-aqb191.fits
# ucb-aqb202.fits
# ucb-aqb216.fits
# ucb-aqb226.fits
# ucb-aqb230.fits
# ucb-aqb232.fits
# ucb-aqb236.fits
# ucb-aqc197.fits
# ucb-aqc202.fits
# ucb-aqc203.fits
# ucb-aqc204.fits
# ucb-aqc205.fits
# ucb-aqd211.fits
# ucb-aqd241.fits
# ucb-aqd242.fits
# ucb-aqd243.fits
# ucb-aqf221.fits
# ucb-aqf237.fits
# ucb-aqf241.fits
# ucb-aqf245.fits
# ucb-aqf247.fits
# ucb-aqf248.fits
# ucb-aqh211.fits
# ucb-aqi212.fits
# ucb-aqi213.fits
# ucb-aqi214.fits
# ucb-aqi216.fits
# ucb-aqi218.fits
# ucb-aqi219.fits
# ucb-aqk191.fits
# ucb-aqk195.fits
# ucb-aqk205.fits
# ucb-aqk208.fits
# ucb-aqk222.fits
# ucb-aqk236.fits
# ucb-aql189.fits
# ucb-aql191.fits
# ucb-aql202.fits
# ucb-aqm204.fits
# ucb-aqm205.fits
# ucb-aqm258.fits
# ucb-aqm260.fits
# ucb-aqn198.fits
# ucb-aqn199.fits
# ucb-aqn200.fits
# ucb-aqn201.fits
# ucb-aqn222.fits
# ucb-aqn223.fits
# ucb-aqo201.fits
# ucb-aqo202.fits
# ucb-aqo204.fits
# ucb-aqp202.fits
# ucb-aqq216.fits
# ucb-aqq219.fits
# ucb-aqq224.fits
# ucb-aqq225.fits
# ucb-aqq226.fits
# ucb-aqq227.fits
# ucb-aqq228.fits
# ucb-aqq229.fits
# ucb-aqq230.fits
# ucb-aqq231.fits
# ucb-aqq232.fits
# ucb-aqq233.fits
# ucb-aqq234.fits
# ucb-aqq246.fits
# ucb-aqr212.fits
# ucb-aqr214.fits
# ucb-aqr219.fits
# ucb-aqr220.fits
# ucb-aqr221.fits
# ucb-aqr222.fits
# ucb-aqr227.fits
# ucb-aqr231.fits
# ucb-aqr232.fits
# ucb-aqr233.fits
# ucb-aqr234.fits
# ucb-aqr235.fits
# ucb-aqs213.fits
# ucb-aqs216.fits
# ucb-aqs217.fits
# ucb-aqs218.fits
# ucb-aqs222.fits
# ucb-aqs224.fits
# ucb-aqt211.fits
# ucb-aqt215.fits
# ucb-aqt227.fits
# ucb-aqt232.fits
# ucb-aqt233.fits
# ucb-aqt234.fits
# ucb-aqt235.fits
# ucb-aqt236.fits
# ucb-aqt237.fits
# ucb-aqt241.fits
# ucb-aqt243.fits
# ucb-aqt244.fits
# ucb-aqt247.fits
# ucb-aqt248.fits
# ucb-aqt249.fits
# ucb-aqt252.fits
# ucb-aqu224.fits
# ucb-aqu233.fits
# ucb-aqu241.fits
# ucb-aqu242.fits
# ucb-aqu243.fits
# ucb-aqu244.fits
# ucb-aqu253.fits
# ucb-aqu254.fits
# ucb-aqv227.fits
# ucb-aqv246.fits
# ucb-aqv256.fits
# ucb-aqw218.fits
# ucb-aqw222.fits
# ucb-aqw224.fits
# ucb-aqw257.fits
# ucb-aqw260.fits
# ucb-aqw261.fits
# ucb-aqw262.fits
# ucb-aqw263.fits
# ucb-aqx208.fits
# ucb-aqx210.fits
# ucb-aqx211.fits
# ucb-aqx262.fits
# ucb-aqx265.fits
# ucb-aqx266.fits
# ucb-aqx267.fits
# ucb-aqx268.fits
# ucb-aqx269.fits
# ucb-aqy215.fits
# ucb-aqy217.fits
# ucb-aqy218.fits
# ucb-aqy219.fits
# ucb-aqy220.fits
# ucb-aqy255.fits
# ucb-aqy256.fits
# ucb-aqy257.fits
# ucb-aqy258.fits
# ucb-aqy259.fits
# ucb-aqy269.fits
# ucb-aqy271.fits
# ucb-aqy275.fits
# ucb-aqz100.fits
# ucb-aqz101.fits
# ucb-aqz132.fits
# ucb-aqz133.fits
# ucb-aqz138.fits
# ucb-aqz140.fits
# ucb-aqz146.fits
# ucb-ara209.fits
# ucb-ara210.fits
# ucb-ara211.fits
# ucb-ara212.fits
# ucb-ara214.fits
# ucb-ara243.fits
# ucb-ara245.fits
# ucb-ara249.fits
# ucb-ara251.fits
# ucb-ara261.fits
# ucb-ara262.fits
# ucb-ara267.fits
# ucb-arb209.fits
# ucb-arb213.fits
# ucb-arb226.fits
# ucb-arb252.fits
# ucb-arb253.fits
# ucb-arb262.fits
# ucb-arb271.fits
# ucb-arb272.fits
# ucb-arb274.fits
# ucb-arc211.fits
# ucb-arc214.fits
# ucb-arc215.fits
# ucb-arc216.fits
# ucb-arc251.fits
# ucb-ard211.fits
# ucb-ard218.fits
# ucb-are211.fits
# ucb-are218.fits
# ucb-arf183.fits
# ucb-arf214.fits
# ucb-arf215.fits
# ucb-arj223.fits
# ucb-arj224.fits
# ucb-arj226.fits
# ucb-arj227.fits
# ucb-arj239.fits
# ucb-arj241.fits
# ucb-arj242.fits
# ucb-arj245.fits
# ucb-arj246.fits
# ucb-arj247.fits
# ucb-arj248.fits
# ucb-arj249.fits
# ucb-arj250.fits
# ucb-arj251.fits
# ucb-arj252.fits
# ucb-arj253.fits
# ucb-arj254.fits
# ucb-arj255.fits
# ucb-arj256.fits
# ucb-arj257.fits
# ucb-arj258.fits
# ucb-arl220.fits
# ucb-arm274.fits
# ucb-arn217.fits
# ucb-aro215.fits
# ucb-aro216.fits
# ucb-arp209.fits
# ucb-arp210.fits
# ucb-arp211.fits
# ucb-arp212.fits
# ucb-arp213.fits
# ucb-arp214.fits
# ucb-arp215.fits
# ucb-arp216.fits
# ucb-arp217.fits
# ucb-arp218.fits
# ucb-arp219.fits
# ucb-arp280.fits
# ucb-arr243.fits
# ucb-art205.fits
# ucb-art208.fits
# ucb-aru287.fits
# ucb-aru288.fits
# ucb-aru289.fits
# ucb-aru290.fits
# ucb-aru291.fits
# ucb-arv179.fits
# ucb-arv185.fits
# ucb-arw193.fits
# ucb-arw197.fits
# ucb-arz281.fits
# ucb-arz282.fits
# ucb-arz283.fits
# ucb-arz284.fits
# ucb-arz372.fits
# ucb-asa222.fits
# ucb-asa223.fits
# ucb-asa224.fits
# ucb-asa225.fits
# ucb-asa226.fits
# ucb-asb214.fits
# ucb-asb217.fits
# ucb-asb222.fits
# ucb-asb224.fits
# ucb-asb226.fits
# ucb-asb227.fits
# ucb-asc203.fits
# ucb-asc204.fits
# ucb-asc227.fits
# ucb-asc228.fits
# ucb-asc239.fits
# ucb-asc240.fits
# ucb-ase205.fits
# ucb-ase209.fits
# ucb-ase210.fits
# ucb-ase214.fits
# ucb-ase215.fits
# ucb-ase216.fits
# ucb-ase231.fits
# ucb-ase239.fits
# ucb-ase242.fits
# ucb-ase243.fits
# ucb-ase265.fits
# ucb-asf223.fits
# ucb-asf226.fits
# ucb-asg200.fits
# ucb-asg201.fits
# ucb-asg203.fits
# ucb-asg205.fits
# ucb-ash200.fits
# ucb-ash238.fits
# ucb-ash245.fits
# ucb-ask201.fits
# ucb-ask202.fits
# ucb-ask203.fits
# ucb-ask212.fits
# ucb-ask223.fits
# ucb-ask224.fits
# ucb-ask230.fits
# ucb-ask232.fits
# ucb-ask234.fits
# ucb-ask235.fits
# ucb-ask261.fits
# ucb-ask262.fits
# ucb-ask264.fits
# ucb-ask265.fits
# ucb-asl207.fits
# ucb-asl241.fits
# ucb-asn193.fits
# ucb-asn194.fits
# ucb-asn195.fits
# ucb-asn196.fits
# ucb-asn197.fits
# ucb-asn198.fits
# ucb-asn202.fits
# ucb-asn205.fits
# ucb-asn208.fits
# ucb-asn209.fits
# ucb-asn221.fits
# ucb-asn222.fits
# ucb-asn230.fits
# ucb-asn231.fits
# ucb-asn233.fits
# ucb-asn234.fits
# ucb-asn235.fits
# ucb-aso192.fits
# ucb-aso211.fits
# ucb-aso251.fits
# ucb-asp194.fits
# ucb-asp195.fits
# ucb-asp201.fits
# ucb-asp231.fits
# ucb-asp237.fits
# ucb-asp247.fits
# ucb-asp249.fits
# ucb-asp260.fits
# ucb-asp261.fits
# ucb-asq206.fits
# ucb-asq207.fits
# ucb-asq246.fits
# ucb-asq261.fits
# ucb-asq266.fits
# ucb-asr215.fits
# ucb-asr279.fits
# ucb-ass261.fits
# ucb-ass306.fits
# ucb-ast200.fits
# ucb-ast201.fits
# ucb-ast202.fits
# ucb-ast204.fits
# ucb-ast206.fits
# ucb-ast207.fits
# ucb-ast210.fits
# ucb-ast211.fits
# ucb-ast212.fits
# ucb-ast213.fits
# ucb-ast214.fits
# ucb-ast229.fits
# ucb-ast273.fits
# ucb-ast274.fits
# ucb-ast275.fits
# ucb-ast276.fits
# ucb-ast286.fits
# ucb-asu182.fits
# ucb-asy139.fits
# ucb-asy141.fits
# ucb-asy142.fits
# ucb-asy146.fits
# ucb-asy161.fits
# ucb-asy162.fits
# ucb-asy163.fits
# ucb-asy164.fits
# ucb-asy165.fits
# ucb-asy174.fits
# ucb-asz185.fits
# ucb-asz186.fits
# ucb-asz190.fits
# ucb-asz191.fits
# ucb-asz196.fits
# ucb-asz199.fits
# ucb-asz211.fits
# ucb-asz218.fits
# ucb-ata189.fits
# ucb-ata193.fits
# ucb-ata209.fits
# ucb-ata244.fits
# ucb-atc194.fits
# ucb-atc196.fits
# ucb-atc241.fits
# ucb-atg159.fits
# ucb-atg160.fits
# ucb-atg161.fits
# ucb-atg167.fits
# ucb-atg168.fits
# ucb-atg169.fits
# ucb-atg170.fits
# ucb-atg171.fits
# ucb-atg172.fits
# ucb-atg208.fits
# ucb-atg209.fits
# ucb-atg210.fits
# ucb-ath237.fits
# ucb-ath238.fits
# ucb-ath239.fits
# ucb-ati192.fits
# ucb-ati193.fits
# ucb-ati194.fits
# ucb-ati195.fits
# ucb-ati196.fits
# ucb-ati197.fits
# ucb-ati199.fits
# ucb-ati200.fits
# ucb-ati201.fits
# ucb-ati208.fits
# ucb-ati209.fits
# ucb-ati210.fits
# ucb-ati211.fits
# ucb-ati212.fits
# ucb-ati213.fits
# ucb-ati215.fits
# ucb-ati216.fits
# ucb-ati217.fits
# ucb-ati218.fits
# ucb-ati219.fits
# ucb-ati220.fits
# ucb-ati225.fits
# ucb-ati226.fits
# ucb-ati227.fits
# ucb-ati243.fits
# ucb-ati244.fits
# ucb-ati245.fits
# ucb-ati246.fits
# ucb-ati247.fits
# ucb-ati248.fits
# ucb-ati252.fits
# ucb-ati253.fits
# ucb-ati254.fits
# ucb-atk213.fits
# ucb-atk214.fits
# ucb-atk215.fits
# ucb-atk216.fits
# ucb-atk217.fits
# ucb-atk218.fits
# ucb-atk224.fits
# ucb-atk225.fits
# ucb-atk226.fits
# ucb-atl189.fits
# ucb-atl190.fits
# ucb-atl191.fits
# ucb-atl193.fits
# ucb-atl194.fits
# ucb-atl195.fits
# ucb-atl198.fits
# ucb-atl199.fits
# ucb-atl200.fits
# ucb-atl201.fits
# ucb-atl202.fits
# ucb-atl203.fits
# ucb-atl204.fits
# ucb-atl205.fits
# ucb-atl210.fits
# ucb-atl211.fits
# ucb-atl212.fits
# ucb-atl218.fits
# ucb-atl219.fits
# ucb-atl220.fits
# ucb-atm198.fits
# ucb-atm199.fits
# ucb-atm200.fits
# ucb-atm206.fits
# ucb-atm207.fits
# ucb-atm208.fits
# ucb-atm221.fits
# ucb-atm222.fits
# ucb-atm223.fits
# ucb-atm227.fits
# ucb-atm228.fits
# ucb-atm229.fits
# ucb-atm234.fits
# ucb-atm235.fits
# ucb-atm236.fits
# ucb-atm237.fits
# ucb-atm238.fits
# ucb-atm239.fits
# ucb-atm242.fits
# ucb-atm243.fits
# ucb-atm244.fits
# ucb-atm245.fits
# ucb-atm246.fits
# ucb-atm247.fits
# ucb-atm252.fits
# ucb-atm253.fits
# ucb-atm254.fits
# ucb-atm261.fits
# ucb-atm262.fits
# ucb-atm263.fits
# ucb-atm270.fits
# ucb-atn197.fits
# ucb-atn198.fits
# ucb-atn199.fits
# ucb-atn221.fits
# ucb-atn222.fits
# ucb-atn223.fits
# ucb-ato198.fits
# ucb-ato199.fits
# ucb-ato200.fits
# ucb-ato208.fits
# ucb-ato209.fits
# ucb-ato210.fits
# ucb-ato212.fits
# ucb-ato213.fits
# ucb-ato214.fits
# ucb-ato221.fits
# ucb-ato222.fits
# ucb-ato223.fits
# ucb-ato224.fits
# ucb-ato225.fits
# ucb-ato226.fits
# ucb-ato242.fits
# ucb-ato243.fits
# ucb-ato244.fits
# ucb-ato245.fits
# ucb-ato246.fits
# ucb-ato247.fits
# ucb-ato248.fits
# ucb-ato249.fits
# ucb-ato250.fits
# ucb-ato254.fits
# ucb-ato255.fits
# ucb-ato256.fits
# ucb-ato257.fits
# ucb-ato258.fits
# ucb-ato259.fits
# ucb-ato260.fits
# ucb-ato261.fits
# ucb-ato262.fits
# ucb-ato264.fits
# ucb-ato265.fits
# ucb-ato266.fits
# ucb-atp210.fits
# ucb-atp211.fits
# ucb-atp212.fits
# ucb-atp241.fits
# ucb-atp242.fits
# ucb-atp243.fits
# ucb-atp244.fits
# ucb-atp245.fits
# ucb-atp246.fits
# ucb-atp259.fits
# ucb-atp260.fits
# ucb-atp261.fits
# ucb-atr195.fits
# ucb-atr196.fits
# ucb-atr197.fits
# ucb-atr205.fits
# ucb-atr206.fits
# ucb-atr207.fits
# ucb-atr208.fits
# ucb-atr209.fits
# ucb-atr210.fits
# ucb-atr211.fits
# ucb-atr212.fits
# ucb-atr213.fits
# ucb-atr214.fits
# ucb-atr215.fits
# ucb-atr216.fits
# ucb-atr225.fits
# ucb-atr226.fits
# ucb-atr227.fits
# ucb-atu220.fits
# ucb-atu221.fits
# ucb-atu222.fits
# ucb-atu230.fits
# ucb-atu231.fits
# ucb-atu232.fits
# ucb-atu280.fits
# ucb-atu281.fits
# ucb-atu282.fits
# ucb-atu283.fits
# ucb-atu284.fits
# ucb-atu285.fits
# ucb-atu289.fits
# ucb-atu290.fits
# ucb-atu291.fits
# ucb-atx213.fits
# ucb-atx214.fits
# ucb-atx215.fits
# ucb-atx266.fits
# ucb-atx308.fits
# ucb-aty196.fits
# ucb-aty197.fits
# ucb-aty198.fits
# ucb-aty199.fits
# ucb-aty200.fits
# ucb-aty201.fits
# ucb-aua219.fits
# ucb-aua220.fits
# ucb-aua221.fits
# ucb-aub223.fits
# ucb-aub224.fits
# ucb-aub225.fits
# ucb-aub226.fits
# ucb-aub227.fits
# ucb-aub228.fits
# ucb-aub230.fits
# ucb-aub231.fits
# ucb-aub232.fits
# ucb-aug266.fits
# ucb-aug267.fits
# ucb-aug268.fits
# ucb-aug284.fits
# ucb-aug285.fits
# ucb-aug286.fits
# ucb-aug290.fits
# ucb-aug291.fits
# ucb-aug292.fits
# ucb-auh214.fits
# ucb-auh215.fits
# ucb-auh216.fits
# ucb-auh217.fits
# ucb-auh218.fits
# ucb-auh219.fits
# ucb-auh248.fits
# ucb-auh254.fits
# ucb-auh255.fits
# ucb-auh256.fits
# ucb-auh257.fits
# ucb-auh258.fits
# ucb-auh259.fits
# ucb-auh263.fits
# ucb-auh264.fits
# ucb-auh265.fits
# ucb-auh280.fits
# ucb-auh281.fits
# ucb-auh282.fits
# ucb-auk237.fits
# ucb-auk242.fits
# ucb-aul205.fits
# ucb-aul206.fits
# ucb-aul207.fits
# ucb-aul245.fits
# ucb-avd202.fits
# ucb-avd203.fits
# ucb-avd204.fits
# ucb-avd208.fits
# ucb-avd209.fits
# ucb-avd210.fits
# ucb-avd211.fits
# ucb-avd212.fits
# ucb-avd213.fits
# ucb-avd217.fits
# ucb-avd218.fits
# ucb-avd219.fits
# ucb-avd223.fits
# ucb-avd224.fits
# ucb-avd225.fits
# ucb-avj209.fits
# ucb-avj210.fits
# ucb-avj211.fits
# ucb-avj217.fits
# ucb-avj218.fits
# ucb-avj219.fits
# ucb-avj241.fits
# ucb-avj242.fits
# ucb-avj243.fits
# ucb-avq186.fits
# ucb-avq187.fits
# ucb-avq188.fits
# ucb-avt193.fits
# ucb-avt194.fits
# ucb-avt195.fits
# ucb-avt196.fits
# ucb-avt197.fits
# ucb-avt198.fits
# ucb-avt202.fits
# ucb-avt203.fits
# ucb-avt204.fits
# ucb-avt205.fits
# ucb-avt206.fits
# ucb-avt207.fits
# ucb-avt208.fits
# ucb-avt209.fits
# ucb-avt210.fits
# ucb-avt211.fits
# ucb-avt212.fits
# ucb-avt213.fits
# ucb-avt215.fits
# ucb-avt216.fits
# ucb-avt217.fits
# ucb-avt231.fits
# ucb-avt232.fits
# ucb-avt233.fits
# ucb-avt251.fits
# ucb-avt252.fits
# ucb-avt253.fits
# ucb-avt254.fits
# ucb-avt255.fits
# ucb-avt256.fits
# ucb-avt257.fits
# ucb-avt258.fits
# ucb-avt259.fits
# ucb-avu195.fits
# ucb-avu196.fits
# ucb-avu197.fits
# ucb-avu201.fits
# ucb-avu202.fits
# ucb-avu203.fits
# ucb-avu204.fits
# ucb-avu205.fits
# ucb-avu206.fits
# ucb-avu210.fits
# ucb-avu211.fits
# ucb-avu212.fits
# ucb-avu219.fits
# ucb-avu220.fits
# ucb-avu221.fits
# ucb-avu232.fits
# ucb-avu233.fits
# ucb-avu234.fits
# ucb-avu257.fits
# ucb-avu258.fits
# ucb-avu259.fits
# ucb-avu260.fits
# ucb-avu261.fits
# ucb-avu262.fits
# ucb-avx200.fits
# ucb-avx201.fits
# ucb-avx202.fits
# ucb-avx203.fits
# ucb-avx204.fits
# ucb-avx205.fits
# ucb-avx206.fits
# ucb-avx207.fits
# ucb-avx208.fits
# ucb-avx209.fits
# ucb-avx210.fits
# ucb-avx211.fits
# ucb-avx212.fits
# ucb-avx213.fits
# ucb-avx214.fits
# ucb-avx216.fits
# ucb-avx217.fits
# ucb-avx218.fits
# ucb-avx219.fits
# ucb-avx220.fits
# ucb-avx221.fits
# ucb-avx222.fits
# ucb-avx223.fits
# ucb-avx224.fits
# ucb-avx225.fits
# ucb-avx226.fits
# ucb-avx227.fits
# ucb-avx228.fits
# ucb-avx229.fits
# ucb-avx230.fits
# ucb-avx231.fits
# ucb-avx232.fits
# ucb-avx233.fits
# ucb-avx234.fits
# ucb-avx235.fits
# ucb-avx236.fits
# ucb-avx237.fits
# ucb-avx238.fits
# ucb-avx239.fits
# ucb-avx240.fits
# ucb-avx241.fits
# ucb-avx242.fits
# ucb-avx244.fits
# ucb-avx245.fits
# ucb-avx246.fits
# ucb-avx247.fits
# ucb-avx248.fits
# ucb-avx249.fits
# ucb-avx250.fits
# ucb-avx251.fits
# ucb-avx252.fits
# ucb-avx253.fits
# ucb-avx254.fits
# ucb-avx255.fits
# ucb-avx256.fits
# ucb-avx257.fits
# ucb-avx258.fits
# ucb-avx259.fits
# ucb-avx260.fits
# ucb-avx261.fits
# ucb-avx265.fits
# ucb-avx266.fits
# ucb-avx267.fits
# ucb-avy188.fits
# ucb-avy189.fits
# ucb-avy190.fits
# ucb-avy191.fits
# ucb-avy192.fits
# ucb-avy193.fits
# ucb-avy202.fits
# ucb-avy203.fits
# ucb-avy204.fits
# ucb-avy235.fits
# ucb-avy236.fits
# ucb-avy237.fits
# ucb-avz186.fits
# ucb-avz187.fits
# ucb-avz188.fits
# ucb-avz202.fits
# ucb-avz203.fits
# ucb-avz204.fits
# ucb-avz245.fits
# ucb-avz246.fits
# ucb-avz247.fits
# ucb-awa191.fits
# ucb-awa192.fits
# ucb-awa193.fits
# ucb-awa194.fits
# ucb-awa195.fits
# ucb-awa196.fits
# ucb-awa197.fits
# ucb-awa198.fits
# ucb-awa199.fits
# ucb-axs244.fits
# ucb-axs245.fits
# ucb-axs246.fits
# ucb-axs250.fits
# ucb-axs251.fits
# ucb-axs252.fits
# ucb-axv200.fits
# ucb-axv201.fits
# ucb-axv202.fits
# ucb-axv203.fits
# ucb-axv204.fits
# ucb-axv205.fits
# ucb-axv206.fits
# ucb-axv207.fits
# ucb-axv208.fits
# ucb-axv209.fits
# ucb-axv210.fits
# ucb-axv211.fits
# ucb-axv222.fits
# ucb-axv223.fits
# ucb-axv224.fits
# ucb-axw240.fits
# ucb-axw241.fits
# ucb-axw242.fits
# ucb-axw254.fits
# ucb-axw255.fits
# ucb-axw256.fits
# ucb-axx207.fits
# ucb-axx208.fits
# ucb-axx209.fits
# ucb-axx237.fits
# ucb-axx238.fits
# ucb-axx239.fits
# ucb-ayc223.fits
# ucb-ayc224.fits
# ucb-ayc225.fits
# ucb-ayc246.fits
# ucb-ayc247.fits
# ucb-ayc248.fits
# ucb-aye196.fits
# ucb-aye197.fits
# ucb-aye198.fits
# ucb-ayf214.fits
# ucb-ayf215.fits
# ucb-ayf216.fits
# ucb-ayf224.fits
# ucb-ayf225.fits
# ucb-ayf226.fits
# ucb-ayi238.fits
# ucb-ayi239.fits
# ucb-ayi240.fits
# ucb-ayj246.fits
# ucb-ayj247.fits
# ucb-ayj248.fits
# ucb-ayk242.fits
# ucb-ayk243.fits
# ucb-ayk244.fits
# ucb-ayl220.fits
# ucb-ayl221.fits
# ucb-ayl222.fits
# ucb-ayl253.fits
# ucb-ayl254.fits
# ucb-ayl255.fits
# ucb-ayl261.fits
# ucb-aym223.fits
# ucb-aym224.fits
# ucb-aym225.fits
# ucb-aym248.fits
# ucb-aym249.fits
# ucb-aym250.fits
# ucb-ayn212.fits
# ucb-ayn213.fits
# ucb-ayn214.fits
# ucb-ayn215.fits
# ucb-ayn216.fits
# ucb-ayn217.fits
# ucb-ayn231.fits
# ucb-ayn232.fits
# ucb-ayn233.fits
# ucb-ayo243.fits
# ucb-ayo244.fits
# ucb-ayo245.fits
# ucb-ayq111.fits
# ucb-ayq112.fits
# ucb-ayq113.fits
# ucb-ayq119.fits
# ucb-ayr209.fits
# ucb-ayr213.fits
# ucb-ayr214.fits
# ucb-ayr215.fits
# ucb-ayr216.fits
# ucb-ayr217.fits
# ucb-ayr218.fits
# ucb-ayr219.fits
# ucb-ayr221.fits
# ucb-ayr222.fits

# %%
# Check that wavelength scale is properly registered
idxs_of_order45 = np.where((5882 < target_wl) * (target_wl < 5900))
plt.figure();plt.plot(target_wl[idxs_of_order45],target[idxs_of_order45])
plt.vlines([5890,5896], 0, 1.1,) # Na-D features

# %%
# checking file types -- can delete this cell
path_to_dir = '/datag/blpd0/datax/apf' # Breakthrough Listen APF database
filelist_1 = sorted(os.listdir(path_to_dir))
filelist_1[5869:]
num_ucb = 0
num_not_ucb = 0
for file in filelist_1:
    if file.startswith('ucb'):
        num_ucb += 1
    else:
        num_not_ucb += 1
        
print(num_ucb)
print(num_not_ucb)
# Out:
# 5877
# 5873
