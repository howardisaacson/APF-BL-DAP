# %%
# Group all the BL APF spectra files into subdirectories by the star they belong to. 

import pandas as pd
import shutil
import os

#apf_name_conversion = pd.read_csv('apf_name_conversion_updated.csv') # same as apf_name_conversion but has a header
apf_log_file = pd.read_csv('./apf_log_full_16Aug2021.csv')
apf_path = '/datag/blpd0/datax/apf'

#star_list = list(dict.fromkeys(apf_name_conversion['HIP_NAME'])) # all unique HIP names of spectra in BL APF directory
star_list = list(dict.fromkeys(apf_log_file['HIP_name'])) # all unique HIP names of spectra in BL APF directory
star_list.remove('None') # some HIP names in the log file were not returned by SIMBAD and are listed as None

def get_filenames(starname): 
    rows = apf_log_file[apf_log_file['HIP_name'] == starname] 
    filenames = rows["Filename"]
    return filenames

# find unique HIP names
#star_list_HIP = np.copy(star_list)
#for star in star_list:
#    star_rows = apf_name_conversion[apf_name_conversion['NAME'] == star]
#    star_list_HIP = star_list_HIP + star_rows['HIP_NAME'].tolist()
#star_list_HIP_unique = list(dict.fromkeys(star_list_HIP))
star_list_HIP_unique = star_list

not_found = []
raw_files = []
skipped = []
no_files = [] # should be empty becuase of how log file was created
for star in star_list_HIP_unique: 
    filenames = get_filenames(star)
    if len(filenames) > 0 :
        print(star+': ')
        print(filenames)
        #dir_path = apf_path + '/' + star + '_spectra'
        dir_path = './APF_spectra/all_apf_spectra/' + star + '_spectra'
        os.mkdir(dir_path)
        for file in filenames:
            if file.startswith('r'): 
                #shutil.move('/home/azuckerman/APF_spectra/apf_spectra/'+file+'.fits', dir_path)
                try:
                    shutil.copy(apf_path + '/' + file, dir_path)
                except FileNotFoundError:
                    print(file + '.fits not found in BL APF directory.')
                    not_found += [file]
            elif file.startswith('ucb'): 
                print('skipping raw file ' + file)
                raw_files += [file]
            else:
                print('skipping file ' + file + ' for unkown reason.')
                skipped =+ [file]
    else: 
        print('No files found for star ' + star + '.')
        no_files += [star]
# Out:
# HIP113357:
# 0       raoy.324.fits
# 1834    rboc.727.fits
# 1835    rboc.728.fits
# 1868    rbon.829.fits
# 4790    rboc.726.fits
# 4824    rbon.830.fits
# 4825    rbon.831.fits
# Name: Filename, dtype: object
# HIP95853:
# 1       rany.280.fits
# 1249    rbfh.240.fits
# 1250    rbfh.241.fits
# 1251    rbfh.242.fits
# 1265    rbfk.246.fits
# 1266    rbfk.247.fits
# 1267    rbfk.248.fits
# 1279    rbfm.248.fits
# 1285    rbfn.238.fits
# 1286    rbfn.239.fits
# 1287    rbfn.240.fits
# 1611    rbmm.211.fits
# 1612    rbmm.213.fits
# 1681    rbmu.245.fits
# 1682    rbmu.246.fits
# 1683    rbmu.248.fits
# 4155    rbfg.234.fits
# 4156    rbfg.235.fits
# 4157    rbfg.236.fits
# 4191    rbfm.246.fits
# 4192    rbfm.247.fits
# 4535    rbmm.212.fits
# 4536    rbmm.214.fits
# 4537    rbmm.215.fits
# 4538    rbmm.216.fits
# 4620    rbmu.247.fits
# 4621    rbmu.249.fits
# 4622    rbmu.250.fits
# Name: Filename, dtype: object
# HIP12444:
# 2       ramq.233.fits
# 4       ramr.228.fits
# 16      rana.224.fits
# 2989    ramu.211.fits
# 2997    ramx.180.fits
# 3007    ramz.228.fits
# Name: Filename, dtype: object
# HIP60965:
# 3       raob.239.fits
# 2871    rbyt.085.fits
# 2872    rbyt.087.fits
# 5757    rbyt.086.fits
# Name: Filename, dtype: object
# HIP64241:
# 5       raob.250.fits
# 2868    rbyo.092.fits
# 2891    rbyv.597.fits
# 5748    rbyo.091.fits
# 5749    rbyo.093.fits
# 5778    rbyv.596.fits
# 5779    rbyv.598.fits
# Name: Filename, dtype: object
# HIP42172:
# 6       ramu.251.fits
# 14      ramz.278.fits
# 80      ranx.231.fits
# 106     raob.211.fits
# 2991    ramu.282.fits
# 2993    ramu.300.fits
# 2995    ramv.177.fits
# 3005    ramx.271.fits
# 3027    ranu.276.fits
# 3036    raod.277.fits
# 3037    ranv.272.fits
# 3053    ranw.272.fits
# 3066    raoo.206.fits
# 3084    rany.220.fits
# 3086    rany.228.fits
# Name: Filename, dtype: object
# HIP65477:
# 7       raob.253.fits
# 2793    rbyh.289.fits
# 2794    rbyh.290.fits
# 2795    rbyh.291.fits
# Name: Filename, dtype: object
# HIP56445:
# 8       ramv.171.fits
# 10      ramw.271.fits
# 29      raod.284.fits
# 36      ranr.295.fits
# 42      ranu.282.fits
# 43      raof.236.fits
# 53      raop.228.fits
# 55      raoq.241.fits
# 68      ranw.304.fits
# 107     raob.235.fits
# 122     rapi.195.fits
# 3003    ramx.270.fits
# 3041    ranv.303.fits
# 3054    raog.244.fits
# 3078    raot.242.fits
# 3081    raou.241.fits
# 3088    rany.279.fits
# 3105    raoy.239.fits
# 3113    raoz.206.fits
# 3120    rapg.209.fits
# 3124    raph.205.fits
# 3128    rapk.191.fits
# Name: Filename, dtype: object
# HIP69483:
# 9       raob.269.fits
# 1577    rblx.195.fits
# 4497    rblx.194.fits
# 4498    rblx.196.fits
# Name: Filename, dtype: object
# HIP71284:
# 11    raob.270.fits
# Name: Filename, dtype: object
# HIP19855:
# 12      ramx.195.fits
# 267     rarz.372.fits
# 2987    ramq.252.fits
# 2999    ramx.196.fits
# 3001    ramx.217.fits
# 3009    rana.243.fits
# 3259    rarm.274.fits
# 3271    rarp.280.fits
# 3299    rash.238.fits
# 3431    ratx.266.fits
# 3453    raul.245.fits
# 3792    razr.282.fits
# Name: Filename, dtype: object
# HIP70497:
# 13      raob.271.fits
# 1907    rboo.116.fits
# 1908    rboo.117.fits
# 2009    rbox.112.fits
# 2307    rbqu.474.fits
# 2308    rbqu.475.fits
# 2328    rbqv.780.fits
# 2346    rbqw.192.fits
# 2542    rbrk.160.fits
# 2568    rbsf.323.fits
# 2582    rbsj.527.fits
# 2588    rbsk.791.fits
# 2596    rbsm.312.fits
# 2597    rbsm.313.fits
# 2613    rbss.533.fits
# 2643    rbta.164.fits
# 2663    rbtg.507.fits
# 2673    rbty.333.fits
# 2674    rbty.335.fits
# 2684    rbua.123.fits
# 4869    rboo.115.fits
# 4938    rbox.113.fits
# 4939    rbox.114.fits
# 5237    rbqu.472.fits
# 5238    rbqu.473.fits
# 5269    rbqw.191.fits
# 5270    rbqw.193.fits
# 5316    rbqy.819.fits
# 5362    rbrd.203.fits
# 5363    rbrd.204.fits
# 5364    rbrd.205.fits
# 5365    rbrd.206.fits
# 5449    rbsf.324.fits
# 5469    rbsj.528.fits
# 5470    rbsj.529.fits
# 5481    rbsm.311.fits
# 5519    rbtg.506.fits
# 5535    rbty.334.fits
# 5548    rbua.122.fits
# 5549    rbua.124.fits
# Name: Filename, dtype: object
# HIP93747:
# 15      raob.275.fits
# 1205    rbfd.231.fits
# 4125    rbfd.232.fits
# 4126    rbfd.233.fits
# Name: Filename, dtype: object
# HIP102532:
# 17      raob.287.fits
# 2361    rbqx.420.fits
# 2362    rbqx.421.fits
# 2363    rbqx.422.fits
# 2385    rbqy.723.fits
# 2386    rbqy.724.fits
# 2387    rbqy.725.fits
# 2444    rbrd.122.fits
# 2445    rbrd.123.fits
# 2446    rbrd.125.fits
# 5277    rbqx.423.fits
# 5299    rbqy.721.fits
# 5300    rbqy.722.fits
# 5347    rbrd.124.fits
# Name: Filename, dtype: object
# HIP77622:
# 18      rann.193.fits
# 3011    ranq.231.fits
# Name: Filename, dtype: object
# HIP80628:
# 19     raoc.198.fits
# 780    raza.151.fits
# 781    raza.152.fits
# 782    raza.153.fits
# Name: Filename, dtype: object
# HIP39064:
# 20    ranq.207.fits
# Name: Filename, dtype: object
# HIP76219:
# 21      raoc.204.fits
# 4049    rbex.236.fits
# 4050    rbex.237.fits
# 4051    rbex.238.fits
# Name: Filename, dtype: object
# HIP14576:
# 22      ranr.210.fits
# 1487    rbhv.256.fits
# 1488    rbhv.257.fits
# 1489    rbhv.258.fits
# Name: Filename, dtype: object
# HIP54182:
# 23      raoc.207.fits
# 2846    rbyl.292.fits
# 2847    rbyl.294.fits
# 5725    rbyl.293.fits
# Name: Filename, dtype: object
# HIP21421:
# 24    ranr.211.fits
# Name: Filename, dtype: object
# HIP44901:
# 25      raod.193.fits
# 4069    rbey.194.fits
# 4070    rbey.195.fits
# 4071    rbey.196.fits
# Name: Filename, dtype: object
# HIP9884:
# 26    ranr.212.fits
# Name: Filename, dtype: object
# HIP16852:
# 27    raod.195.fits
# Name: Filename, dtype: object
# HIP37826:
# 28    ranr.241.fits
# Name: Filename, dtype: object
# HIP50583:
# 30      ranr.263.fits
# 1007    rbbn.256.fits
# 1011    rbbr.261.fits
# 1019    rbbw.247.fits
# 1020    rbby.200.fits
# 1023    rbcd.204.fits
# 1025    rbce.229.fits
# 1027    rbci.206.fits
# 1028    rbci.217.fits
# 1042    rbcr.231.fits
# 1047    rbct.183.fits
# 1049    rbcu.222.fits
# 1057    rbdl.181.fits
# 1071    rbds.202.fits
# 1153    rbey.197.fits
# 3933    rbbx.261.fits
# 3934    rbbx.275.fits
# 3935    rbby.203.fits
# 3937    rbcb.216.fits
# 3943    rbci.204.fits
# 3944    rbci.215.fits
# 3955    rbcp.227.fits
# 3956    rbcp.235.fits
# 3961    rbcv.224.fits
# 3964    rbcv.257.fits
# 3968    rbdg.195.fits
# 3982    rbdp.210.fits
# 3986    rbdr.195.fits
# 3994    rbeb.194.fits
# Name: Filename, dtype: object
# HIP88175:
# 31      raod.324.fits
# 2852    rbyn.689.fits
# 2881    rbyu.297.fits
# 2882    rbyu.299.fits
# 5731    rbyn.688.fits
# 5732    rbyn.690.fits
# 5762    rbyu.298.fits
# Name: Filename, dtype: object
# HIP53910:
# 32      ranr.271.fits
# 2812    rbyi.507.fits
# 5681    rbyi.506.fits
# 5682    rbyi.508.fits
# Name: Filename, dtype: object
# HIP92946:
# 33      raod.333.fits
# 871     razq.220.fits
# 872     razq.221.fits
# 3786    razq.222.fits
# Name: Filename, dtype: object
# HIP62956:
# 34    ranr.293.fits
# Name: Filename, dtype: object
# HIP106481:
# 35      raod.346.fits
# 3914    rbbo.232.fits
# 3915    rbbo.233.fits
# 3916    rbbo.234.fits
# Name: Filename, dtype: object
# HIP90139:
# 37      raoe.184.fits
# 3046    raof.244.fits
# Name: Filename, dtype: object
# HIP23875:
# 38    ranu.194.fits
# Name: Filename, dtype: object
# HIP9487:
# 39      raof.187.fits
# 1054    rbdg.186.fits
# Name: Filename, dtype: object
# HIP58001:
# 40    ranu.281.fits
# Name: Filename, dtype: object
# HIP4436:
# 41      raof.189.fits
# 1462    rbhu.226.fits
# 1463    rbhu.228.fits
# 4389    rbhu.227.fits
# Name: Filename, dtype: object
# HIP46853:
# 44      ranv.280.fits
# 1953    rboq.761.fits
# 2031    rboy.448.fits
# 2032    rboy.450.fits
# 2095    rbpl.438.fits
#             ...
# 5533    rbty.300.fits
# 5537    rbtz.604.fits
# 5538    rbtz.605.fits
# 5543    rbua.099.fits
# 5544    rbua.101.fits
# Name: Filename, Length: 124, dtype: object
# HIP26563:
# 45    raog.189.fits
# Name: Filename, dtype: object
# HIP50372:
# 46      ranv.285.fits
# 1089    rbel.241.fits
# 1090    rbel.242.fits
# 1091    rbel.243.fits
# Name: Filename, dtype: object
# HIP33202:
# 47    raog.190.fits
# Name: Filename, dtype: object
# HIP81833:
# 48      ranv.299.fits
# 3720    rayy.199.fits
# 3721    rayy.200.fits
# 3722    rayy.201.fits
# Name: Filename, dtype: object
# HIP71957:
# 49      raog.287.fits
# 2569    rbsf.334.fits
# 2585    rbsj.541.fits
# 2600    rbsm.318.fits
# 2601    rbsm.319.fits
# 2640    rbta.154.fits
# 2641    rbta.155.fits
# 2660    rbtg.501.fits
# 2689    rbua.136.fits
# 2690    rbua.137.fits
# 2801    rbyi.486.fits
# 2802    rbyi.487.fits
# 5450    rbsf.333.fits
# 5451    rbsf.335.fits
# 5473    rbsj.540.fits
# 5474    rbsj.542.fits
# 5483    rbsm.317.fits
# 5507    rbta.156.fits
# 5516    rbtg.500.fits
# 5517    rbtg.502.fits
# 5553    rbua.135.fits
# 5671    rbyi.485.fits
# Name: Filename, dtype: object
# HIP85157:
# 50      ranv.312.fits
# 1134    rbex.240.fits
# 1599    rbmm.185.fits
# 1665    rbmu.195.fits
# 1666    rbmu.197.fits
# 4052    rbex.239.fits
# 4053    rbex.241.fits
# 4521    rbmm.186.fits
# 4522    rbmm.187.fits
# 4606    rbmu.196.fits
# Name: Filename, dtype: object
# HIP37288:
# 51      raop.198.fits
# 3074    raop.196.fits
# 3076    raop.197.fits
# Name: Filename, dtype: object
# HIP83000:
# 52      ranv.316.fits
# 1026    rbce.243.fits
# 3941    rbce.241.fits
# 3942    rbce.242.fits
# Name: Filename, dtype: object
# HIP77464:
# 54      ranv.323.fits
# 1154    rbey.200.fits
# 1155    rbey.201.fits
# 4072    rbey.202.fits
# Name: Filename, dtype: object
# HIP74666:
# 56      ranv.345.fits
# 1094    rbep.199.fits
# 1095    rbep.200.fits
# 4010    rbep.198.fits
# 4024    rbep.226.fits
# 4025    rbep.227.fits
# 4026    rbep.228.fits
# Name: Filename, dtype: object
# HIP8903:
# 58      ranw.195.fits
# 3025    ranu.193.fits
# Name: Filename, dtype: object
# HIP677:
# 60      ranw.196.fits
# 1432    rbhp.207.fits
# 3049    ranw.215.fits
# 4360    rbhp.208.fits
# 4361    rbhp.209.fits
# Name: Filename, dtype: object
# HIP80179:
# 61      raou.288.fits
# 783     raza.157.fits
# 3723    raza.156.fits
# 3724    raza.158.fits
# Name: Filename, dtype: object
# HIP105199:
# 62      ranw.197.fits
# 969     rbau.183.fits
# 3051    ranw.216.fits
# 3857    rbau.184.fits
# 3858    rbau.185.fits
# Name: Filename, dtype: object
# HIP69989:
# 63      raow.180.fits
# 89      raox.242.fits
# 3094    raox.212.fits
# 3106    raoy.259.fits
# Name: Filename, dtype: object
# HIP99031:
# 65      raow.182.fits
# 3096    raox.245.fits
# 3108    raoy.265.fits
# 5683    rbyi.514.fits
# 5684    rbyi.515.fits
# 5685    rbyi.516.fits
# Name: Filename, dtype: object
# HIP78459:
# 67     raow.192.fits
# 83     raox.218.fits
# 91     raox.266.fits
# 101    raoy.285.fits
# Name: Filename, dtype: object
# HIP84862:
# 69      raow.218.fits
# 85      raox.221.fits
# 105     raoy.305.fits
# 1598    rbmm.181.fits
# 1671    rbmu.211.fits
# 3092    raow.200.fits
# 3099    raox.280.fits
# 4518    rbmm.182.fits
# 4519    rbmm.183.fits
# 4520    rbmm.184.fits
# 4611    rbmu.209.fits
# 4612    rbmu.210.fits
# Name: Filename, dtype: object
# HIP69673:
# 70      ranw.314.fits
# 2771    rbxr.284.fits
# 2785    rbyb.691.fits
# 5641    rbxr.282.fits
# 5642    rbxr.283.fits
# 5660    rbyb.692.fits
# 5661    rbyb.693.fits
# Name: Filename, dtype: object
# HIP32439:
# 71     raox.187.fits
# 108    raoy.325.fits
# Name: Filename, dtype: object
# HIP72607:
# 72      ranw.315.fits
# 2836    rbyk.092.fits
# 5708    rbyk.090.fits
# 5709    rbyk.091.fits
# Name: Filename, dtype: object
# HIP49081:
# 73      raox.194.fits
# 3101    raoy.202.fits
# Name: Filename, dtype: object
# HIP102488:
# 74      ranw.331.fits
# 933     rbak.207.fits
# 1854    rboj.101.fits
# 1855    rboj.103.fits
# 1856    rboj.105.fits
# 1920    rbop.411.fits
# 1921    rbop.413.fits
# 1922    rbop.414.fits
# 1978    rbou.120.fits
# 1979    rbou.122.fits
# 2120    rbpp.689.fits
# 2121    rbpp.690.fits
# 2122    rbpp.692.fits
# 2158    rbqb.608.fits
# 2159    rbqb.610.fits
# 2170    rbqk.404.fits
# 2171    rbqk.405.fits
# 2172    rbqk.406.fits
# 2388    rbqy.749.fits
# 3837    rbak.205.fits
# 3838    rbak.206.fits
# 4808    rboj.102.fits
# 4809    rboj.104.fits
# 4891    rbop.412.fits
# 4892    rbop.415.fits
# 4920    rbou.121.fits
# 4921    rbou.123.fits
# 4922    rbou.124.fits
# 4981    rbpc.794.fits
# 4982    rbpc.795.fits
# 4983    rbpc.796.fits
# 5050    rbpp.691.fits
# 5051    rbpp.693.fits
# 5088    rbqb.606.fits
# 5089    rbqb.607.fits
# 5090    rbqb.609.fits
# 5302    rbqy.747.fits
# 5303    rbqy.748.fits
# Name: Filename, dtype: object
# HIP21039:
# 75      raox.195.fits
# 3103    raoy.210.fits
# Name: Filename, dtype: object
# HIP14668:
# 76      ranx.186.fits
# 1472    rbhv.228.fits
# 1473    rbhv.229.fits
# 4403    rbhv.227.fits
# Name: Filename, dtype: object
# HIP47080:
# 77    raox.200.fits
# Name: Filename, dtype: object
# HIP41307:
# 78    ranx.227.fits
# Name: Filename, dtype: object
# HIP42080:
# 79      raox.201.fits
# 3100    raoy.201.fits
# Name: Filename, dtype: object
# HIP38048:
# 81      raox.202.fits
# 3102    raoy.207.fits
# Name: Filename, dtype: object
# HIP53229:
# 82    ranx.259.fits
# Name: Filename, dtype: object
# HIP87585:
# 84      ranx.260.fits
# 1190    rbfb.232.fits
# 4107    rbfb.231.fits
# 4108    rbfb.233.fits
# Name: Filename, dtype: object
# HIP83207:
# 86      ranx.273.fits
# 886     razy.180.fits
# 887     razy.181.fits
# 3803    razy.179.fits
# Name: Filename, dtype: object
# HIP56802:
# 87    raox.225.fits
# 99    raoy.226.fits
# Name: Filename, dtype: object
# HIP21589:
# 88    rany.193.fits
# Name: Filename, dtype: object
# HIP30419:
# 90    rany.200.fits
# Name: Filename, dtype: object
# HIP37629:
# 92    rany.213.fits
# Name: Filename, dtype: object
# HIP97650:
# 93     raox.274.fits
# 103    raoy.300.fits
# Name: Filename, dtype: object
# HIP51658:
# 94    rany.249.fits
# Name: Filename, dtype: object
# HIP61317:
# 95      rany.271.fits
# 2915    rbzf.097.fits
# 2916    rbzf.098.fits
# 5810    rbzf.099.fits
# Name: Filename, dtype: object
# HIP64394:
# 96      rany.282.fits
# 2292    rbqt.209.fits
# 2309    rbqu.476.fits
# 2329    rbqv.787.fits
# 2347    rbqw.194.fits
# 2348    rbqw.195.fits
# 2349    rbqw.196.fits
# 2434    rbrc.847.fits
# 2465    rbrd.212.fits
# 2466    rbrd.213.fits
# 2541    rbrk.157.fits
# 2558    rbrl.453.fits
# 2559    rbrl.454.fits
# 2590    rbsk.797.fits
# 2598    rbsm.314.fits
# 2599    rbsm.315.fits
# 2620    rbsy.414.fits
# 2621    rbsy.415.fits
# 2622    rbsy.416.fits
# 2639    rbta.153.fits
# 2653    rbtg.491.fits
# 2654    rbtg.492.fits
# 2655    rbtg.493.fits
# 2681    rbua.112.fits
# 2682    rbua.113.fits
# 5222    rbqt.207.fits
# 5223    rbqt.208.fits
# 5239    rbqu.477.fits
# 5240    rbqu.478.fits
# 5253    rbqv.785.fits
# 5254    rbqv.786.fits
# 5315    rbqy.816.fits
# 5337    rbrc.846.fits
# 5338    rbrc.848.fits
# 5368    rbrd.214.fits
# 5427    rbrk.155.fits
# 5428    rbrk.156.fits
# 5441    rbrl.455.fits
# 5447    rbsf.316.fits
# 5448    rbsf.317.fits
# 5459    rbsg.636.fits
# 5465    rbsj.521.fits
# 5482    rbsm.316.fits
# 5490    rbss.532.fits
# 5529    rbtv.486.fits
# 5545    rbua.111.fits
# Name: Filename, dtype: object
# HIP22044:
# 97    raoy.206.fits
# Name: Filename, dtype: object
# HIP72220:
# 98      rany.285.fits
# 5714    rbyk.099.fits
# 5715    rbyk.100.fits
# 5716    rbyk.101.fits
# Name: Filename, dtype: object
# HIP98036:
# 100     rany.300.fits
# 2806    rbyi.497.fits
# 2807    rbyi.499.fits
# 5678    rbyi.498.fits
# Name: Filename, dtype: object
# HIP36366:
# 102     ranz.162.fits
# 1968    rbor.148.fits
# 2107    rbpn.136.fits
# 2152    rbpz.144.fits
# 2153    rbpz.145.fits
# 2154    rbpz.146.fits
# 2467    rbrd.217.fits
# 2468    rbrd.218.fits
# 2634    rbta.143.fits
# 4823    rbol.518.fits
# 4932    rbow.683.fits
# 4987    rbpc.880.fits
# 5069    rbps.450.fits
# 5156    rbqn.462.fits
# 5157    rbqn.464.fits
# 5218    rbqt.180.fits
# 5314    rbqy.811.fits
# 5369    rbrd.216.fits
# 5477    rbsk.792.fits
# Name: Filename, dtype: object
# HIP12777:
# 104     ranz.164.fits
# 1858    rboj.129.fits
# 1859    rboj.131.fits
# 1928    rbop.428.fits
# 1929    rbop.430.fits
#             ...
# 5492    rbsy.382.fits
# 5496    rbsz.712.fits
# 5502    rbta.106.fits
# 5503    rbta.107.fits
# 5504    rbta.108.fits
# Name: Filename, Length: 113, dtype: object
# HIP15648:
# 109     rapa.189.fits
# 4434    rbie.230.fits
# 4435    rbie.231.fits
# 4436    rbie.232.fits
# Name: Filename, dtype: object
# HIP23783:
# 110    rapa.194.fits
# Name: Filename, dtype: object
# HIP25278:
# 111     rapa.195.fits
# 1063    rbdp.190.fits
# 3976    rbdp.189.fits
# 3977    rbdp.191.fits
# Name: Filename, dtype: object
# HIP75312:
# 112     rapa.212.fits
# 1101    rbep.229.fits
# 1102    rbep.230.fits
# 1103    rbep.231.fits
# 3117    rapa.249.fits
# 4011    rbep.201.fits
# 4012    rbep.202.fits
# 4013    rbep.203.fits
# Name: Filename, dtype: object
# HIP78180:
# 113     rapa.215.fits
# 116     rapa.252.fits
# 1191    rbfb.257.fits
# 4112    rbfb.258.fits
# 4113    rbfb.259.fits
# Name: Filename, dtype: object
# HIP53824:
# 114     rapa.224.fits
# 2819    rbyj.787.fits
# 3118    rapa.263.fits
# 5695    rbyj.785.fits
# 5696    rbyj.786.fits
# Name: Filename, dtype: object
# HIP93408:
# 115     rapa.237.fits
# 1211    rbfd.240.fits
# 1212    rbfd.242.fits
# 4128    rbfd.241.fits
# Name: Filename, dtype: object
# HIP89348:
# 117     rapa.264.fits
# 3116    rapa.225.fits
# Name: Filename, dtype: object
# HIP96258:
# 118     rapg.212.fits
# 1646    rbmn.262.fits
# 1647    rbmn.264.fits
# 3125    raph.207.fits
# 4578    rbmn.263.fits
# 4646    rbmv.210.fits
# 4647    rbmv.211.fits
# 4648    rbmv.212.fits
# Name: Filename, dtype: object
# HIP91973:
# 119     rapg.214.fits
# 3126    raph.209.fits
# Name: Filename, dtype: object
# HIP22287:
# 123    rapn.180.fits
# Name: Filename, dtype: object
# HIP86623:
# 127     rapw.185.fits
# 1188    rbfb.226.fits
# 4103    rbfb.225.fits
# 4104    rbfb.227.fits
# Name: Filename, dtype: object
# HIP88745:
# 128     rapw.190.fits
# 1200    rbfd.216.fits
# 1201    rbfd.218.fits
# 4121    rbfd.217.fits
# Name: Filename, dtype: object
# HIP5336:
# 129    rapw.195.fits
# Name: Filename, dtype: object
# HIP102843:
# 130     rapx.189.fits
# 3839    rbak.209.fits
# 3840    rbak.210.fits
# 3841    rbak.211.fits
# Name: Filename, dtype: object
# HIP70400:
# 131    rapx.193.fits
# Name: Filename, dtype: object
# HIP102531:
# 132     rapx.202.fits
# 940     rbal.200.fits
# 941     rbal.201.fits
# 3843    rbal.199.fits
# Name: Filename, dtype: object
# HIP112935:
# 133     rapy.200.fits
# 1032    rbcj.205.fits
# 1033    rbcj.206.fits
# 1820    rboc.687.fits
# 1878    rbon.857.fits
# 1879    rbon.858.fits
# 1880    rbon.859.fits
# 2018    rbox.134.fits
# 2019    rbox.135.fits
# 3945    rbcj.204.fits
# 4772    rboc.686.fits
# 4773    rboc.688.fits
# 4946    rbox.136.fits
# Name: Filename, dtype: object
# HIP92549:
# 134    rapy.201.fits
# 865    razq.214.fits
# 866    razq.215.fits
# 867    razq.216.fits
# Name: Filename, dtype: object
# HIP93017:
# 135    rapy.202.fits
# 862    razq.209.fits
# 863    razq.210.fits
# 864    razq.211.fits
# Name: Filename, dtype: object
# HIP108036:
# 136     rapy.204.fits
# 1008    rbbo.206.fits
# 1632    rbmm.259.fits
# 1633    rbmm.262.fits
# 1693    rbmu.280.fits
# 1694    rbmu.282.fits
# 3903    rbbo.205.fits
# 3904    rbbo.207.fits
# 4559    rbmm.260.fits
# 4560    rbmm.261.fits
# 4632    rbmu.281.fits
# Name: Filename, dtype: object
# HIP94083:
# 137     rapy.205.fits
# 1206    rbfd.234.fits
# 1207    rbfd.235.fits
# 1208    rbfd.236.fits
# Name: Filename, dtype: object
# HIP97675:
# 138     rapy.216.fits
# 1332    rbfw.316.fits
# 4244    rbfw.314.fits
# 4245    rbfw.315.fits
# Name: Filename, dtype: object
# HIP110778:
# 139     rapy.217.fits
# 1024    rbce.198.fits
# 1848    rboi.714.fits
# 4805    rboi.715.fits
# Name: Filename, dtype: object
# HIP75761:
# 140     rapz.210.fits
# 1096    rbep.212.fits
# 1097    rbep.214.fits
# 4017    rbep.213.fits
# Name: Filename, dtype: object
# HIP79672:
# 141     rapz.216.fits
# 2833    rbyk.087.fits
# 2834    rbyk.088.fits
# 2835    rbyk.089.fits
# Name: Filename, dtype: object
# HIP14862:
# 142     raqa.197.fits
# 1506    rbit.197.fits
# 1507    rbit.198.fits
# 4441    rbit.196.fits
# Name: Filename, dtype: object
# HIP72848:
# 143    raqa.198.fits
# Name: Filename, dtype: object
# HIP73996:
# 144     raqa.199.fits
# 1098    rbep.215.fits
# 2011    rbox.118.fits
# 2544    rbrk.163.fits
# 2567    rbsf.322.fits
# 2577    rbsg.640.fits
# 2644    rbta.165.fits
# 2691    rbua.141.fits
# 4018    rbep.216.fits
# 4019    rbep.217.fits
# 5471    rbsj.535.fits
# 5484    rbsm.323.fits
# 5491    rbss.539.fits
# 5518    rbtg.505.fits
# 5528    rbtv.485.fits
# 5534    rbty.325.fits
# Name: Filename, dtype: object
# HIP79822:
# 145     raqa.209.fits
# 778     rayy.196.fits
# 779     rayy.197.fits
# 3719    rayy.198.fits
# Name: Filename, dtype: object
# HIP518:
# 146     raqa.213.fits
# 1736    rbnk.496.fits
# 1746    rbnm.002.fits
# 1747    rbnm.003.fits
# 1748    rbnm.004.fits
# 1758    rbno.603.fits
# 1769    rbnp.917.fits
# 1780    rbns.586.fits
# 1781    rbns.587.fits
# 4382    rbhu.215.fits
# 4383    rbhu.216.fits
# 4384    rbhu.217.fits
# 4687    rbnk.494.fits
# 4688    rbnk.495.fits
# 4701    rbnn.308.fits
# 4702    rbnn.309.fits
# 4703    rbnn.310.fits
# 4709    rbno.602.fits
# 4710    rbno.604.fits
# 4718    rbnp.918.fits
# 4719    rbnp.919.fits
# 4727    rbns.585.fits
# Name: Filename, dtype: object
# HIP83608:
# 147     raqa.216.fits
# 919     rbai.212.fits
# 3829    rbai.210.fits
# 3830    rbai.211.fits
# Name: Filename, dtype: object
# HIP83601:
# 148     raqa.217.fits
# 891     rbaa.203.fits
# 3808    rbaa.202.fits
# 3809    rbaa.204.fits
# Name: Filename, dtype: object
# HIP114430:
# 149     raqa.218.fits
# 1073    rbds.246.fits
# 1074    rbds.247.fits
# 1075    rbds.248.fits
# 1950    rboq.742.fits
# 1951    rboq.744.fits
# 2092    rbpl.409.fits
# 2093    rbpl.410.fits
# 2094    rbpl.411.fits
# 2769    rbxq.100.fits
# 4908    rboq.743.fits
# 5635    rbxq.101.fits
# 5636    rbxq.102.fits
# Name: Filename, dtype: object
# HIP4151:
# 150     raqa.219.fits
# 1465    rbhv.196.fits
# 1857    rboj.116.fits
# 1926    rbop.422.fits
# 1927    rbop.423.fits
#             ...
# 5410    rbrj.598.fits
# 5420    rbrk.093.fits
# 5455    rbsg.607.fits
# 5497    rbsz.713.fits
# 5498    rbsz.714.fits
# Name: Filename, Length: 97, dtype: object
# HIP85819:
# 151     raqa.221.fits
# 1600    rbmm.188.fits
# 1601    rbmm.191.fits
# 1669    rbmu.202.fits
# 1670    rbmu.204.fits
# 4084    rbez.218.fits
# 4085    rbez.219.fits
# 4086    rbez.220.fits
# 4523    rbmm.189.fits
# 4524    rbmm.190.fits
# 4609    rbmu.203.fits
# 4610    rbmu.205.fits
# Name: Filename, dtype: object
# HIP114189:
# 152     raqa.231.fits
# 1407    rbha.217.fits
# 1408    rbha.218.fits
# 1942    rboq.723.fits
# 1959    rbor.114.fits
# 1960    rbor.115.fits
# 1961    rbor.116.fits
# 4336    rbha.219.fits
# 4904    rboq.724.fits
# 4905    rboq.725.fits
# Name: Filename, dtype: object
# HIP96895:
# 153     raqa.252.fits
# 2902    rbze.683.fits
# 5797    rbze.682.fits
# 5798    rbze.684.fits
# Name: Filename, dtype: object
# HIP85295:
# 154     raqb.191.fits
# 1643    rbmn.252.fits
# 1644    rbmn.253.fits
# 1715    rbmw.202.fits
# 4571    rbmn.254.fits
# 4665    rbmw.201.fits
# 4666    rbmw.203.fits
# Name: Filename, dtype: object
# HIP94346:
# 155     raqb.216.fits
# 2905    rbze.688.fits
# 2906    rbze.690.fits
# 5800    rbze.689.fits
# Name: Filename, dtype: object
# HIP113718:
# 156     raqb.226.fits
# 1393    rbgy.238.fits
# 1991    rbow.630.fits
# 1992    rbow.631.fits
# 2054    rbpi.383.fits
# 2055    rbpi.384.fits
# 2077    rbpj.700.fits
# 4317    rbgy.236.fits
# 4318    rbgy.237.fits
# 4928    rbow.629.fits
# 4995    rbpi.385.fits
# 5017    rbpj.698.fits
# 5018    rbpj.699.fits
# Name: Filename, dtype: object
# HIP101027:
# 157     raqb.232.fits
# 771     rays.206.fits
# 772     rays.207.fits
# 773     rays.210.fits
# 3712    rays.208.fits
# 3713    rays.211.fits
# 3714    rays.212.fits
# Name: Filename, dtype: object
# HIP99452:
# 158    raqb.236.fits
# 959    rbam.208.fits
# 960    rbam.209.fits
# 961    rbam.210.fits
# Name: Filename, dtype: object
# HIP70016:
# 159    raqc.197.fits
# Name: Filename, dtype: object
# HIP71395:
# 160    raqd.211.fits
# Name: Filename, dtype: object
# HIP98698:
# 162     raqf.237.fits
# 2817    rbyi.526.fits
# 5691    rbyi.527.fits
# 5692    rbyi.528.fits
# Name: Filename, dtype: object
# HIP98677:
# 163     raqf.241.fits
# 2805    rbyi.494.fits
# 5676    rbyi.495.fits
# 5677    rbyi.496.fits
# Name: Filename, dtype: object
# HIP5310:
# 164     raqf.245.fits
# 1504    rbit.186.fits
# 1505    rbit.188.fits
# 2052    rbpe.388.fits
# 4440    rbit.187.fits
# 4988    rbpe.387.fits
# 4989    rbpe.389.fits
# Name: Filename, dtype: object
# HIP3765:
# 165    raqf.247.fits
# Name: Filename, dtype: object
# HIP10644:
# 166     raqf.248.fits
# 1930    rbop.435.fits
# 1931    rbop.437.fits
# 1982    rbou.130.fits
# 1983    rbou.132.fits
# 2034    rbpa.114.fits
# 2101    rbpn.102.fits
# 2139    rbps.426.fits
# 2149    rbpz.129.fits
# 2221    rbqn.458.fits
# 2277    rbqt.156.fits
# 2395    rbqy.764.fits
# 2451    rbrd.162.fits
# 2452    rbrd.163.fits
# 4813    rboj.137.fits
# 4814    rboj.138.fits
# 4815    rboj.139.fits
# 4897    rbop.436.fits
# 4924    rbou.131.fits
# 4972    rbpa.113.fits
# 5066    rbps.424.fits
# 5067    rbps.425.fits
# 5078    rbpz.127.fits
# 5079    rbpz.128.fits
# 5215    rbqt.154.fits
# 5216    rbqt.155.fits
# 5350    rbrd.161.fits
# 5438    rbrl.435.fits
# Name: Filename, dtype: object
# HIP99770:
# 167     raqh.211.fits
# 764     rayr.231.fits
# 765     rayr.232.fits
# 3703    rayr.233.fits
# Name: Filename, dtype: object
# HIP7535:
# 168     raqi.218.fits
# 1518    rbjf.208.fits
# 4452    rbjf.206.fits
# 4453    rbjf.207.fits
# Name: Filename, dtype: object
# HIP5346:
# 169     raqi.219.fits
# 1497    rbie.209.fits
# 4429    rbie.210.fits
# 4430    rbie.211.fits
# Name: Filename, dtype: object
# HIP74995:
# 170     raqk.195.fits
# 2859    rbyn.703.fits
# 2860    rbyn.705.fits
# 2893    rbyy.285.fits
# 2894    rbyy.286.fits
# 5739    rbyn.704.fits
# 5785    rbyy.287.fits
# Name: Filename, dtype: object
# HIP81375:
# 171     raqk.205.fits
# 2825    rbyj.803.fits
# 2826    rbyj.804.fits
# 2827    rbyj.805.fits
# Name: Filename, dtype: object
# HIP82860:
# 172     raql.189.fits
# 901     rbac.209.fits
# 902     rbac.210.fits
# 908     rbad.301.fits
# 909     rbad.303.fits
# 3817    rbac.208.fits
# 3822    rbad.302.fits
# Name: Filename, dtype: object
# HIP65515:
# 173    raql.191.fits
# Name: Filename, dtype: object
# HIP81300:
# 174     raqm.205.fits
# 2828    rbyj.806.fits
# 2829    rbyj.807.fits
# 2830    rbyj.808.fits
# Name: Filename, dtype: object
# HIP9153:
# 175     raqm.258.fits
# 1522    rbjf.213.fits
# 1523    rbjf.215.fits
# 4454    rbjf.214.fits
# Name: Filename, dtype: object
# HIP2762:
# 176     raqm.260.fits
# 1461    rbhu.223.fits
# 4387    rbhu.222.fits
# 4388    rbhu.224.fits
# Name: Filename, dtype: object
# HIP69414:
# 177     raqn.198.fits
# 2897    rbza.685.fits
# 5790    rbza.683.fits
# 5791    rbza.684.fits
# Name: Filename, dtype: object
# HIP80644:
# 178     raqn.199.fits
# 1571    rblu.228.fits
# 1572    rblu.229.fits
# 1585    rbmd.180.fits
# 1586    rbmd.182.fits
# 4491    rblu.230.fits
# 4507    rbmd.181.fits
# Name: Filename, dtype: object
# HIP67422:
# 181     raqo.201.fits
# 1342    rbfy.220.fits
# 1343    rbfy.221.fits
# 4255    rbfy.219.fits
# Name: Filename, dtype: object
# HIP112527:
# 182     raqq.219.fits
# 1828    rboc.715.fits
# 1888    rbon.877.fits
# 1889    rbon.878.fits
# 2021    rbox.140.fits
# 4784    rboc.713.fits
# 4785    rboc.714.fits
# 4846    rbon.876.fits
# 4949    rbox.141.fits
# 4950    rbox.142.fits
# Name: Filename, dtype: object
# HIP90790:
# 183    raqq.229.fits
# Name: Filename, dtype: object
# HIP88684:
# 184     raqq.230.fits
# 768     rayr.245.fits
# 769     rayr.246.fits
# 3708    rayr.247.fits
# Name: Filename, dtype: object
# HIP88972:
# 185    raqq.231.fits
# Name: Filename, dtype: object
# HIP90979:
# 186     raqq.232.fits
# 815     raze.208.fits
# 816     raze.209.fits
# 3759    raze.210.fits
# Name: Filename, dtype: object
# HIP89560:
# 187     raqq.233.fits
# 809     raze.200.fits
# 810     raze.201.fits
# 3756    raze.199.fits
# Name: Filename, dtype: object
# HIP22361:
# 188    raqq.246.fits
# Name: Filename, dtype: object
# HIP81813:
# 189     raqr.212.fits
# 5701    rbyj.800.fits
# 5702    rbyj.801.fits
# 5703    rbyj.802.fits
# Name: Filename, dtype: object
# HIP90035:
# 190     raqr.219.fits
# 822     razg.219.fits
# 3763    razg.220.fits
# 3764    razg.221.fits
# Name: Filename, dtype: object
# HIP910:
# 191     raqr.232.fits
# 1449    rbhs.215.fits
# 1450    rbhs.216.fits
# 4372    rbhs.214.fits
# Name: Filename, dtype: object
# HIP3909:
# 192    raqr.233.fits
# Name: Filename, dtype: object
# HIP5799:
# 193     raqr.234.fits
# 1482    rbhv.246.fits
# 1483    rbhv.247.fits
# 4411    rbhv.245.fits
# Name: Filename, dtype: object
# HIP13601:
# 194    raqr.235.fits
# Name: Filename, dtype: object
# HIP51502:
# 195    raqs.217.fits
# Name: Filename, dtype: object
# HIP51384:
# 196     raqs.218.fits
# 4003    rbel.290.fits
# 4004    rbel.291.fits
# 4005    rbel.292.fits
# Name: Filename, dtype: object
# HIP51819:
# 197    raqs.222.fits
# Name: Filename, dtype: object
# HIP89087:
# 198    raqs.224.fits
# Name: Filename, dtype: object
# HIP62523:
# 199    raqt.211.fits
# Name: Filename, dtype: object
# HIP91608:
# 200     raqt.233.fits
# 3741    razc.233.fits
# 3742    razc.234.fits
# 3743    razc.235.fits
# Name: Filename, dtype: object
# HIP91430:
# 201     raqt.234.fits
# 796     razc.223.fits
# 3737    razc.222.fits
# 3738    razc.224.fits
# Name: Filename, dtype: object
# HIP90656:
# 202    raqt.236.fits
# Name: Filename, dtype: object
# HIP95501:
# 203     raqt.241.fits
# 1239    rbfg.222.fits
# 1240    rbfg.223.fits
# 1253    rbfh.252.fits
# 1254    rbfh.253.fits
# 1282    rbfn.235.fits
# 1283    rbfn.236.fits
# 1284    rbfn.237.fits
# 1308    rbfp.225.fits
# 1309    rbfp.226.fits
# 1310    rbfp.227.fits
# 1620    rbmm.229.fits
# 1621    rbmm.230.fits
# 1622    rbmm.231.fits
# 1623    rbmm.234.fits
# 1689    rbmu.263.fits
# 1690    rbmu.264.fits
# 1691    rbmu.266.fits
# 1692    rbmu.267.fits
# 2044    rbpc.789.fits
# 2045    rbpc.790.fits
# 2046    rbpc.792.fits
# 2047    rbpc.793.fits
# 2123    rbpp.702.fits
# 2124    rbpp.703.fits
# 2176    rbqk.414.fits
# 2177    rbqk.415.fits
# 4149    rbfg.221.fits
# 4169    rbfh.251.fits
# 4177    rbfk.239.fits
# 4178    rbfk.240.fits
# 4179    rbfk.241.fits
# 4543    rbmm.228.fits
# 4544    rbmm.232.fits
# 4545    rbmm.233.fits
# 4630    rbmu.265.fits
# 4631    rbmu.268.fits
# 4880    rbop.390.fits
# 4881    rbop.391.fits
# 4882    rbop.392.fits
# 4883    rbop.393.fits
# 4884    rbop.394.fits
# 4980    rbpc.791.fits
# 5052    rbpp.701.fits
# 5053    rbpp.704.fits
# 5106    rbqk.413.fits
# Name: Filename, dtype: object
# HIP103441:
# 204     raqt.243.fits
# 935     rbal.193.fits
# 936     rbal.194.fits
# 3842    rbal.195.fits
# Name: Filename, dtype: object
# HIP103650:
# 205     raqt.244.fits
# 2693    rbul.484.fits
# 2710    rbun.104.fits
# 2711    rbun.105.fits
# 5556    rbul.482.fits
# 5557    rbul.483.fits
# 5579    rbun.106.fits
# Name: Filename, dtype: object
# HIP104092:
# 206     raqt.247.fits
# 3868    rbaw.202.fits
# 3869    rbaw.203.fits
# 3870    rbaw.204.fits
# Name: Filename, dtype: object
# HIP95319:
# 207     raqt.252.fits
# 1648    rbmn.268.fits
# 1649    rbmn.269.fits
# 1704    rbmv.223.fits
# 4582    rbmn.270.fits
# 4651    rbmv.222.fits
# 4652    rbmv.224.fits
# 4683    rbng.584.fits
# 4684    rbng.585.fits
# 4685    rbng.586.fits
# Name: Filename, dtype: object
# HIP95575:
# 208     raqu.233.fits
# 1252    rbfh.244.fits
# 1263    rbfk.244.fits
# 1264    rbfk.245.fits
# 1276    rbfm.240.fits
# 1296    rbfo.238.fits
# 1297    rbfo.240.fits
# 1312    rbfp.232.fits
# 1313    rbfp.233.fits
# 1645    rbmn.256.fits
# 1700    rbmv.217.fits
# 1701    rbmv.218.fits
# 4152    rbfg.231.fits
# 4153    rbfg.232.fits
# 4154    rbfg.233.fits
# 4164    rbfh.245.fits
# 4165    rbfh.246.fits
# 4180    rbfk.243.fits
# 4188    rbfm.238.fits
# 4189    rbfm.239.fits
# 4211    rbfo.239.fits
# 4225    rbfp.234.fits
# 4572    rbmn.255.fits
# 4573    rbmn.257.fits
# 4649    rbmv.216.fits
# Name: Filename, dtype: object
# HIP94650:
# 209     raqu.242.fits
# 1248    rbfh.238.fits
# 1262    rbfk.237.fits
# 1275    rbfm.237.fits
# 1298    rbfo.241.fits
# 1299    rbfo.242.fits
# 1314    rbfp.235.fits
# 1315    rbfp.236.fits
# 1316    rbfp.237.fits
# 1320    rbfq.230.fits
# 1321    rbfq.231.fits
# 1322    rbfq.232.fits
# 4162    rbfh.237.fits
# 4163    rbfh.239.fits
# 4175    rbfk.235.fits
# 4176    rbfk.236.fits
# 4186    rbfm.235.fits
# 4187    rbfm.236.fits
# 4212    rbfo.243.fits
# Name: Filename, dtype: object
# HIP103388:
# 210    raqu.244.fits
# 942    rbal.202.fits
# 943    rbal.203.fits
# 944    rbal.204.fits
# Name: Filename, dtype: object
# HIP13642:
# 211    raqu.254.fits
# Name: Filename, dtype: object
# HIP94349:
# 212     raqv.246.fits
# 1241    rbfg.225.fits
# 1247    rbfh.235.fits
# 1268    rbfk.251.fits
# 1269    rbfk.253.fits
# 1277    rbfm.241.fits
# 1278    rbfm.243.fits
# 1291    rbfn.254.fits
# 1300    rbfo.249.fits
# 4150    rbfg.226.fits
# 4151    rbfg.227.fits
# 4160    rbfh.234.fits
# 4161    rbfh.236.fits
# 4181    rbfk.252.fits
# 4190    rbfm.242.fits
# 4204    rbfn.255.fits
# 4205    rbfn.256.fits
# 4216    rbfo.250.fits
# 4217    rbfo.251.fits
# Name: Filename, dtype: object
# HIP102870:
# 213     raqv.256.fits
# 5351    rbrd.164.fits
# 5352    rbrd.165.fits
# 5353    rbrd.166.fits
# 5580    rbun.111.fits
# 5581    rbun.112.fits
# 5582    rbun.113.fits
# Name: Filename, dtype: object
# HIP101093:
# 214     raqw.257.fits
# 221     raqy.255.fits
# 2857    rbyn.700.fits
# 2858    rbyn.702.fits
# 2886    rbyu.311.fits
# 3217    raqx.262.fits
# 5738    rbyn.701.fits
# 5766    rbyu.310.fits
# 5767    rbyu.312.fits
# Name: Filename, dtype: object
# HIP101382:
# 215     raqw.261.fits
# 222     raqy.256.fits
# 248     rarj.249.fits
# 3221    raqx.268.fits
# 3252    rarj.245.fits
# 3253    rarj.246.fits
# 3254    rarj.247.fits
# 3255    rarj.248.fits
# 3256    rarj.250.fits
# 3257    rarj.251.fits
# Name: Filename, dtype: object
# HIP76603:
# 216    raqx.211.fits
# 220    raqy.219.fits
# Name: Filename, dtype: object
# HIP102040:
# 217     raqx.269.fits
# 3225    raqy.258.fits
# Name: Filename, dtype: object
# HIP76832:
# 218     raqy.215.fits
# 1181    rbfa.186.fits
# 1182    rbfa.188.fits
# 4092    rbfa.187.fits
# Name: Filename, dtype: object
# HIP76602:
# 219     raqy.217.fits
# 3216    raqx.210.fits
# Name: Filename, dtype: object
# HIP101955:
# 223     raqy.259.fits
# 2856    rbyn.699.fits
# 2884    rbyu.307.fits
# 2885    rbyu.308.fits
# 3218    raqx.265.fits
# 5736    rbyn.697.fits
# 5737    rbyn.698.fits
# 5765    rbyu.309.fits
# Name: Filename, dtype: object
# HIP12832:
# 224     raqy.269.fits
# 1513    rbjf.200.fits
# 1514    rbjf.201.fits
# 1515    rbjf.202.fits
# Name: Filename, dtype: object
# HIP74981:
# 225     raqz.100.fits
# 232     rara.212.fits
# 2861    rbyn.706.fits
# 2887    rbyu.315.fits
# 5740    rbyn.707.fits
# 5741    rbyn.708.fits
# 5768    rbyu.316.fits
# 5769    rbyu.317.fits
# Name: Filename, dtype: object
# HIP101150:
# 226    raqz.132.fits
# 947    rbal.211.fits
# 948    rbal.212.fits
# 949    rbal.213.fits
# Name: Filename, dtype: object
# HIP102226:
# 227    raqz.133.fits
# 236    rara.249.fits
# Name: Filename, dtype: object
# HIP101262:
# 228     raqz.138.fits
# 235     rara.245.fits
# 2855    rbyn.694.fits
# 2883    rbyu.304.fits
# 5734    rbyn.695.fits
# 5735    rbyn.696.fits
# 5763    rbyu.305.fits
# 5764    rbyu.306.fits
# Name: Filename, dtype: object
# HIP68469:
# 229     rara.209.fits
# 5792    rbza.686.fits
# 5793    rbza.687.fits
# 5794    rbza.688.fits
# Name: Filename, dtype: object
# HIP83996:
# 230     rara.210.fits
# 910     rbad.312.fits
# 911     rbad.313.fits
# 3823    rbad.314.fits
# Name: Filename, dtype: object
# HIP75722:
# 231     rara.211.fits
# 2853    rbyn.691.fits
# 2854    rbyn.693.fits
# 5733    rbyn.692.fits
# 5782    rbyw.782.fits
# 5783    rbyw.783.fits
# 5784    rbyw.784.fits
# Name: Filename, dtype: object
# HIP83762:
# 233     rara.214.fits
# 2784    rbyb.686.fits
# 3228    raqz.101.fits
# 5649    rbxr.301.fits
# 5650    rbxr.302.fits
# 5651    rbxr.303.fits
# 5655    rbyb.685.fits
# 5656    rbyb.687.fits
# Name: Filename, dtype: object
# HIP101180:
# 234    rara.243.fits
# 953    rbam.202.fits
# 954    rbam.203.fits
# 955    rbam.204.fits
# Name: Filename, dtype: object
# HIP103039:
# 238     rarb.262.fits
# 2745    rbxd.705.fits
# 2746    rbxd.706.fits
# 2747    rbxg.506.fits
# 2749    rbxi.110.fits
# 2750    rbxi.111.fits
# 2751    rbxj.305.fits
# 2752    rbxj.306.fits
# 2758    rbxm.100.fits
# 2759    rbxm.101.fits
# 2760    rbxm.102.fits
# 5621    rbxg.507.fits
# 5628    rbxj.304.fits
# Name: Filename, dtype: object
# HIP78353:
# 239     rarc.214.fits
# 1164    rbez.203.fits
# 1165    rbez.204.fits
# 4079    rbez.205.fits
# Name: Filename, dtype: object
# HIP103096:
# 240    rarc.251.fits
# Name: Filename, dtype: object
# HIP83945:
# 241     rard.218.fits
# 892     rbaa.205.fits
# 3810    rbaa.206.fits
# 3811    rbaa.207.fits
# Name: Filename, dtype: object
# HIP76315:
# 242     rare.211.fits
# 2903    rbze.685.fits
# 2904    rbze.686.fits
# 5799    rbze.687.fits
# Name: Filename, dtype: object
# HIP63076:
# 244    rarj.223.fits
# Name: Filename, dtype: object
# HIP62207:
# 245    rarj.224.fits
# Name: Filename, dtype: object
# HIP62145:
# 246    rarj.226.fits
# Name: Filename, dtype: object
# HIP107975:
# 249     rarj.252.fits
# 250     rarj.253.fits
# 251     rarj.254.fits
# 252     rarj.255.fits
# 253     rarj.256.fits
# 254     rarj.257.fits
# 1640    rbmm.276.fits
# 1641    rbmm.277.fits
# 1699    rbmu.308.fits
# 3147    rapz.220.fits
# 3258    rarj.258.fits
# 4567    rbmm.275.fits
# 4568    rbmm.278.fits
# 4644    rbmu.309.fits
# 4645    rbmu.310.fits
# Name: Filename, dtype: object
# HIP4856:
# 256     rarp.211.fits
# 1458    rbhu.212.fits
# 1459    rbhu.213.fits
# 2082    rbpj.721.fits
# 2117    rbpo.422.fits
# 2118    rbpo.423.fits
# 2119    rbpo.424.fits
# 2224    rbqn.472.fits
# 4381    rbhu.214.fits
# 5027    rbpj.720.fits
# 5028    rbpj.722.fits
# 5158    rbqn.473.fits
# 5159    rbqn.474.fits
# Name: Filename, dtype: object
# HIP72944:
# 257    rarp.213.fits
# Name: Filename, dtype: object
# HIP70952:
# 258     rarp.218.fits
# 1328    rbfw.303.fits
# 1329    rbfw.305.fits
# 4242    rbfw.304.fits
# Name: Filename, dtype: object
# HIP113829:
# 259     rarr.243.fits
# 1412    rbhb.215.fits
# 1413    rbhb.216.fits
# 1414    rbhb.217.fits
# 1946    rboq.729.fits
# 1947    rboq.730.fits
# 1948    rboq.731.fits
# Name: Filename, dtype: object
# HIP79755:
# 261     raru.288.fits
# 784     raza.161.fits
# 3725    raza.159.fits
# 3726    raza.160.fits
# Name: Filename, dtype: object
# HIP92270:
# 262    raru.290.fits
# 868    razq.217.fits
# 869    razq.218.fits
# 870    razq.219.fits
# Name: Filename, dtype: object
# HIP84223:
# 263     rarw.197.fits
# 893     rbaa.212.fits
# 894     rbaa.213.fits
# 3812    rbaa.211.fits
# Name: Filename, dtype: object
# HIP105932:
# 264     rarz.281.fits
# 993     rbax.220.fits
# 3879    rbax.218.fits
# 3880    rbax.219.fits
# Name: Filename, dtype: object
# HIP71311:
# 265    rarz.282.fits
# Name: Filename, dtype: object
# HIP83451:
# 266     rarz.283.fits
# 920     rbaj.212.fits
# 921     rbaj.213.fits
# 3832    rbaj.214.fits
# Name: Filename, dtype: object
# HIP110341:
# 268     rasa.222.fits
# 999     rbbm.198.fits
# 1000    rbbm.199.fits
# 1792    rbnv.274.fits
# 1806    rbnw.613.fits
# 1807    rbnw.614.fits
# 3889    rbbm.200.fits
# 4740    rbnv.275.fits
# 4741    rbnv.276.fits
# 4756    rbnw.612.fits
# 4766    rbnx.110.fits
# 4767    rbnx.111.fits
# 4768    rbnx.112.fits
# Name: Filename, dtype: object
# HIP117779:
# 269     rasa.223.fits
# 1397    rbgy.242.fits
# 2222    rbqn.460.fits
# 2223    rbqn.461.fits
# 2250    rbqr.543.fits
# 4319    rbgy.243.fits
# 4320    rbgy.244.fits
# 5155    rbqn.459.fits
# 5179    rbqr.544.fits
# 5180    rbqr.545.fits
# Name: Filename, dtype: object
# HIP1463:
# 270     rasa.225.fits
# 5572    rbun.082.fits
# 5573    rbun.083.fits
# 5574    rbun.084.fits
# Name: Filename, dtype: object
# HIP106106:
# 273     rasb.224.fits
# 991     rbax.215.fits
# 992     rbax.217.fits
# 3878    rbax.216.fits
# Name: Filename, dtype: object
# HIP110395:
# 274     rasb.226.fits
# 1001    rbbm.205.fits
# 1864    rbon.825.fits
# 1865    rbon.826.fits
# 1866    rbon.827.fits
# 1867    rbon.828.fits
# 2003    rbox.085.fits
# 2004    rbox.086.fits
# 2005    rbox.088.fits
# 2006    rbox.089.fits
# 3890    rbbm.204.fits
# 3891    rbbm.206.fits
# 4934    rbox.087.fits
# Name: Filename, dtype: object
# HIP86087:
# 275     rase.205.fits
# 1137    rbex.245.fits
# 1138    rbex.247.fits
# 4055    rbex.246.fits
# Name: Filename, dtype: object
# HIP82817:
# 276     rase.216.fits
# 917     rbai.198.fits
# 3825    rbai.199.fits
# 3826    rbai.200.fits
# Name: Filename, dtype: object
# HIP108092:
# 277     rase.231.fits
# 1002    rbbn.202.fits
# 1003    rbbn.204.fits
# 1717    rbmw.256.fits
# 1718    rbmw.258.fits
# 3893    rbbn.203.fits
# 4669    rbmw.257.fits
# Name: Filename, dtype: object
# HIP116495:
# 278     rase.239.fits
# 1380    rbgw.242.fits
# 2016    rbox.128.fits
# 2017    rbox.129.fits
# 2104    rbpn.117.fits
# 2105    rbpn.118.fits
# 2106    rbpn.119.fits
# 2390    rbqy.756.fits
# 2391    rbqy.757.fits
# 4302    rbgw.240.fits
# 4303    rbgw.241.fits
# 4942    rbox.130.fits
# 5306    rbqy.755.fits
# Name: Filename, dtype: object
# HIP111685:
# 279     rase.243.fits
# 1068    rbdr.259.fits
# 1069    rbdr.260.fits
# 1843    rbod.104.fits
# 3987    rbdr.258.fits
# 4797    rbod.103.fits
# 4798    rbod.105.fits
# Name: Filename, dtype: object
# HIP14286:
# 280     rasf.223.fits
# 1479    rbhv.239.fits
# 1480    rbhv.241.fits
# 4408    rbhv.240.fits
# Name: Filename, dtype: object
# HIP92311:
# 281    rasg.201.fits
# 880    razs.216.fits
# 881    razs.217.fits
# 882    razs.218.fits
# Name: Filename, dtype: object
# HIP105406:
# 282    rasg.203.fits
# 978    rbav.189.fits
# 979    rbav.190.fits
# 980    rbav.191.fits
# Name: Filename, dtype: object
# HIP106400:
# 285     rask.202.fits
# 1012    rbbs.223.fits
# 1013    rbbs.225.fits
# 3924    rbbs.224.fits
# Name: Filename, dtype: object
# HIP109638:
# 286     rask.223.fits
# 1009    rbbr.212.fits
# 2748    rbxh.703.fits
# 2763    rbxn.307.fits
# 2766    rbxp.704.fits
# 2767    rbxp.705.fits
# 2768    rbxp.706.fits
# 2770    rbxq.103.fits
# 3922    rbbr.210.fits
# 3923    rbbr.211.fits
# 5625    rbxh.704.fits
# 5626    rbxh.705.fits
# 5633    rbxn.306.fits
# 5637    rbxq.104.fits
# 5638    rbxq.105.fits
# Name: Filename, dtype: object
# HIP110951:
# 287     rask.224.fits
# 1070    rbdr.261.fits
# 3988    rbdr.262.fits
# 3989    rbdr.263.fits
# Name: Filename, dtype: object
# HIP116384:
# 288     rask.230.fits
# 1427    rbhh.211.fits
# 2128    rbpp.720.fits
# 2129    rbpp.721.fits
# 2130    rbpp.722.fits
# 4352    rbhh.212.fits
# 4353    rbhh.213.fits
# Name: Filename, dtype: object
# HIP116613:
# 289     rask.235.fits
# 2399    rbqy.781.fits
# 2400    rbqy.782.fits
# 4346    rbhb.233.fits
# 4347    rbhb.234.fits
# 4348    rbhb.235.fits
# 5109    rbqk.424.fits
# 5110    rbqk.425.fits
# 5111    rbqk.426.fits
# 5307    rbqy.780.fits
# Name: Filename, dtype: object
# HIP8497:
# 290     rask.261.fits
# 1528    rbjf.222.fits
# 1529    rbjf.224.fits
# 4457    rbjf.223.fits
# Name: Filename, dtype: object
# HIP8543:
# 291    rask.262.fits
# Name: Filename, dtype: object
# HIP11569:
# 292     rask.265.fits
# 1558    rble.256.fits
# 1560    rblf.240.fits
# 1561    rblf.241.fits
# 1562    rblf.242.fits
# 4476    rbld.251.fits
# 4477    rbld.252.fits
# 4478    rbld.253.fits
# 4479    rble.254.fits
# 4480    rble.255.fits
# Name: Filename, dtype: object
# HIP109857:
# 293     rasn.193.fits
# 1021    rbcc.285.fits
# 1022    rbcc.286.fits
# 1784    rbnv.258.fits
# 1785    rbnv.259.fits
# 1798    rbnw.597.fits
# 1799    rbnw.598.fits
# 3938    rbcc.287.fits
# 4730    rbnv.256.fits
# 4731    rbnv.257.fits
# 4749    rbnw.599.fits
# 4750    rbnw.600.fits
# Name: Filename, dtype: object
# HIP96183:
# 294     rasn.194.fits
# 852     razp.232.fits
# 853     razp.233.fits
# 854     razp.234.fits
# 1702    rbmv.219.fits
# 1703    rbmv.220.fits
# 4579    rbmn.265.fits
# 4580    rbmn.266.fits
# 4581    rbmn.267.fits
# 4650    rbmv.221.fits
# Name: Filename, dtype: object
# HIP92951:
# 295     rasn.195.fits
# 847     razp.223.fits
# 3780    razp.224.fits
# 3781    razp.225.fits
# Name: Filename, dtype: object
# HIP92984:
# 297    rasn.202.fits
# 843    razp.217.fits
# 844    razp.218.fits
# 845    razp.219.fits
# Name: Filename, dtype: object
# HIP96229:
# 298     rasn.205.fits
# 849     razp.229.fits
# 850     razp.230.fits
# 851     razp.231.fits
# 1617    rbmm.224.fits
# 1618    rbmm.226.fits
# 1619    rbmm.227.fits
# 1684    rbmu.251.fits
# 1685    rbmu.253.fits
# 1686    rbmu.255.fits
# 4541    rbmm.223.fits
# 4542    rbmm.225.fits
# 4623    rbmu.252.fits
# 4624    rbmu.254.fits
# Name: Filename, dtype: object
# HIP106811:
# 299     rasn.208.fits
# 3897    rbbn.216.fits
# 3898    rbbn.217.fits
# 3899    rbbn.218.fits
# Name: Filename, dtype: object
# HIP114379:
# 300     rasn.222.fits
# 1387    rbgx.237.fits
# 1388    rbgx.238.fits
# 1389    rbgx.239.fits
# 2074    rbpj.692.fits
# 4996    rbpi.394.fits
# 4997    rbpi.395.fits
# 4998    rbpi.396.fits
# 5014    rbpj.690.fits
# 5015    rbpj.691.fits
# Name: Filename, dtype: object
# HIP1692:
# 301     rasn.230.fits
# 1460    rbhu.220.fits
# 4385    rbhu.219.fits
# 4386    rbhu.221.fits
# Name: Filename, dtype: object
# HIP7078:
# 302    rasn.233.fits
# Name: Filename, dtype: object
# HIP6917:
# 303     rasn.234.fits
# 1493    rbie.194.fits
# 4421    rbie.195.fits
# 4422    rbie.196.fits
# Name: Filename, dtype: object
# HIP11759:
# 305    raso.251.fits
# Name: Filename, dtype: object
# HIP86032:
# 306     rasp.194.fits
# 1145    rbex.260.fits
# 1146    rbex.262.fits
# 4062    rbex.261.fits
# Name: Filename, dtype: object
# HIP9724:
# 307     rasp.249.fits
# 1538    rbjg.216.fits
# 1539    rbjg.217.fits
# 4468    rbjg.215.fits
# Name: Filename, dtype: object
# HIP14669:
# 309     rasq.261.fits
# 1500    rbie.228.fits
# 4432    rbie.227.fits
# 4433    rbie.229.fits
# Name: Filename, dtype: object
# HIP19655:
# 310    rasq.266.fits
# Name: Filename, dtype: object
# HIP17609:
# 311    rass.306.fits
# Name: Filename, dtype: object
# HIP93871:
# 312     rast.202.fits
# 1215    rbfd.247.fits
# 1216    rbfd.248.fits
# 4130    rbfd.249.fits
# Name: Filename, dtype: object
# HIP86287:
# 313     rast.204.fits
# 1135    rbex.242.fits
# 1136    rbex.244.fits
# 4054    rbex.243.fits
# Name: Filename, dtype: object
# HIP86282:
# 314     rast.206.fits
# 1176    rbez.224.fits
# 1177    rbez.225.fits
# 4088    rbez.226.fits
# Name: Filename, dtype: object
# HIP107556:
# 315     rast.207.fits
# 1361    rbgj.209.fits
# 1362    rbgj.211.fits
# 4276    rbgj.210.fits
# Name: Filename, dtype: object
# HIP116838:
# 316     rast.210.fits
# 1425    rbhh.208.fits
# 1426    rbhh.210.fits
# 2056    rbpi.403.fits
# 2057    rbpi.404.fits
# 2078    rbpj.705.fits
# 4351    rbhh.209.fits
# 4999    rbpi.402.fits
# 5022    rbpj.704.fits
# 5023    rbpj.706.fits
# Name: Filename, dtype: object
# HIP443:
# 317     rast.211.fits
# 1444    rbhr.222.fits
# 1445    rbhr.224.fits
# 1751    rbnn.305.fits
# 1752    rbnn.307.fits
# 1770    rbnp.924.fits
# 1771    rbnp.925.fits
# 1772    rbnp.926.fits
# 4369    rbhr.223.fits
# 4691    rbnk.523.fits
# 4692    rbnk.524.fits
# 4693    rbnk.525.fits
# 4694    rbnk.526.fits
# 4699    rbnn.304.fits
# 4700    rbnn.306.fits
# 4711    rbno.605.fits
# 4712    rbno.606.fits
# 4713    rbno.607.fits
# 4720    rbnp.923.fits
# Name: Filename, dtype: object
# HIP116758:
# 318     rast.212.fits
# 1381    rbgw.243.fits
# 1382    rbgw.245.fits
# 1993    rbow.632.fits
# 1994    rbow.633.fits
# 1995    rbow.634.fits
# 2050    rbpc.829.fits
# 4304    rbgw.244.fits
# 4985    rbpc.827.fits
# 4986    rbpc.828.fits
# Name: Filename, dtype: object
# HIP110750:
# 319     rast.214.fits
# 4279    rbgj.221.fits
# Name: Filename, dtype: object
# HIP27654:
# 320     rast.276.fits
# 3331    rast.273.fits
# 3332    rast.274.fits
# 3333    rast.275.fits
# Name: Filename, dtype: object
# HIP93805:
# 321     rasu.182.fits
# 1213    rbfd.244.fits
# 1214    rbfd.245.fits
# 4129    rbfd.243.fits
# Name: Filename, dtype: object
# HIP13834:
# 322    rasy.139.fits
# Name: Filename, dtype: object
# HIP15197:
# 323     rasy.141.fits
# 1490    rbhv.259.fits
# 4415    rbhv.260.fits
# 4416    rbhv.261.fits
# Name: Filename, dtype: object
# HIP15457:
# 324     rasy.142.fits
# 1486    rbhv.253.fits
# 1860    rboj.151.fits
# 1861    rboj.153.fits
# 1932    rbop.440.fits
# 2001    rbow.669.fits
# 2040    rbpb.438.fits
# 2098    rbpm.763.fits
# 2143    rbps.448.fits
# 2281    rbqt.162.fits
# 2282    rbqt.163.fits
# 2283    rbqt.164.fits
# 4413    rbhv.251.fits
# 4414    rbhv.252.fits
# 4819    rboj.152.fits
# 4898    rbop.439.fits
# 4930    rbow.668.fits
# 4931    rbow.670.fits
# 5073    rbpz.117.fits
# 5074    rbpz.118.fits
# 5154    rbqn.454.fits
# 5322    rbrb.508.fits
# 5437    rbrl.423.fits
# Name: Filename, dtype: object
# HIP15411:
# 325     rasy.146.fits
# 1476    rbhv.234.fits
# 4405    rbhv.233.fits
# 4406    rbhv.235.fits
# Name: Filename, dtype: object
# HIP20641:
# 326    rasy.162.fits
# Name: Filename, dtype: object
# HIP20219:
# 327    rasy.164.fits
# Name: Filename, dtype: object
# HIP20542:
# 328    rasy.165.fits
# Name: Filename, dtype: object
# HIP100064:
# 329     rasz.185.fits
# 761     rayr.225.fits
# 762     rayr.226.fits
# 3700    rayr.224.fits
# Name: Filename, dtype: object
# HIP99572:
# 330     rasz.186.fits
# 946     rbal.210.fits
# 3338    rasz.191.fits
# 3846    rbal.208.fits
# 3847    rbal.209.fits
# Name: Filename, dtype: object
# HIP916:
# 331    rasz.190.fits
# Name: Filename, dtype: object
# HIP99880:
# 332    rasz.196.fits
# 937    rbal.196.fits
# 938    rbal.197.fits
# 939    rbal.198.fits
# Name: Filename, dtype: object
# HIP93873:
# 334     rata.193.fits
# 1218    rbfd.253.fits
# 4133    rbfd.254.fits
# 4134    rbfd.255.fits
# Name: Filename, dtype: object
# HIP1242:
# 335     rata.209.fits
# 1446    rbhr.229.fits
# 1447    rbhr.230.fits
# 1448    rbhr.231.fits
# Name: Filename, dtype: object
# HIP99764:
# 336     ratc.194.fits
# 962     rbam.213.fits
# 963     rbam.214.fits
# 3852    rbam.212.fits
# Name: Filename, dtype: object
# HIP24454:
# 337     ratg.159.fits
# 338     ratg.160.fits
# 3345    ratg.161.fits
# Name: Filename, dtype: object
# HIP34341:
# 339     ratg.167.fits
# 3346    ratg.168.fits
# 3347    ratg.169.fits
# Name: Filename, dtype: object
# HIP34115:
# 340     ratg.171.fits
# 3348    ratg.170.fits
# 3349    ratg.172.fits
# Name: Filename, dtype: object
# HIP24332:
# 341     ratg.208.fits
# 342     ratg.209.fits
# 3350    ratg.210.fits
# Name: Filename, dtype: object
# HIP15220:
# 343     rath.237.fits
# 344     rath.238.fits
# 345     rath.239.fits
# 3344    ratc.241.fits
# Name: Filename, dtype: object
# HIP4454:
# 346     rati.192.fits
# 347     rati.193.fits
# 1492    rbhw.204.fits
# 3351    rati.194.fits
# 4419    rbhw.205.fits
# 4420    rbhw.206.fits
# Name: Filename, dtype: object
# HIP109427:
# 348     rati.195.fits
# 349     rati.197.fits
# 1040    rbck.200.fits
# 1788    rbnv.270.fits
# 1789    rbnv.271.fits
# ...
# 2086    rbpk.122.fits
# 3157    raqb.190.fits
# 5002    rbpi.413.fits
# 5003    rbpi.415.fits
# 5026    rbpj.714.fits
# 5036    rbpk.123.fits
# Name: Filename, dtype: object
# HIP115445:
# 2068    rbpi.438.fits
# 2069    rbpi.439.fits
# 4956    rbox.156.fits
# 4957    rbox.157.fits
# 4958    rbox.158.fits
# 5011    rbpi.440.fits
# Name: Filename, dtype: object
# HIP5247:
# 2070    rbpi.447.fits
# 2071    rbpi.448.fits
# 5012    rbpi.446.fits
# 5031    rbpj.742.fits
# 5032    rbpj.743.fits
# 5033    rbpj.744.fits
# Name: Filename, dtype: object
# HIP4845:
# 2083    rbpj.731.fits
# 2115    rbpo.414.fits
# 2116    rbpo.415.fits
# 2248    rbqr.537.fits
# 2249    rbqr.538.fits
# 5029    rbpj.730.fits
# 5030    rbpj.732.fits
# 5049    rbpo.413.fits
# 5178    rbqr.539.fits
# Name: Filename, dtype: object
# HIP116106:
# 2089    rbpk.132.fits
# 2090    rbpk.134.fits
# 2174    rbqk.410.fits
# 5039    rbpk.133.fits
# 5105    rbqk.411.fits
# Name: Filename, dtype: object
# HIP51459:
# 2108    rbpn.138.fits
# 2197    rbql.683.fits
# 2207    rbqm.144.fits
# 2268    rbqs.884.fits
# 2284    rbqt.173.fits
#             ...
# 5464    rbsj.511.fits
# 5475    rbsk.787.fits
# 5480    rbsm.305.fits
# 5539    rbtz.607.fits
# 5550    rbua.127.fits
# Name: Filename, Length: 64, dtype: object
# HIP4849:
# 2161    rbqb.629.fits
# 2162    rbqb.630.fits
# 2203    rbqm.124.fits
# 2204    rbqm.126.fits
# 2217    rbqn.451.fits
# 5093    rbqb.628.fits
# 5130    rbqm.125.fits
# 5152    rbqn.452.fits
# 5153    rbqn.453.fits
# Name: Filename, dtype: object
# HIP117559:
# 2218    rbqn.455.fits
# 2219    rbqn.456.fits
# 2220    rbqn.457.fits
# Name: Filename, dtype: object
# HIP57757:
# 2289    rbqt.203.fits
# 2290    rbqt.204.fits
# 2291    rbqt.205.fits
# 2305    rbqu.469.fits
# 2306    rbqu.471.fits
# 2345    rbqw.190.fits
# 2409    rbqy.812.fits
# 2410    rbqy.813.fits
# 2411    rbqy.814.fits
# 2433    rbrc.845.fits
# 2463    rbrd.208.fits
# 2464    rbrd.209.fits
# 2538    rbrk.151.fits
# 2539    rbrk.152.fits
# 2540    rbrk.153.fits
# 2556    rbrl.449.fits
# 2564    rbsf.313.fits
# 2565    rbsf.314.fits
# 2566    rbsf.315.fits
# 2576    rbsg.635.fits
# 2589    rbsk.796.fits
# 2594    rbsm.302.fits
# 2595    rbsm.304.fits
# 2614    rbss.534.fits
# 2623    rbsy.419.fits
# 2624    rbsy.420.fits
# 2635    rbta.146.fits
# 2636    rbta.147.fits
# 2637    rbta.148.fits
# 2656    rbtg.494.fits
# 2657    rbtg.496.fits
# 2683    rbua.114.fits
# 3043    ranv.307.fits
# 5221    rbqt.200.fits
# 5236    rbqu.470.fits
# 5252    rbqv.781.fits
# 5266    rbqw.187.fits
# 5267    rbqw.188.fits
# 5268    rbqw.189.fits
# 5334    rbrc.842.fits
# 5335    rbrc.843.fits
# 5336    rbrc.844.fits
# 5366    rbrd.210.fits
# 5367    rbrd.211.fits
# 5426    rbrk.150.fits
# 5439    rbrl.447.fits
# 5440    rbrl.448.fits
# 5466    rbsj.522.fits
# 5467    rbsj.523.fits
# 5468    rbsj.524.fits
# 5479    rbsm.303.fits
# 5493    rbsy.417.fits
# 5494    rbsy.418.fits
# 5515    rbtg.495.fits
# 5546    rbua.115.fits
# 5547    rbua.116.fits
# Name: Filename, dtype: object
# HIP114924:
# 2396    rbqy.766.fits
# 2397    rbqy.767.fits
# 2398    rbqy.768.fits
# 3146    rapz.217.fits
# Name: Filename, dtype: object
# HIP46509:
# 2408    rbqy.807.fits
# 2471    rbrd.224.fits
# 2472    rbrd.225.fits
# 3034    raod.266.fits
# 5220    rbqt.189.fits
# 5371    rbrd.223.fits
# Name: Filename, dtype: object
# HIP11452:
# 2515    rbri.310.fits
# 2516    rbri.311.fits
# 2517    rbri.312.fits
# 2553    rbrl.416.fits
# 2554    rbrl.417.fits
# 3305    rask.264.fits
# 5433    rbrl.418.fits
# Name: Filename, dtype: object
# HIP110774:
# 2696    rbul.511.fits
# 2732    rbuw.482.fits
# 2733    rbuw.484.fits
# 5559    rbul.512.fits
# 5560    rbul.513.fits
# 5603    rbuw.483.fits
# Name: Filename, dtype: object
# HIP59000:
# 2702    rbum.699.fits
# 2703    rbum.700.fits
# 2736    rbva.606.fits
# 5566    rbum.701.fits
# 5608    rbva.605.fits
# 5609    rbva.607.fits
# Name: Filename, dtype: object
# HIP10416:
# 2708    rbun.086.fits
# 3365    rati.246.fits
# 3366    rati.247.fits
# 3367    rati.248.fits
# 5575    rbun.085.fits
# 5576    rbun.087.fits
# 5589    rbup.589.fits
# 5590    rbup.590.fits
# 5591    rbup.591.fits
# Name: Filename, dtype: object
# HIP115562:
# 2715    rbuo.389.fits
# 2716    rbuo.390.fits
# 2719    rbup.592.fits
# 2720    rbup.593.fits
# 5587    rbuo.388.fits
# 5592    rbup.594.fits
# Name: Filename, dtype: object
# HIP117197:
# 2724    rbur.285.fits
# 2725    rbur.286.fits
# 2727    rbut.682.fits
# 2728    rbut.683.fits
# 5596    rbur.287.fits
# 5599    rbut.684.fits
# Name: Filename, dtype: object
# HIP114570:
# 2729    rbuu.082.fits
# 2730    rbuu.084.fits
# 2731    rbuv.282.fits
# 3026    raod.196.fits
# 4341    rbha.228.fits
# 4342    rbha.229.fits
# 4343    rbha.230.fits
# 5600    rbuu.083.fits
# 5601    rbuv.283.fits
# 5602    rbuv.284.fits
# Name: Filename, dtype: object
# HIP114886:
# 2757    rbxl.814.fits
# 5620    rbwx.319.fits
# 5631    rbxl.815.fits
# Name: Filename, dtype: object
# HIP54061:
# 2772    rbxr.285.fits
# 2773    rbxr.286.fits
# 2774    rbxr.287.fits
# 2787    rbyb.697.fits
# 2788    rbyb.699.fits
# 3017    ranr.272.fits
# 5664    rbyb.698.fits
# Name: Filename, dtype: object
# HIP54872:
# 2775    rbxr.288.fits
# 2786    rbyb.695.fits
# 3029    ranu.280.fits
# 5643    rbxr.289.fits
# 5644    rbxr.290.fits
# 5662    rbyb.694.fits
# 5663    rbyb.696.fits
# Name: Filename, dtype: object
# HIP86614:
# 2777    rbxr.299.fits
# 3028    raod.197.fits
# 5647    rbxr.298.fits
# 5648    rbxr.300.fits
# 5657    rbyb.688.fits
# 5658    rbyb.689.fits
# 5659    rbyb.690.fits
# Name: Filename, dtype: object
# HIP53954:
# 2778    rbxs.482.fits
# 5652    rbxs.483.fits
# 5653    rbxs.484.fits
# Name: Filename, dtype: object
# HIP69713:
# 2779    rbxt.690.fits
# 2780    rbxt.691.fits
# 3058    raog.278.fits
# 5654    rbxt.692.fits
# Name: Filename, dtype: object
# HIP77257:
# 2789    rbyh.284.fits
# 3090    rany.301.fits
# 5665    rbyh.283.fits
# 5666    rbyh.285.fits
# Name: Filename, dtype: object
# HIP67275:
# 2790    rbyh.286.fits
# 2791    rbyh.287.fits
# 2792    rbyh.288.fits
# 3006    raob.259.fits
# Name: Filename, dtype: object
# HIP65355:
# 2796    rbyh.292.fits
# 2797    rbyh.293.fits
# 3179    raqo.202.fits
# 5667    rbyh.294.fits
# Name: Filename, dtype: object
# HIP103256:
# 2798    rbyh.307.fits
# 3229    raqz.140.fits
# 5668    rbyh.306.fits
# 5669    rbyh.308.fits
# Name: Filename, dtype: object
# HIP78709:
# 2799    rbyi.482.fits
# 2800    rbyi.484.fits
# 3156    raqb.189.fits
# 5670    rbyi.483.fits
# Name: Filename, dtype: object
# HIP71743:
# 2808    rbyi.500.fits
# 2809    rbyi.501.fits
# 3195    raqs.213.fits
# 5679    rbyi.502.fits
# Name: Filename, dtype: object
# HIP63503:
# 2810    rbyi.503.fits
# 2811    rbyi.505.fits
# 3561    rawt.208.fits
# 3562    rawt.209.fits
# 3563    rawt.210.fits
# 5680    rbyi.504.fits
# Name: Filename, dtype: object
# HIP98792:
# 2814    rbyi.522.fits
# 3173    raqk.222.fits
# 5688    rbyi.520.fits
# 5689    rbyi.521.fits
# Name: Filename, dtype: object
# HIP98767:
# 2815    rbyi.523.fits
# 2816    rbyi.525.fits
# 3122    rapg.233.fits
# 5690    rbyi.524.fits
# Name: Filename, dtype: object
# HIP80008:
# 2831    rbyj.811.fits
# 3095    raox.219.fits
# 3098    raox.279.fits
# 3110    raoy.303.fits
# 5704    rbyj.809.fits
# 5705    rbyj.810.fits
# Name: Filename, dtype: object
# HIP79882:
# 2832    rbyj.814.fits
# 3047    ranv.317.fits
# 3715    rayv.285.fits
# 5706    rbyj.812.fits
# 5707    rbyj.813.fits
# Name: Filename, dtype: object
# HIP72603:
# 2837    rbyk.093.fits
# 2838    rbyk.094.fits
# 3135    rapx.190.fits
# 5710    rbyk.095.fits
# Name: Filename, dtype: object
# HIP63894:
# 2839    rbyk.103.fits
# 3244    rarc.216.fits
# 5717    rbyk.102.fits
# 5718    rbyk.104.fits
# Name: Filename, dtype: object
# HIP63762:
# 2840    rbyk.106.fits
# 3245    rard.211.fits
# 5719    rbyk.105.fits
# 5720    rbyk.107.fits
# Name: Filename, dtype: object
# HIP63608:
# 2844    rbyl.290.fits
# 2845    rbyl.291.fits
# 3000    raob.246.fits
# 3016    raoc.196.fits
# 3038    raod.299.fits
# 5724    rbyl.289.fits
# Name: Filename, dtype: object
# HIP88348:
# 2848    rbyn.683.fits
# 2849    rbyn.684.fits
# 2875    rbyu.285.fits
# 2876    rbyu.286.fits
# 2877    rbyu.287.fits
# 3158    raqb.202.fits
# 5729    rbyn.682.fits
# Name: Filename, dtype: object
# HIP88622:
# 2850    rbyn.686.fits
# 2851    rbyn.687.fits
# 2880    rbyu.296.fits
# 3185    raqq.226.fits
# 5730    rbyn.685.fits
# 5760    rbyu.294.fits
# 5761    rbyu.295.fits
# Name: Filename, dtype: object
# HIP68184:
# 2862    rbyn.709.fits
# 2863    rbyn.711.fits
# 2888    rbyu.318.fits
# 2889    rbyu.319.fits
# 3235    rarb.209.fits
# 5742    rbyn.710.fits
# 5770    rbyv.582.fits
# 5771    rbyv.583.fits
# 5772    rbyv.584.fits
# Name: Filename, dtype: object
# HIP60910:
# 2869    rbyo.096.fits
# 2895    rbyy.288.fits
# 2896    rbyy.289.fits
# 3580    raxd.206.fits
# 3581    raxd.207.fits
# 3582    raxd.208.fits
# 5750    rbyo.094.fits
# 5751    rbyo.095.fits
# 5786    rbyy.290.fits
# Name: Filename, dtype: object
# HIP64577:
# 2878    rbyu.288.fits
# 2879    rbyu.290.fits
# 3129    rapl.193.fits
# 3133    rapn.186.fits
# 5759    rbyu.289.fits
# Name: Filename, dtype: object
# HIP75829:
# 2907    rbze.691.fits
# 2908    rbzf.083.fits
# 3160    raqc.202.fits
# 5801    rbze.692.fits
# 5802    rbzf.082.fits
# 5803    rbzf.084.fits
# Name: Filename, dtype: object
# HIP69732:
# 2909    rbzf.085.fits
# 2910    rbzf.086.fits
# 3012    raob.273.fits
# 5804    rbzf.087.fits
# Name: Filename, dtype: object
# HIP61174:
# 2917    rbzg.282.fits
# 2918    rbzg.283.fits
# 2919    rbzg.284.fits
# 2998    raob.240.fits
# Name: Filename, dtype: object
# HIP76568:
# 2920    rcab.498.fits
# 2921    rcab.499.fits
# 2922    rcab.500.fits
# 3209    raqw.218.fits
# 3222    raqy.218.fits
# Name: Filename, dtype: object
# HIP7513:
# 2984    ranz.163.fits
# Name: Filename, dtype: object
# HIP28614:
# 2988    ranz.165.fits
# Name: Filename, dtype: object
# HIP26366:
# 2990    ranz.166.fits
# Name: Filename, dtype: object
# HIP14632:
# 2994    ranz.168.fits
# Name: Filename, dtype: object
# HIP55705:
# 2996    raob.231.fits
# Name: Filename, dtype: object
# HIP91971:
# 3002    raob.251.fits
# 3797    razs.212.fits
# 3798    razs.213.fits
# 3799    razs.214.fits
# Name: Filename, dtype: object
# HIP88601:
# 3008    raob.268.fits
# 3696    rayr.217.fits
# 3697    rayr.218.fits
# 3698    rayr.219.fits
# Name: Filename, dtype: object
# HIP36850:
# 3013    ranr.237.fits
# Name: Filename, dtype: object
# HIP49669:
# 3015    ranr.262.fits
# Name: Filename, dtype: object
# HIP57632:
# 3019    ranr.288.fits
# Name: Filename, dtype: object
# HIP72659:
# 3020    raoc.201.fits
# Name: Filename, dtype: object
# HIP65378:
# 3021    ranr.296.fits
# Name: Filename, dtype: object
# HIP23497:
# 3030    raod.198.fits
# Name: Filename, dtype: object
# HIP20648:
# 3032    raod.199.fits
# Name: Filename, dtype: object
# HIP27288:
# 3033    ranv.215.fits
# 3035    ranv.230.fits
# Name: Filename, dtype: object
# HIP21594:
# 3040    raoe.183.fits
# 3044    raof.190.fits
# Name: Filename, dtype: object
# HIP11783:
# 3048    raog.191.fits
# 4462    rbjg.209.fits
# 4463    rbjg.210.fits
# 4464    rbjg.211.fits
# Name: Filename, dtype: object
# HIP45336:
# 3052    raog.222.fits
# Name: Filename, dtype: object
# HIP64924:
# 3056    raog.261.fits
# Name: Filename, dtype: object
# HIP67301:
# 3057    ranw.305.fits
# 4229    rbfw.285.fits
# 4230    rbfw.286.fits
# 4231    rbfw.287.fits
# Name: Filename, dtype: object
# HIP18907:
# 3069    ranx.187.fits
# Name: Filename, dtype: object
# HIP79881:
# 3070    raoo.254.fits
# Name: Filename, dtype: object
# HIP31592:
# 3073    ranx.216.fits
# Name: Filename, dtype: object
# HIP36046:
# 3075    ranx.217.fits
# Name: Filename, dtype: object
# HIP27913:
# 3080    rany.191.fits
# Name: Filename, dtype: object
# HIP21402:
# 3082    rany.192.fits
# Name: Filename, dtype: object
# HIP77655:
# 3085    raou.278.fits
# Name: Filename, dtype: object
# HIP77060:
# 3091    raow.191.fits
# 3097    raox.261.fits
# 3109    raoy.280.fits
# Name: Filename, dtype: object
# HIP18975:
# 3093    raox.193.fits
# Name: Filename, dtype: object
# HIP21036:
# 3104    raoy.211.fits
# Name: Filename, dtype: object
# HIP51933:
# 3119    rapg.203.fits
# 3123    raph.201.fits
# Name: Filename, dtype: object
# HIP13665:
# 3142    rapy.208.fits
# 4490    rblj.252.fits
# Name: Filename, dtype: object
# HIP97295:
# 3143    rapy.214.fits
# Name: Filename, dtype: object
# HIP79137:
# 3150    raqa.207.fits
# 3709    rays.194.fits
# 3710    rays.195.fits
# 3711    rays.196.fits
# Name: Filename, dtype: object
# HIP86722:
# 3162    raqc.204.fits
# Name: Filename, dtype: object
# HIP3206:
# 3166    raqf.221.fits
# Name: Filename, dtype: object
# HIP104239:
# 3169    raqi.214.fits
# Name: Filename, dtype: object
# HIP9269:
# 3170    raqi.216.fits
# Name: Filename, dtype: object
# HIP62512:
# 3171    raqk.191.fits
# Name: Filename, dtype: object
# HIP7981:
# 3174    raqk.236.fits
# Name: Filename, dtype: object
# HIP6379:
# 3180    raqo.204.fits
# Name: Filename, dtype: object
# HIP71181:
# 3182    raqq.216.fits
# Name: Filename, dtype: object
# HIP89962:
# 3187    raqq.228.fits
# Name: Filename, dtype: object
# HIP90376:
# 3188    raqq.234.fits
# Name: Filename, dtype: object
# HIP16499:
# 3194    raqr.231.fits
# Name: Filename, dtype: object
# HIP89474:
# 3198    raqt.227.fits
# Name: Filename, dtype: object
# HIP103800:
# 3203    raqt.249.fits
# 3881    rbax.221.fits
# 3882    rbax.222.fits
# 3883    rbax.223.fits
# Name: Filename, dtype: object
# HIP103859:
# 3206    raqu.243.fits
# 3884    rbax.224.fits
# 3885    rbax.225.fits
# 3886    rbax.226.fits
# Name: Filename, dtype: object
# HIP91605:
# 3208    raqv.227.fits
# Name: Filename, dtype: object
# HIP76375:
# 3210    raqw.222.fits
# Name: Filename, dtype: object
# HIP102253:
# 3213    raqw.262.fits
# 3219    raqx.266.fits
# 3224    raqy.257.fits
# Name: Filename, dtype: object
# HIP13081:
# 3226    raqy.271.fits
# Name: Filename, dtype: object
# HIP19255:
# 3230    raqz.146.fits
# Name: Filename, dtype: object
# HIP59504:
# 3234    rara.267.fits
# 4239    rbfw.300.fits
# 4240    rbfw.301.fits
# 4241    rbfw.302.fits
# Name: Filename, dtype: object
# HIP78241:
# 3237    rarb.226.fits
# Name: Filename, dtype: object
# HIP19335:
# 3239    rarb.271.fits
# Name: Filename, dtype: object
# HIP29761:
# 3240    rarb.272.fits
# Name: Filename, dtype: object
# HIP19205:
# 3241    rarb.274.fits
# Name: Filename, dtype: object
# HIP68337:
# 3243    rarc.215.fits
# Name: Filename, dtype: object
# HIP70536:
# 3249    rarj.227.fits
# Name: Filename, dtype: object
# HIP79492:
# 3270    rarp.219.fits
# 3745    razd.206.fits
# 3746    razd.207.fits
# 3747    razd.208.fits
# 3748    razd.209.fits
# Name: Filename, dtype: object
# HIP17147:
# 3288    rasc.239.fits
# 3289    rasc.240.fits
# Name: Filename, dtype: object
# HIP98828:
# 3290    rase.209.fits
# 3849    rbam.194.fits
# 3850    rbam.195.fits
# 3851    rbam.196.fits
# Name: Filename, dtype: object
# HIP19337:
# 3296    rasf.226.fits
# Name: Filename, dtype: object
# HIP106897:
# 3310    rasn.209.fits
# 3908    rbbo.221.fits
# 3909    rbbo.222.fits
# 3910    rbbo.223.fits
# Name: Filename, dtype: object
# HIP3092:
# 3314    raso.211.fits
# 3317    rasp.231.fits
# Name: Filename, dtype: object
# HIP19554:
# 3320    rasp.260.fits
# Name: Filename, dtype: object
# HIP19719:
# 3321    rasp.261.fits
# Name: Filename, dtype: object
# HIP9716:
# 3323    rasq.246.fits
# Name: Filename, dtype: object
# HIP19832:
# 3325    rasr.279.fits
# Name: Filename, dtype: object
# HIP10279:
# 3330    rast.229.fits
# 4465    rbjg.212.fits
# 4466    rbjg.213.fits
# 4467    rbjg.214.fits
# Name: Filename, dtype: object
# HIP20261:
# 3335    rasy.161.fits
# Name: Filename, dtype: object
# HIP20635:
# 3336    rasy.163.fits
# Name: Filename, dtype: object
# HIP24340:
# 3337    rasy.174.fits
# Name: Filename, dtype: object
# HIP28103:
# 3439    raug.284.fits
# 3440    raug.285.fits
# 3441    raug.286.fits
# Name: Filename, dtype: object
# HIP45688:
# 3463    ravj.217.fits
# 3464    ravj.218.fits
# 3465    ravj.219.fits
# Name: Filename, dtype: object
# HIP23179:
# 3523    rawa.194.fits
# 3524    rawa.195.fits
# 3525    rawa.196.fits
# Name: Filename, dtype: object
# HIP22498:
# 3529    rawa.207.fits
# 3530    rawa.208.fits
# 3531    rawa.209.fits
# Name: Filename, dtype: object
# HIP22288:
# 3535    rawb.200.fits
# 3536    rawb.201.fits
# 3537    rawb.202.fits
# Name: Filename, dtype: object
# HIP31703:
# 3544    rawd.184.fits
# Name: Filename, dtype: object
# HIP57328:
# 3549    rawl.232.fits
# 3550    rawl.233.fits
# 3551    rawl.234.fits
# Name: Filename, dtype: object
# HIP52316:
# 3555    rawm.202.fits
# 3556    rawm.203.fits
# 3557    rawm.204.fits
# Name: Filename, dtype: object
# HIP72622:
# 3661    raxv.209.fits
# 3662    raxv.210.fits
# 3663    raxv.211.fits
# Name: Filename, dtype: object
# HIP45343:
# 4726    rbnp.959.fits
# 4759    rbnw.678.fits
# Name: Filename, dtype: object
# HIP120005:
# 4728    rbns.600.fits
# Name: Filename, dtype: object
# HIP109388:
# 5627    rbxh.706.fits
# 5639    rbxq.106.fits
# 5640    rbxq.107.fits
# Name: Filename, dtype: object

# %%
import os
files = os.listdir('/datag/blpd0/datax/apf')

# %%
# check if empty directories
no_files = []
has_files = []
total_num_spectra = 0
for dir_name in os.listdir('./APF_spectra/all_apf_spectra'):
    num_spectra = len(os.listdir('./APF_spectra/all_apf_spectra/' + dir_name))
    if num_spectra < 1:
        no_files += [dir_name]
    if num_spectra >= 1:
        has_files += [dir_name]
    total_num_spectra += num_spectra
        
print(str(len(no_files)) + ' directories are empty.')
print(str(len(has_files)) + ' directories are not empty.')
print(str(total_num_spectra) + ' total spectra files were placed in a subdirectory.')
print('    ' + str(len(raw_files)) + ' files skipped due to being raw.')
print('    ' + str(len(skipped)) + ' files skipped due for some other reason.')
# Out:
# 0 directories are empty.
# 810 directories are not empty.
# 5272 total spectra files were placed in a subdirectory.
#     0 files skipped due to being raw.
#     0 files skipped due for some other reason.

# %%
apf_files = os.listdir('/datag/blpd0/datax/apf')
num_raw = 0
num_reduced = 0
weird_files = []
for file in apf_files:
    if file.startswith('ucb'):
        #apf_files.remove(file)
        num_raw += 1
    if file.startswith('r'):
        num_reduced += 1
    if not file.startswith('ucb') and not file.startswith('r'):
        weird_files += [file]

stars = list(apf_log_file['HIP_name'])
num_no_HIP = stars.count('None')
        
total_apf_files = len(os.listdir('/datag/blpd0/datax/apf'))
print('In BL APF directory (' + str(total_apf_files) + ' total files): ')
print('    ' + str(num_raw) + ' raw files.')
print('    ' + str(num_reduced) + ' reduced files.')
print('    ' + str(len(weird_files)) + ' other files.')

print()
print(str(total_apf_files - total_num_spectra) + ' files were not used.')
print('    ' + str(num_raw) + ' becuase they are raw.')
print('    ' + str(num_no_HIP) + ' becuase they did not return a HIP name.')
# Out:
# In BL APF directory (11750 total files):
#     5877 raw files.
#     5869 reduced files.
#     4 other files.
#
# 6478 files were not used.
#     5877 becuase they are raw.
#     597 becuase they did not return a HIP name.

# %%
weird_files
# Out:
# ['apf_log.txt',
#  'apf_log_current_new.txt',
#  'apf_log_current.txt',
#  'apf_log_current_25mar2019.txt']
