# %%
# inject high intensity signals to verify that we can recover them after they go through SM-Emp 
# in the shifted spectra and the residuals.
# Then should check that they are recovered by the search algorithm, of course.

import numpy as np
import os
import matplotlib.pyplot as plt
from astropy.io import fits
import pandas as pd
import math
from scipy.interpolate import interp1d
from mpmath import mp
mp.dps=100
exp_array = np.frompyfunc(mp.exp, 1, 1)

# %%
# make a directory for the injected spectra -- only run this once
#if not os.path.isdir('/mnt_home/azuckerman/BL_APF_DAP/APF_spectra/injected_spectra'):
#    os.mkdir('/mnt_home/azuckerman/BL_APF_DAP/APF_spectra/injected_spectra')

# %%
# function to insert simulated gaussians
def insert_gaussian(spectrum, gaussian_params, midpoint, numpoints):
    height = gaussian_params[0]
    position = gaussian_params[1] # position within segment, not index in spectrum
    FWHM = gaussian_params[2]
    offset = gaussian_params[3]
    x = np.linspace(0,numpoints-1,numpoints) # numpoints must be odd
    gauss = gaussian(x,height,position,FWHM/(2*np.sqrt(2*np.log(2))),offset)
    new_spect = spectrum
    new_spect[midpoint - math.floor(numpoints/2):midpoint + math.floor(numpoints/2)] = spectrum[midpoint - math.floor(numpoints/2):midpoint + math.floor(numpoints/2)] + gauss
    return new_spect
    
def gaussian(x,a,b,c,d): # a = height, b = position of peak, c = width, x = numpy array of x values
    f = a*exp_array((-(x-b)**2)/(2*c)**2) + d
    return f

# %%
test_stars = ['GJ1002', # -> cool (T ~ 3100K)
              'HIP115562', # -> relatively cool (T ~ 3700K)
              'GJ144', # -> medium temperature (T ~ 5000K)
              'HIP13834'] # -> hot (T ~ 6300K)

star_list = os.listdir('APF_spectra/all_apf_spectra_highest_SNR')[0:300]

heights = [1.5, 2, 3] # times the 98th percentile of order 40


#if not os.path.isdir('APF_spectra/injected_spectra_' + str(height)):
#   os.mkdir('APF_spectra/injected_spectra_' + str(height))
apf_wave = fits.open('apf_wav.fits')
j = 0
injected_peak_photons = np.zeros(len(star_list)*3) # *3 becuase three different inejctions in each star
median_photons_100_pix = np.zeros(len(star_list)*3)
injection_wl = np.zeros(len(star_list)*3)*np.nan
stars = []
if not os.path.isdir('APF_spectra/injected_spectra'):
    os.mkdir('APF_spectra/injected_spectra')
    
for star_name in star_list:
    star = star_name.split('_')[0]
    for m in range(3): stars += [star] # want three entries for this star: one for each injection
    dir_path = 'APF_spectra/all_apf_spectra_highest_SNR/' + star + '_spectra'
    i = 0
    print('Star: ' + star)
    for file in os.listdir(dir_path):
        hdu = fits.open(dir_path + '/' + file)# , mode='update')
        spectrum = np.copy(hdu[0].data)
        color = 'C' + str(i)  
        n = 0
        orders = [39, 40, 41]
        y = hdu[0].data
        for height in heights:
            order = orders[n] # inject the 1.5 hieght into order 39, 2 into order 40, etc
            y_order = y[order]
            h = height - 1 # becuase in the above implementation we add to the baseline, so ie. h = 1 injects a guassian whose peak is at twice the pixels value of the 98th percentile
            print('    file ' + file + ': injecting signal of W = 5, H = ' + str(height) + 
                  '*(98th pct level of order) = ' + str(np.round(height * np.percentile(y_order,98),3)) + ' into order 40.')  
            median_100 = np.median(y_order[int(len(y_order)/2 - 50): int(len(y_order)/2 + 50)])
            y_new = insert_gaussian(y_order, [height*np.percentile(y_order,98), 49, 20, 0], int(len(y_order)/2), 100)
            injection_center_wl = apf_wave[0].data[order][int(len(y_order)/2)]
            print('                     : injecting at center point ' + str(injection_center_wl) + ' A')
            #y[int(len(y)/2)] = 10 * np.percentile(y,99)
            #x = apf_wave[0].data[order]
            #plt.plot(x, y[:-1], '.', c = color)
            #plt.xlim([5553,5557])
            injected_peak_photons[3*j + n] = injected_peak_photons[3*j + n] + height * np.percentile(y_order,98) # sum over each file
            median_photons_100_pix[3*j + n] = median_photons_100_pix[3*j + n] + median_100 # sum over each file
            injection_wl[3*j + n] = injection_center_wl # same for each file (and each star)
            spectrum[order,:] = y_new
            n += 1
        #plt.figure(star + ', ' + file)
        #for order in np.arange(38,43,1):
        #    plt.plot(apf_wave[0].data[order], spectrum[order,:-1])
        #    plt.title(star + ', ' + file)
        i += 1

        new_header = hdu[0].header # get header
        new_header.set('Injected', 'YES','Spectrum contains injected gaussian for testing.')
        data_hdu = fits.PrimaryHDU(spectrum, new_header) 
        hdu_new = fits.HDUList([data_hdu])
        out_path = 'APF_spectra/injected_spectra/'
        if not os.path.isdir(out_path + star + '_spectra/'):
            os.mkdir(out_path + star + '_spectra/')
        #hdu_new.writeto(out_path + star + '_spectra/' + file + '_injected' + '.fits')
        hdu.close()
        
    j += 1

save_injection_key = False
if save_injection_key:
    save_data = list(zip(stars, injection_wl, injected_peak_photons, median_photons_100_pix))
    df = pd.DataFrame(save_data,
              columns = ['Star_name', 'Injection_wavelength', 'Injected_peak_photons', 'Local_median_photons'])
    if os.path.exists('Injection_key_full.csv'):
        df.to_csv('Injection_key_full.csv', mode='a', index = False, header=False)
    else:
        df.to_csv('Injection_key_full.csv', index = False)
# Out:
# Star: HIP109980
#     file rbob.394.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 4880.957 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbob.394.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 6809.051 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbob.394.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 10311.392 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbob.396.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 4800.042 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbob.396.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 6709.871 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbob.396.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 10143.86 into order 40.
#                      : injecting at center point 5622.229264717167 A
# WARNING: VerifyWarning: Card is too long, comment will be truncated. [astropy.io.fits.card]
#     file rbob.395.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 4800.015 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbob.395.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 6735.552 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbob.395.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 10187.105 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP11000
#     file ratn.221.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 11454.764 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratn.221.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 15926.943 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratn.221.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 24145.103 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file ratn.222.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 11723.733 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratn.222.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 16288.98 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratn.222.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 24705.488 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file ratn.223.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 11515.962 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratn.223.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 16026.293 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratn.223.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 24259.299 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP11029
#     file rbjf.220.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 38915.02 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbjf.220.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 52590.176 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbjf.220.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 78701.318 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbjf.221.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 35194.076 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbjf.221.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 47688.975 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbjf.221.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 71310.421 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbjf.219.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 37563.105 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbjf.219.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 50781.837 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbjf.219.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 76119.4 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP110341
#     file rbnv.274.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 47414.863 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbnv.274.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 64333.102 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbnv.274.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 97488.601 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbnv.275.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 41664.72 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbnv.275.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 56437.971 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbnv.275.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 85551.992 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbnv.276.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 42229.127 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbnv.276.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 57147.81 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbnv.276.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 86384.533 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP110395
#     file rbox.086.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 29296.569 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbox.086.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 39080.962 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbox.086.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 58175.876 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbox.088.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 28784.072 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbox.088.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 38422.645 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbox.088.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 57121.98 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbox.089.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 28645.647 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbox.089.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 38221.484 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbox.089.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 56809.039 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbox.087.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 28392.31 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbox.087.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 37917.75 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbox.087.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 56357.269 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbox.085.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 30656.42 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbox.085.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 40959.631 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbox.085.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 60906.969 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP110526
#     file rbxh.701.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 1649.004 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbxh.701.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 2109.999 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbxh.701.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 3215.131 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbxh.702.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 2481.814 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbxh.702.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 3155.559 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbxh.702.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 4852.546 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbxh.700.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 1512.453 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbxh.700.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 1919.8 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbxh.700.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 2957.43 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP110640
#     file ratl.195.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 13830.013 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratl.195.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 19289.827 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratl.195.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 29104.608 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file ratl.193.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 12184.024 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratl.193.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 16890.133 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratl.193.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 25484.104 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file ratl.194.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 12972.728 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratl.194.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 18061.303 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratl.194.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 27247.131 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP110750
#     file rcai.102.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 14801.727 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rcai.102.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 20578.009 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rcai.102.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 31130.559 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rcai.103.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 14733.162 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rcai.103.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 20608.697 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rcai.103.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 31280.077 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rcai.104.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 15027.58 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rcai.104.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 21020.096 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rcai.104.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 31738.614 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP110774
#     file rbul.511.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 4537.148 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbul.511.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 6344.772 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbul.511.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 9601.69 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbul.512.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 5987.825 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbul.512.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 8391.194 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbul.512.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 12657.646 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbul.513.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 6179.593 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbul.513.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 8639.961 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbul.513.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 13091.753 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP110778
#     file rboi.715.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 52763.932 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rboi.715.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 71879.692 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rboi.715.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 108763.388 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rboi.714.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 52888.935 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rboi.714.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 71997.872 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rboi.714.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 108707.562 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP11090
#     file rcbi.129.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 85724.818 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rcbi.129.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 115998.457 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rcbi.129.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 175393.459 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rcbi.130.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 86563.501 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rcbi.130.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 116890.337 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rcbi.130.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 176667.619 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rcbi.131.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 86253.03 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rcbi.131.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 116756.436 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rcbi.131.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 176379.273 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP110951
#     file rask.224.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 3371.115 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rask.224.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 4779.308 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rask.224.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 7124.466 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP111169
#     file rbox.101.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 51964.085 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbox.101.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 69245.586 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbox.101.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 103148.719 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbox.097.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 50320.794 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbox.097.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 67124.551 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbox.097.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 99942.237 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbox.100.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 51590.474 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbox.100.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 68827.033 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbox.100.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 102548.996 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbox.098.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 51193.145 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbox.098.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 68220.66 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbox.098.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 101691.738 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbox.099.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 51456.425 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbox.099.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 68679.441 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbox.099.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 102208.125 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP111170
#     file rboc.702.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 44958.689 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rboc.702.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 61207.124 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rboc.702.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 92871.46 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rboc.703.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 45229.269 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rboc.703.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 61554.51 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rboc.703.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 93325.59 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rboc.701.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 46036.488 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rboc.701.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 62664.884 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rboc.701.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 95070.701 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP111313
#     file rbgm.225.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 5026.332 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbgm.225.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 6933.665 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbgm.225.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 10433.435 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbgm.226.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 5025.235 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbgm.226.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 6978.168 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbgm.226.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 10442.59 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbgm.224.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 4945.501 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbgm.224.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 6815.256 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbgm.224.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 10256.262 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP111685
#     file rase.243.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 16608.4 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rase.243.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 23405.02 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rase.243.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 34776.483 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP112190
#     file rboc.716.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 12044.053 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rboc.716.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 16603.207 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rboc.716.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 25170.562 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rboc.718.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 11966.712 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rboc.718.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 16504.81 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rboc.718.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 24950.631 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rboc.717.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 12110.391 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rboc.717.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 16680.055 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rboc.717.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 25337.59 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP112245
#     file raqr.214.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 59658.69 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file raqr.214.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 81804.002 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file raqr.214.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 124490.64 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP112496
#     file rcam.101.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 23659.425 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rcam.101.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 32873.119 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rcam.101.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 49971.244 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rcam.102.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 22823.505 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rcam.102.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 31677.437 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rcam.102.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 48124.009 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rcam.103.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 23352.867 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rcam.103.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 32359.082 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rcam.103.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 49201.27 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP112527
#     file raqq.219.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 64721.057 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file raqq.219.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 89164.395 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file raqq.219.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 135436.664 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP112724
#     file rbon.887.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 56077.421 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbon.887.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 77161.821 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbon.887.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 118316.388 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbon.888.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 54463.437 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbon.888.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 75065.483 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbon.888.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 115038.5 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbon.889.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 54739.676 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbon.889.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 75294.838 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbon.889.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 115230.433 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbon.890.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 51356.008 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbon.890.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 70701.849 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbon.890.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 108381.018 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbon.885.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 46957.578 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbon.885.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 64539.388 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbon.885.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 98982.974 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbon.886.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 54321.86 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbon.886.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 74753.784 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbon.886.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 114685.85 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP112748
#     file rbon.871.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 49482.278 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbon.871.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 68046.442 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbon.871.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 104090.6 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbon.867.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 50296.013 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbon.867.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 69063.61 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbon.867.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 105859.654 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbon.869.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 51147.91 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbon.869.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 70230.641 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbon.869.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 107465.155 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbon.870.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 46871.658 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbon.870.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 64489.086 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbon.870.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 98660.454 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbon.872.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 49980.429 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbon.872.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 68698.686 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbon.872.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 105191.882 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbon.868.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 52970.6 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbon.868.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 72817.322 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbon.868.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 111498.384 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP112774
#     file rbgz.206.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 3040.455 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbgz.206.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 4259.651 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbgz.206.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 6421.014 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbgz.207.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 3035.039 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbgz.207.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 4306.071 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbgz.207.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 6403.855 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbgz.210.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 2968.164 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbgz.210.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 4174.848 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbgz.210.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 6253.406 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbgz.211.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 3267.87 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbgz.211.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 4584.235 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbgz.211.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 6869.217 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbgz.212.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 3064.365 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbgz.212.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 4330.492 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbgz.212.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 6482.229 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbgz.205.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 2811.581 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbgz.205.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 3943.764 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbgz.205.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 5925.399 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP112870
#     file rboc.733.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 10961.728 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rboc.733.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 15091.557 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rboc.733.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 22973.543 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rboc.736.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 11011.055 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rboc.736.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 15197.358 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rboc.736.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 23138.424 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rboc.737.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 10778.832 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rboc.737.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 14884.09 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rboc.737.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 22613.491 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rboc.738.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 10571.685 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rboc.738.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 14551.403 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rboc.738.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 22119.798 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rboc.734.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 10297.021 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rboc.734.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 14192.031 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rboc.734.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 21654.384 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP112909
#     file rbxp.702.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 1610.73 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbxp.702.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 2049.254 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbxp.702.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 3116.148 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbxp.703.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 1708.089 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbxp.703.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 2195.465 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbxp.703.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 3330.817 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbxp.701.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 1235.42 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbxp.701.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 1598.399 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbxp.701.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 2433.741 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP112915
#     file ratu.230.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 20100.878 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratu.230.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 27869.769 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratu.230.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 42204.026 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file ratu.231.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 19131.49 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratu.231.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 26499.667 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratu.231.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 40062.999 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file ratu.232.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 16743.343 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratu.232.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 23199.213 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratu.232.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 35133.819 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP112918
#     file rboc.731.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 3292.39 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rboc.731.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 4620.399 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rboc.731.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 6943.236 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rboc.729.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 3196.446 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rboc.729.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 4478.795 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rboc.729.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 6769.243 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rboc.730.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 3284.408 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rboc.730.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 4590.9 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rboc.730.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 6919.961 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP112935
#     file rbcj.205.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 49014.104 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbcj.205.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 66386.323 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbcj.205.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 100491.649 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbcj.206.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 51338.348 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbcj.206.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 69467.426 into order 40.
# ...
#                      : injecting at center point 5555.36527738973 A
#     file ravd.208.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 97008.297 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file ravd.210.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 45712.686 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ravd.210.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 61236.032 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ravd.210.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 92353.8 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file ravd.209.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 46222.234 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ravd.209.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 61900.77 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ravd.209.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 93341.74 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP23497
#     file raod.198.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 37599.514 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file raod.198.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 50370.432 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file raod.198.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 75461.777 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP23783
#     file rapa.194.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 62117.553 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rapa.194.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 83821.714 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rapa.194.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 126408.332 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP23875
#     file ranu.194.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 57958.136 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ranu.194.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 77788.21 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ranu.194.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 115752.734 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP23941
#     file ravz.202.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 24310.336 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ravz.202.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 33008.795 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ravz.202.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 49894.748 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file ravz.203.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 25629.096 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ravz.203.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 34809.681 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ravz.203.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 52727.036 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file ravz.204.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 22534.894 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ravz.204.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 30573.026 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ravz.204.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 46320.808 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP24332
#     file ratg.209.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 29276.837 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratg.209.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 39704.11 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratg.209.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 60147.006 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file ratg.210.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 29327.73 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratg.210.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 39767.325 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratg.210.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 60297.767 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file ratg.208.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 29254.907 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratg.208.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 39599.399 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratg.208.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 60112.904 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP24340
#     file rasy.174.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 72197.39 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rasy.174.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 96510.871 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rasy.174.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 143850.292 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP24454
#     file ratg.159.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 3258.163 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratg.159.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 4594.419 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratg.159.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 6970.035 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file ratg.160.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 3923.694 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratg.160.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 5511.28 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratg.160.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 8332.432 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file ratg.161.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 4285.965 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratg.161.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 6023.499 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratg.161.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 9120.525 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP24874
#     file rawb.194.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 9937.944 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rawb.194.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 13788.28 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rawb.194.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 20956.692 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rawb.195.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 9515.6 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rawb.195.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 13199.53 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rawb.195.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 19968.214 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rawb.196.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 9207.004 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rawb.196.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 12748.373 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rawb.196.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 19360.942 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP25110
#     file rbdp.186.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 56982.247 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbdp.186.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 76933.783 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbdp.186.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 116589.094 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbdp.187.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 62163.283 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbdp.187.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 83909.579 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbdp.187.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 126865.885 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbdp.188.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 60493.852 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbdp.188.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 81632.969 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbdp.188.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 123595.338 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP25278
#     file rbdp.190.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 62065.79 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbdp.190.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 84224.767 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbdp.190.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 127568.429 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbdp.189.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 61929.701 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbdp.189.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 83869.616 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbdp.189.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 127319.686 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbdp.191.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 62233.343 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbdp.191.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 84290.413 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbdp.191.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 127785.386 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP25486
#     file rbac.282.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 23574.447 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbac.282.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 32200.471 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbac.282.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 48502.666 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbac.322.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 36937.902 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbac.322.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 50218.418 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbac.322.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 75808.224 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP2552
#     file ratl.198.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 3369.072 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratl.198.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 4480.918 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratl.198.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 6938.199 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file ratl.200.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 3388.01 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratl.200.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 4512.119 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratl.200.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 7001.899 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file ratl.199.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 3259.841 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ratl.199.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 4340.361 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ratl.199.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 6734.439 into order 40.
#                      : injecting at center point 5622.229264717167 A

# %%
# how to inject into somewhere other than the peak of the blaze function 
star_list = os.listdir('APF_spectra/all_apf_spectra_highest_SNR')[300:600]

heights = [1.5, 2, 3] # times the 98th percentile of order 40


#if not os.path.isdir('APF_spectra/injected_spectra_' + str(height)):
#   os.mkdir('APF_spectra/injected_spectra_' + str(height))
apf_wave = fits.open('apf_wav.fits')
j = 0
injected_peak_photons = np.zeros(len(star_list)*3) # *3 becuase three different inejctions in each star
median_photons_100_pix = np.zeros(len(star_list)*3)
injection_wl = np.zeros(len(star_list)*3)*np.nan
stars = []
if not os.path.isdir('APF_spectra/injected_spectra'):
    os.mkdir('APF_spectra/injected_spectra')
    
for star_name in star_list:
    star = star_name.split('_')[0]
    for m in range(3): stars += [star] # want three entries for this star: one for each injection
    dir_path = 'APF_spectra/all_apf_spectra_highest_SNR/' + star + '_spectra'
    i = 0
    print('Star: ' + star)
    for file in os.listdir(dir_path):
        hdu = fits.open(dir_path + '/' + file)# , mode='update')
        spectrum = np.copy(hdu[0].data)
        color = 'C' + str(i)  
        n = 0
        orders = [39, 40, 41]
        y = hdu[0].data
        for height in heights:
            # Inject into the first of the overlapping orders
            order = orders[n] # inject the 1.5 hieght into order 39, 2 into order 40, etc
            frac = 5
            y_order = y[order]
            injection_center_wl = apf_wave[0].data[order][int(len(y_order)/frac)] # deliberately inject into the order edge (overlapping region)
            h = height - 1 # becuase in the above implementation we add to the baseline, so ie. h = 1 injects a guassian whose peak is at twice the pixels value of the 98th percentile  
            # is this close to ok near edges??
            median_100 = np.median(y_order[int(len(y_order)/frac - 50): int(len(y_order)/frac + 50)])
            second_order = order - 1
            y_second_order = y[second_order] 
            second_median_100 = np.median(y_second_order[int(len(y_second_order)/frac - 50): int(len(y_order)/frac + 50)]) 
            combined_median_100 = median_100 + second_median_100
            num_photons = height * combined_median_100
            y_new = insert_gaussian(y_order, [num_photons, 49, 20, 0], int(len(y_order)/frac), 100)
            print('    file ' + file + ': injecting signal of W = 5, H = ' + str(height) + 
                  '*(local median) = ' + str(np.round(num_photons,3)) + '. ')
            print('                     : injecting at center point ' + str(injection_center_wl) + ' A, order ' + str(order))
            
            # Inject into the second of the overlapping orders

            #second_y_new = insert_gaussian(y_second_order, [height*np.percentile(y_second_order,98), 49, 20, 0], int(len(y_second_order)/frac), 100)
            #print('                     : injecting at center point ' + str(injection_center_wl) + ' A ' + str(second_order))
            
            #y[int(len(y)/2)] = 10 * np.percentile(y,99)
            #x = apf_wave[0].data[order]
            #plt.plot(x, y[:-1], '.', c = color)
            #plt.xlim([5553,5557])
            injected_peak_photons[3*j + n] = injected_peak_photons[3*j + n] + height * combined_median_100 # sum over each file
            median_photons_100_pix[3*j + n] = median_photons_100_pix[3*j + n] + combined_median_100 # sum over each file
            injection_wl[3*j + n] = injection_center_wl # same for each file (and each star)
            spectrum[order,:] = y_new
            n += 1
        #plt.figure()
        #for order in np.arange(38,43,1):
        #    plt.plot(apf_wave[0].data[order], spectrum[order,:-1])
        #    plt.title(star + ', ' + file)
        i += 1

        new_header = hdu[0].header # get header
        new_header.set('Injected', 'YES','Spectrum contains injected gaussian for testing.')
        data_hdu = fits.PrimaryHDU(spectrum, new_header) 
        hdu_new = fits.HDUList([data_hdu])
        out_path = 'APF_spectra/injected_spectra_order_edges/'
        if not os.path.isdir(out_path + star + '_spectra/'):
            os.mkdir(out_path + star + '_spectra/')
        #hdu_new.writeto(out_path + star + '_spectra/' + file + '_injected' + '.fits')
        hdu.close()
        
    j += 1

save_injection_key = True
if save_injection_key:
    save_data = list(zip(stars, injection_wl, injected_peak_photons, median_photons_100_pix))
    df = pd.DataFrame(save_data,
              columns = ['Star_name', 'Injection_wavelength', 'Injected_peak_photons', 'Local_median_photons'])
    if os.path.exists('Injection_key_full.csv'):
        df.to_csv('Injection_key_full.csv', mode = 'a', index = False, header = False)
    else:
        df.to_csv('Injection_key_full.csv', index = False)
# Out:
# Star: HIP25878
#     file rbnp.951.fits: injecting signal of W = 5, H = 1.5*(local median) = 10227.092.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbnp.951.fits: injecting signal of W = 5, H = 2*(local median) = 18960.688.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbnp.951.fits: injecting signal of W = 5, H = 3*(local median) = 35803.852.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbnp.952.fits: injecting signal of W = 5, H = 1.5*(local median) = 11148.643.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbnp.952.fits: injecting signal of W = 5, H = 2*(local median) = 20782.051.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbnp.952.fits: injecting signal of W = 5, H = 3*(local median) = 38926.515.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbnp.950.fits: injecting signal of W = 5, H = 1.5*(local median) = 9160.914.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbnp.950.fits: injecting signal of W = 5, H = 2*(local median) = 17129.396.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbnp.950.fits: injecting signal of W = 5, H = 3*(local median) = 32281.978.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP26366
#     file ranz.166.fits: injecting signal of W = 5, H = 1.5*(local median) = 51772.23.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ranz.166.fits: injecting signal of W = 5, H = 2*(local median) = 82679.992.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ranz.166.fits: injecting signal of W = 5, H = 3*(local median) = 138131.871.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP26563
#     file raog.189.fits: injecting signal of W = 5, H = 1.5*(local median) = 36294.501.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raog.189.fits: injecting signal of W = 5, H = 2*(local median) = 57499.723.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raog.189.fits: injecting signal of W = 5, H = 3*(local median) = 93907.799.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP26624
#     file ravy.188.fits: injecting signal of W = 5, H = 1.5*(local median) = 65561.783.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravy.188.fits: injecting signal of W = 5, H = 2*(local median) = 104514.742.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravy.188.fits: injecting signal of W = 5, H = 3*(local median) = 172632.27.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravy.189.fits: injecting signal of W = 5, H = 1.5*(local median) = 64123.312.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravy.189.fits: injecting signal of W = 5, H = 2*(local median) = 102434.141.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravy.189.fits: injecting signal of W = 5, H = 3*(local median) = 169459.289.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravy.190.fits: injecting signal of W = 5, H = 1.5*(local median) = 66005.754.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravy.190.fits: injecting signal of W = 5, H = 2*(local median) = 105171.266.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravy.190.fits: injecting signal of W = 5, H = 3*(local median) = 173808.445.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP27288
#     file ranv.215.fits: injecting signal of W = 5, H = 1.5*(local median) = 60950.344.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ranv.215.fits: injecting signal of W = 5, H = 2*(local median) = 96430.992.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ranv.215.fits: injecting signal of W = 5, H = 3*(local median) = 158252.742.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ranv.230.fits: injecting signal of W = 5, H = 1.5*(local median) = 63187.775.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ranv.230.fits: injecting signal of W = 5, H = 2*(local median) = 99535.844.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ranv.230.fits: injecting signal of W = 5, H = 3*(local median) = 163650.879.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP2762
#     file rbhu.223.fits: injecting signal of W = 5, H = 1.5*(local median) = 68445.785.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbhu.223.fits: injecting signal of W = 5, H = 2*(local median) = 109650.781.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbhu.223.fits: injecting signal of W = 5, H = 3*(local median) = 181497.387.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbhu.222.fits: injecting signal of W = 5, H = 1.5*(local median) = 67104.492.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbhu.222.fits: injecting signal of W = 5, H = 2*(local median) = 107832.398.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbhu.222.fits: injecting signal of W = 5, H = 3*(local median) = 178292.602.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbhu.224.fits: injecting signal of W = 5, H = 1.5*(local median) = 66712.764.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbhu.224.fits: injecting signal of W = 5, H = 2*(local median) = 107672.406.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbhu.224.fits: injecting signal of W = 5, H = 3*(local median) = 176325.727.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP27654
#     file rast.276.fits: injecting signal of W = 5, H = 1.5*(local median) = 97532.795.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rast.276.fits: injecting signal of W = 5, H = 2*(local median) = 157796.0.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rast.276.fits: injecting signal of W = 5, H = 3*(local median) = 261190.242.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rast.273.fits: injecting signal of W = 5, H = 1.5*(local median) = 85876.471.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rast.273.fits: injecting signal of W = 5, H = 2*(local median) = 139309.156.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rast.273.fits: injecting signal of W = 5, H = 3*(local median) = 231154.547.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rast.274.fits: injecting signal of W = 5, H = 1.5*(local median) = 105116.766.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rast.274.fits: injecting signal of W = 5, H = 2*(local median) = 170709.438.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rast.274.fits: injecting signal of W = 5, H = 3*(local median) = 282085.969.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rast.275.fits: injecting signal of W = 5, H = 1.5*(local median) = 87162.41.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rast.275.fits: injecting signal of W = 5, H = 2*(local median) = 141398.5.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rast.275.fits: injecting signal of W = 5, H = 3*(local median) = 234229.594.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP27913
#     file rany.191.fits: injecting signal of W = 5, H = 1.5*(local median) = 84835.576.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rany.191.fits: injecting signal of W = 5, H = 2*(local median) = 136929.656.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rany.191.fits: injecting signal of W = 5, H = 3*(local median) = 221146.312.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP27922
#     file rauh.265.fits: injecting signal of W = 5, H = 1.5*(local median) = 21419.49.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rauh.265.fits: injecting signal of W = 5, H = 2*(local median) = 35069.625.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rauh.265.fits: injecting signal of W = 5, H = 3*(local median) = 58540.98.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rauh.263.fits: injecting signal of W = 5, H = 1.5*(local median) = 24755.684.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rauh.263.fits: injecting signal of W = 5, H = 2*(local median) = 40255.348.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rauh.263.fits: injecting signal of W = 5, H = 3*(local median) = 67594.424.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rauh.264.fits: injecting signal of W = 5, H = 1.5*(local median) = 23295.042.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rauh.264.fits: injecting signal of W = 5, H = 2*(local median) = 37988.137.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rauh.264.fits: injecting signal of W = 5, H = 3*(local median) = 63464.912.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP28103
#     file raug.284.fits: injecting signal of W = 5, H = 1.5*(local median) = 73378.57.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raug.284.fits: injecting signal of W = 5, H = 2*(local median) = 117860.023.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raug.284.fits: injecting signal of W = 5, H = 3*(local median) = 195338.297.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file raug.285.fits: injecting signal of W = 5, H = 1.5*(local median) = 70595.496.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raug.285.fits: injecting signal of W = 5, H = 2*(local median) = 113311.906.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raug.285.fits: injecting signal of W = 5, H = 3*(local median) = 186903.117.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file raug.286.fits: injecting signal of W = 5, H = 1.5*(local median) = 69570.393.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raug.286.fits: injecting signal of W = 5, H = 2*(local median) = 111994.031.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raug.286.fits: injecting signal of W = 5, H = 3*(local median) = 184699.816.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP28368
#     file ravx.200.fits: injecting signal of W = 5, H = 1.5*(local median) = 1027.107.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravx.200.fits: injecting signal of W = 5, H = 2*(local median) = 1778.946.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravx.200.fits: injecting signal of W = 5, H = 3*(local median) = 3081.643.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravx.201.fits: injecting signal of W = 5, H = 1.5*(local median) = 1191.249.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravx.201.fits: injecting signal of W = 5, H = 2*(local median) = 2096.687.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravx.201.fits: injecting signal of W = 5, H = 3*(local median) = 3688.644.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravx.202.fits: injecting signal of W = 5, H = 1.5*(local median) = 1180.43.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravx.202.fits: injecting signal of W = 5, H = 2*(local median) = 2089.207.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravx.202.fits: injecting signal of W = 5, H = 3*(local median) = 3544.907.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP28614
#     file ranz.165.fits: injecting signal of W = 5, H = 1.5*(local median) = 65332.646.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ranz.165.fits: injecting signal of W = 5, H = 2*(local median) = 104254.375.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ranz.165.fits: injecting signal of W = 5, H = 3*(local median) = 170069.473.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP29277
#     file rcdr.591.fits: injecting signal of W = 5, H = 1.5*(local median) = 3369.345.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rcdr.591.fits: injecting signal of W = 5, H = 2*(local median) = 5830.242.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rcdr.591.fits: injecting signal of W = 5, H = 3*(local median) = 10658.821.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rcdr.592.fits: injecting signal of W = 5, H = 1.5*(local median) = 3817.524.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rcdr.592.fits: injecting signal of W = 5, H = 2*(local median) = 6581.266.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rcdr.592.fits: injecting signal of W = 5, H = 3*(local median) = 12111.533.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rcdr.593.fits: injecting signal of W = 5, H = 1.5*(local median) = 4377.019.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rcdr.593.fits: injecting signal of W = 5, H = 2*(local median) = 7525.91.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rcdr.593.fits: injecting signal of W = 5, H = 3*(local median) = 14172.308.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP29650
#     file raub.230.fits: injecting signal of W = 5, H = 1.5*(local median) = 27060.527.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raub.230.fits: injecting signal of W = 5, H = 2*(local median) = 43048.781.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raub.230.fits: injecting signal of W = 5, H = 3*(local median) = 71558.842.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file raub.232.fits: injecting signal of W = 5, H = 1.5*(local median) = 38403.571.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raub.232.fits: injecting signal of W = 5, H = 2*(local median) = 60902.18.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raub.232.fits: injecting signal of W = 5, H = 3*(local median) = 101814.445.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file raub.231.fits: injecting signal of W = 5, H = 1.5*(local median) = 24786.762.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raub.231.fits: injecting signal of W = 5, H = 2*(local median) = 39317.762.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raub.231.fits: injecting signal of W = 5, H = 3*(local median) = 65064.281.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP29761
#     file rcbp.094.fits: injecting signal of W = 5, H = 1.5*(local median) = 21036.05.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rcbp.094.fits: injecting signal of W = 5, H = 2*(local median) = 35720.363.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rcbp.094.fits: injecting signal of W = 5, H = 3*(local median) = 59978.086.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rcbp.095.fits: injecting signal of W = 5, H = 1.5*(local median) = 20468.851.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rcbp.095.fits: injecting signal of W = 5, H = 2*(local median) = 34626.453.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rcbp.095.fits: injecting signal of W = 5, H = 3*(local median) = 57889.77.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rcbp.096.fits: injecting signal of W = 5, H = 1.5*(local median) = 44051.93.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rcbp.096.fits: injecting signal of W = 5, H = 2*(local median) = 74079.766.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rcbp.096.fits: injecting signal of W = 5, H = 3*(local median) = 124205.543.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP29800
#     file ravd.219.fits: injecting signal of W = 5, H = 1.5*(local median) = 29278.57.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravd.219.fits: injecting signal of W = 5, H = 2*(local median) = 46828.75.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravd.219.fits: injecting signal of W = 5, H = 3*(local median) = 76929.486.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravd.218.fits: injecting signal of W = 5, H = 1.5*(local median) = 31004.83.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravd.218.fits: injecting signal of W = 5, H = 2*(local median) = 49595.016.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravd.218.fits: injecting signal of W = 5, H = 3*(local median) = 81421.559.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravd.217.fits: injecting signal of W = 5, H = 1.5*(local median) = 38242.482.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravd.217.fits: injecting signal of W = 5, H = 2*(local median) = 61365.988.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravd.217.fits: injecting signal of W = 5, H = 3*(local median) = 100851.586.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP29860
#     file ravd.223.fits: injecting signal of W = 5, H = 1.5*(local median) = 24343.515.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravd.223.fits: injecting signal of W = 5, H = 2*(local median) = 38918.297.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravd.223.fits: injecting signal of W = 5, H = 3*(local median) = 65397.188.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravd.224.fits: injecting signal of W = 5, H = 1.5*(local median) = 22888.595.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravd.224.fits: injecting signal of W = 5, H = 2*(local median) = 36577.414.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravd.224.fits: injecting signal of W = 5, H = 3*(local median) = 61247.812.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravd.225.fits: injecting signal of W = 5, H = 1.5*(local median) = 27228.923.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravd.225.fits: injecting signal of W = 5, H = 2*(local median) = 43534.508.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravd.225.fits: injecting signal of W = 5, H = 3*(local median) = 73190.449.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP2
#     file rbhp.210.fits: injecting signal of W = 5, H = 1.5*(local median) = 6824.111.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbhp.210.fits: injecting signal of W = 5, H = 2*(local median) = 11454.905.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbhp.210.fits: injecting signal of W = 5, H = 3*(local median) = 19631.599.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbhp.211.fits: injecting signal of W = 5, H = 1.5*(local median) = 6567.806.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbhp.211.fits: injecting signal of W = 5, H = 2*(local median) = 11084.721.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbhp.211.fits: injecting signal of W = 5, H = 3*(local median) = 18851.145.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbhp.212.fits: injecting signal of W = 5, H = 1.5*(local median) = 6815.915.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbhp.212.fits: injecting signal of W = 5, H = 2*(local median) = 11870.27.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbhp.212.fits: injecting signal of W = 5, H = 3*(local median) = 19726.006.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP30060
#     file ravu.204.fits: injecting signal of W = 5, H = 1.5*(local median) = 61830.703.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravu.204.fits: injecting signal of W = 5, H = 2*(local median) = 97336.68.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravu.204.fits: injecting signal of W = 5, H = 3*(local median) = 159421.512.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravu.205.fits: injecting signal of W = 5, H = 1.5*(local median) = 57111.908.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravu.205.fits: injecting signal of W = 5, H = 2*(local median) = 89955.555.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravu.205.fits: injecting signal of W = 5, H = 3*(local median) = 147776.426.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravu.206.fits: injecting signal of W = 5, H = 1.5*(local median) = 59919.006.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravu.206.fits: injecting signal of W = 5, H = 2*(local median) = 93969.0.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravu.206.fits: injecting signal of W = 5, H = 3*(local median) = 154380.82.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP30112
#     file ravt.198.fits: injecting signal of W = 5, H = 1.5*(local median) = 4476.135.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravt.198.fits: injecting signal of W = 5, H = 2*(local median) = 7882.168.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravt.198.fits: injecting signal of W = 5, H = 3*(local median) = 12666.699.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravt.197.fits: injecting signal of W = 5, H = 1.5*(local median) = 4366.626.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravt.197.fits: injecting signal of W = 5, H = 2*(local median) = 7647.242.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravt.197.fits: injecting signal of W = 5, H = 3*(local median) = 12503.619.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravt.196.fits: injecting signal of W = 5, H = 1.5*(local median) = 4299.156.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravt.196.fits: injecting signal of W = 5, H = 2*(local median) = 7708.783.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravt.196.fits: injecting signal of W = 5, H = 3*(local median) = 12417.256.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP30419
#     file rany.200.fits: injecting signal of W = 5, H = 1.5*(local median) = 90455.859.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rany.200.fits: injecting signal of W = 5, H = 2*(local median) = 144595.219.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rany.200.fits: injecting signal of W = 5, H = 3*(local median) = 237193.875.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP30630
#     file ravt.216.fits: injecting signal of W = 5, H = 1.5*(local median) = 41671.333.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravt.216.fits: injecting signal of W = 5, H = 2*(local median) = 70122.812.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravt.216.fits: injecting signal of W = 5, H = 3*(local median) = 115117.898.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravt.215.fits: injecting signal of W = 5, H = 1.5*(local median) = 42142.383.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravt.215.fits: injecting signal of W = 5, H = 2*(local median) = 71241.539.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravt.215.fits: injecting signal of W = 5, H = 3*(local median) = 116980.266.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravt.217.fits: injecting signal of W = 5, H = 1.5*(local median) = 41766.973.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravt.217.fits: injecting signal of W = 5, H = 2*(local median) = 70440.797.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravt.217.fits: injecting signal of W = 5, H = 3*(local median) = 115863.469.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP30756
#     file ravt.195.fits: injecting signal of W = 5, H = 1.5*(local median) = 16630.315.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravt.195.fits: injecting signal of W = 5, H = 2*(local median) = 27941.889.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravt.195.fits: injecting signal of W = 5, H = 3*(local median) = 47856.0.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravt.193.fits: injecting signal of W = 5, H = 1.5*(local median) = 17186.106.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravt.193.fits: injecting signal of W = 5, H = 2*(local median) = 28573.381.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravt.193.fits: injecting signal of W = 5, H = 3*(local median) = 48949.022.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravt.194.fits: injecting signal of W = 5, H = 1.5*(local median) = 17174.578.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravt.194.fits: injecting signal of W = 5, H = 2*(local median) = 28770.943.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravt.194.fits: injecting signal of W = 5, H = 3*(local median) = 49249.945.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP3092
#     file raso.211.fits: injecting signal of W = 5, H = 1.5*(local median) = 53987.977.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raso.211.fits: injecting signal of W = 5, H = 2*(local median) = 103502.016.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raso.211.fits: injecting signal of W = 5, H = 3*(local median) = 168494.191.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP31592
#     file ranx.216.fits: injecting signal of W = 5, H = 1.5*(local median) = 3028.627.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ranx.216.fits: injecting signal of W = 5, H = 2*(local median) = 4895.257.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ranx.216.fits: injecting signal of W = 5, H = 3*(local median) = 8554.764.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP31635
#     file ravu.219.fits: injecting signal of W = 5, H = 1.5*(local median) = 4290.184.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravu.219.fits: injecting signal of W = 5, H = 2*(local median) = 8160.84.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravu.219.fits: injecting signal of W = 5, H = 3*(local median) = 14019.335.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravu.220.fits: injecting signal of W = 5, H = 1.5*(local median) = 4118.709.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravu.220.fits: injecting signal of W = 5, H = 2*(local median) = 7833.683.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravu.220.fits: injecting signal of W = 5, H = 3*(local median) = 13844.927.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravu.221.fits: injecting signal of W = 5, H = 1.5*(local median) = 4090.861.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravu.221.fits: injecting signal of W = 5, H = 2*(local median) = 7842.306.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravu.221.fits: injecting signal of W = 5, H = 3*(local median) = 13612.351.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP31703
#     file rawd.184.fits: injecting signal of W = 5, H = 1.5*(local median) = 1119.545.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rawd.184.fits: injecting signal of W = 5, H = 2*(local median) = 1830.89.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rawd.184.fits: injecting signal of W = 5, H = 3*(local median) = 3059.026.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP3206
#     file raqf.221.fits: injecting signal of W = 5, H = 1.5*(local median) = 45301.488.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raqf.221.fits: injecting signal of W = 5, H = 2*(local median) = 76018.492.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raqf.221.fits: injecting signal of W = 5, H = 3*(local median) = 127984.828.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP32439
#     file raoy.325.fits: injecting signal of W = 5, H = 1.5*(local median) = 97212.832.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raoy.325.fits: injecting signal of W = 5, H = 2*(local median) = 156633.094.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raoy.325.fits: injecting signal of W = 5, H = 3*(local median) = 259580.766.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP32617
#     file raua.219.fits: injecting signal of W = 5, H = 1.5*(local median) = 38647.025.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raua.219.fits: injecting signal of W = 5, H = 2*(local median) = 62391.688.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raua.219.fits: injecting signal of W = 5, H = 3*(local median) = 103426.805.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file raua.221.fits: injecting signal of W = 5, H = 1.5*(local median) = 15332.106.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raua.221.fits: injecting signal of W = 5, H = 2*(local median) = 24672.838.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raua.221.fits: injecting signal of W = 5, H = 3*(local median) = 40613.59.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file raua.220.fits: injecting signal of W = 5, H = 1.5*(local median) = 34072.025.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raua.220.fits: injecting signal of W = 5, H = 2*(local median) = 55008.844.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raua.220.fits: injecting signal of W = 5, H = 3*(local median) = 90333.879.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP32769
#     file rauh.280.fits: injecting signal of W = 5, H = 1.5*(local median) = 12943.096.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rauh.280.fits: injecting signal of W = 5, H = 2*(local median) = 24759.018.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rauh.280.fits: injecting signal of W = 5, H = 3*(local median) = 40733.358.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rauh.282.fits: injecting signal of W = 5, H = 1.5*(local median) = 9918.34.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rauh.282.fits: injecting signal of W = 5, H = 2*(local median) = 19162.25.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rauh.282.fits: injecting signal of W = 5, H = 3*(local median) = 31552.207.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rauh.281.fits: injecting signal of W = 5, H = 1.5*(local median) = 11118.699.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rauh.281.fits: injecting signal of W = 5, H = 2*(local median) = 21282.094.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rauh.281.fits: injecting signal of W = 5, H = 3*(local median) = 34887.656.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP32919
#     file rawa.206.fits: injecting signal of W = 5, H = 1.5*(local median) = 11794.081.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rawa.206.fits: injecting signal of W = 5, H = 2*(local median) = 20768.652.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rawa.206.fits: injecting signal of W = 5, H = 3*(local median) = 34775.212.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rawa.205.fits: injecting signal of W = 5, H = 1.5*(local median) = 11805.152.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rawa.205.fits: injecting signal of W = 5, H = 2*(local median) = 20575.418.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rawa.205.fits: injecting signal of W = 5, H = 3*(local median) = 34481.109.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rawa.204.fits: injecting signal of W = 5, H = 1.5*(local median) = 11268.801.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rawa.204.fits: injecting signal of W = 5, H = 2*(local median) = 19758.986.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rawa.204.fits: injecting signal of W = 5, H = 3*(local median) = 33239.578.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP33202
#     file raog.190.fits: injecting signal of W = 5, H = 1.5*(local median) = 39124.365.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raog.190.fits: injecting signal of W = 5, H = 2*(local median) = 62648.586.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raog.190.fits: injecting signal of W = 5, H = 3*(local median) = 102554.988.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP33373
#     file raug.291.fits: injecting signal of W = 5, H = 1.5*(local median) = 10093.26.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raug.291.fits: injecting signal of W = 5, H = 2*(local median) = 17605.305.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raug.291.fits: injecting signal of W = 5, H = 3*(local median) = 29299.983.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file raug.290.fits: injecting signal of W = 5, H = 1.5*(local median) = 10899.048.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raug.290.fits: injecting signal of W = 5, H = 2*(local median) = 18973.824.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raug.290.fits: injecting signal of W = 5, H = 3*(local median) = 31641.363.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file raug.292.fits: injecting signal of W = 5, H = 1.5*(local median) = 11442.083.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file raug.292.fits: injecting signal of W = 5, H = 2*(local median) = 19823.615.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file raug.292.fits: injecting signal of W = 5, H = 3*(local median) = 32741.326.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP33560
#     file ravx.206.fits: injecting signal of W = 5, H = 1.5*(local median) = 3525.273.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravx.206.fits: injecting signal of W = 5, H = 2*(local median) = 6305.942.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravx.206.fits: injecting signal of W = 5, H = 3*(local median) = 10960.73.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravx.207.fits: injecting signal of W = 5, H = 1.5*(local median) = 3092.325.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravx.207.fits: injecting signal of W = 5, H = 2*(local median) = 5476.596.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravx.207.fits: injecting signal of W = 5, H = 3*(local median) = 9478.282.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravx.208.fits: injecting signal of W = 5, H = 1.5*(local median) = 2381.216.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravx.208.fits: injecting signal of W = 5, H = 2*(local median) = 4222.749.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravx.208.fits: injecting signal of W = 5, H = 3*(local median) = 7202.425.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP34115
#     file ratg.171.fits: injecting signal of W = 5, H = 1.5*(local median) = 720.206.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ratg.171.fits: injecting signal of W = 5, H = 2*(local median) = 1129.319.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ratg.171.fits: injecting signal of W = 5, H = 3*(local median) = 2014.167.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ratg.170.fits: injecting signal of W = 5, H = 1.5*(local median) = 657.783.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ratg.170.fits: injecting signal of W = 5, H = 2*(local median) = 1103.182.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ratg.170.fits: injecting signal of W = 5, H = 3*(local median) = 1796.238.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ratg.172.fits: injecting signal of W = 5, H = 1.5*(local median) = 750.034.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ratg.172.fits: injecting signal of W = 5, H = 2*(local median) = 1307.595.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ratg.172.fits: injecting signal of W = 5, H = 3*(local median) = 2278.565.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP3419
#     file ratm.234.fits: injecting signal of W = 5, H = 1.5*(local median) = 95206.582.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ratm.234.fits: injecting signal of W = 5, H = 2*(local median) = 163582.547.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ratm.234.fits: injecting signal of W = 5, H = 3*(local median) = 261187.43.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ratm.236.fits: injecting signal of W = 5, H = 1.5*(local median) = 85919.578.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ratm.236.fits: injecting signal of W = 5, H = 2*(local median) = 147010.906.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ratm.236.fits: injecting signal of W = 5, H = 3*(local median) = 234578.344.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ratm.235.fits: injecting signal of W = 5, H = 1.5*(local median) = 83373.223.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ratm.235.fits: injecting signal of W = 5, H = 2*(local median) = 142211.812.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ratm.235.fits: injecting signal of W = 5, H = 3*(local median) = 227744.812.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP34341
#     file ratg.167.fits: injecting signal of W = 5, H = 1.5*(local median) = 3006.625.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ratg.167.fits: injecting signal of W = 5, H = 2*(local median) = 5889.412.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ratg.167.fits: injecting signal of W = 5, H = 3*(local median) = 10537.622.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ratg.168.fits: injecting signal of W = 5, H = 1.5*(local median) = 3557.861.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ratg.168.fits: injecting signal of W = 5, H = 2*(local median) = 6857.286.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ratg.168.fits: injecting signal of W = 5, H = 3*(local median) = 12206.079.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ratg.169.fits: injecting signal of W = 5, H = 1.5*(local median) = 4362.974.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ratg.169.fits: injecting signal of W = 5, H = 2*(local median) = 8498.093.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ratg.169.fits: injecting signal of W = 5, H = 3*(local median) = 15168.833.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP34567
#     file ravu.195.fits: injecting signal of W = 5, H = 1.5*(local median) = 50463.287.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravu.195.fits: injecting signal of W = 5, H = 2*(local median) = 82128.625.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravu.195.fits: injecting signal of W = 5, H = 3*(local median) = 137007.504.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravu.196.fits: injecting signal of W = 5, H = 1.5*(local median) = 53539.119.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravu.196.fits: injecting signal of W = 5, H = 2*(local median) = 87238.031.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravu.196.fits: injecting signal of W = 5, H = 3*(local median) = 144224.438.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file ravu.197.fits: injecting signal of W = 5, H = 1.5*(local median) = 50702.438.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file ravu.197.fits: injecting signal of W = 5, H = 2*(local median) = 82376.82.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file ravu.197.fits: injecting signal of W = 5, H = 3*(local median) = 136802.73.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP34950
#     file ravu.211.fits: injecting signal of W = 5, H = 1.5*(local median) = 18469.509.
#                      : injecting at center point 5461.813824900171 A, order 39
# ...
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbep.231.fits: injecting signal of W = 5, H = 2*(local median) = 63689.367.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbep.231.fits: injecting signal of W = 5, H = 3*(local median) = 105322.91.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbep.201.fits: injecting signal of W = 5, H = 1.5*(local median) = 32633.865.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbep.201.fits: injecting signal of W = 5, H = 2*(local median) = 52532.414.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbep.201.fits: injecting signal of W = 5, H = 3*(local median) = 87471.059.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbep.202.fits: injecting signal of W = 5, H = 1.5*(local median) = 32121.34.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbep.202.fits: injecting signal of W = 5, H = 2*(local median) = 51869.48.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbep.202.fits: injecting signal of W = 5, H = 3*(local median) = 85943.807.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbep.203.fits: injecting signal of W = 5, H = 1.5*(local median) = 33386.238.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbep.203.fits: injecting signal of W = 5, H = 2*(local median) = 54056.688.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbep.203.fits: injecting signal of W = 5, H = 3*(local median) = 89661.07.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP7535
#     file rbjf.208.fits: injecting signal of W = 5, H = 1.5*(local median) = 55637.279.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbjf.208.fits: injecting signal of W = 5, H = 2*(local median) = 90382.312.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbjf.208.fits: injecting signal of W = 5, H = 3*(local median) = 148446.211.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbjf.206.fits: injecting signal of W = 5, H = 1.5*(local median) = 59069.432.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbjf.206.fits: injecting signal of W = 5, H = 2*(local median) = 95193.344.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbjf.206.fits: injecting signal of W = 5, H = 3*(local median) = 156592.102.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbjf.207.fits: injecting signal of W = 5, H = 1.5*(local median) = 54984.305.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbjf.207.fits: injecting signal of W = 5, H = 2*(local median) = 89006.875.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbjf.207.fits: injecting signal of W = 5, H = 3*(local median) = 146192.965.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP75458
#     file rbeq.243.fits: injecting signal of W = 5, H = 1.5*(local median) = 57666.129.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbeq.243.fits: injecting signal of W = 5, H = 2*(local median) = 99842.125.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbeq.243.fits: injecting signal of W = 5, H = 3*(local median) = 172726.922.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbeq.244.fits: injecting signal of W = 5, H = 1.5*(local median) = 61362.486.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbeq.244.fits: injecting signal of W = 5, H = 2*(local median) = 106287.008.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbeq.244.fits: injecting signal of W = 5, H = 3*(local median) = 184062.34.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbeq.242.fits: injecting signal of W = 5, H = 1.5*(local median) = 58035.539.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbeq.242.fits: injecting signal of W = 5, H = 2*(local median) = 100467.883.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbeq.242.fits: injecting signal of W = 5, H = 3*(local median) = 173563.863.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP75718
#     file rbep.206.fits: injecting signal of W = 5, H = 1.5*(local median) = 43471.383.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbep.206.fits: injecting signal of W = 5, H = 2*(local median) = 73238.164.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbep.206.fits: injecting signal of W = 5, H = 3*(local median) = 115280.648.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbep.237.fits: injecting signal of W = 5, H = 1.5*(local median) = 49021.849.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbep.237.fits: injecting signal of W = 5, H = 2*(local median) = 82077.867.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbep.237.fits: injecting signal of W = 5, H = 3*(local median) = 131868.141.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbep.204.fits: injecting signal of W = 5, H = 1.5*(local median) = 40332.744.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbep.204.fits: injecting signal of W = 5, H = 2*(local median) = 68268.297.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbep.204.fits: injecting signal of W = 5, H = 3*(local median) = 107811.609.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbep.236.fits: injecting signal of W = 5, H = 1.5*(local median) = 48095.839.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbep.236.fits: injecting signal of W = 5, H = 2*(local median) = 80518.656.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbep.236.fits: injecting signal of W = 5, H = 3*(local median) = 129528.328.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbep.205.fits: injecting signal of W = 5, H = 1.5*(local median) = 42098.229.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbep.205.fits: injecting signal of W = 5, H = 2*(local median) = 70753.828.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbep.205.fits: injecting signal of W = 5, H = 3*(local median) = 112288.559.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbep.238.fits: injecting signal of W = 5, H = 1.5*(local median) = 50231.666.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbep.238.fits: injecting signal of W = 5, H = 2*(local median) = 83759.141.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbep.238.fits: injecting signal of W = 5, H = 3*(local median) = 135036.445.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP75722
#     file rbyn.691.fits: injecting signal of W = 5, H = 1.5*(local median) = 66395.812.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbyn.691.fits: injecting signal of W = 5, H = 2*(local median) = 109803.234.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbyn.691.fits: injecting signal of W = 5, H = 3*(local median) = 193515.703.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbyn.693.fits: injecting signal of W = 5, H = 1.5*(local median) = 79541.561.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbyn.693.fits: injecting signal of W = 5, H = 2*(local median) = 131209.641.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbyn.693.fits: injecting signal of W = 5, H = 3*(local median) = 232389.352.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbyn.692.fits: injecting signal of W = 5, H = 1.5*(local median) = 75044.566.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbyn.692.fits: injecting signal of W = 5, H = 2*(local median) = 124132.516.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbyn.692.fits: injecting signal of W = 5, H = 3*(local median) = 219443.438.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP75761
#     file rapz.210.fits: injecting signal of W = 5, H = 1.5*(local median) = 95337.006.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rapz.210.fits: injecting signal of W = 5, H = 2*(local median) = 153367.531.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rapz.210.fits: injecting signal of W = 5, H = 3*(local median) = 252363.023.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP7576
#     file rcbk.719.fits: injecting signal of W = 5, H = 1.5*(local median) = 73579.547.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rcbk.719.fits: injecting signal of W = 5, H = 2*(local median) = 127032.617.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rcbk.719.fits: injecting signal of W = 5, H = 3*(local median) = 215502.562.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rcbk.720.fits: injecting signal of W = 5, H = 1.5*(local median) = 76231.02.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rcbk.720.fits: injecting signal of W = 5, H = 2*(local median) = 131625.641.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rcbk.720.fits: injecting signal of W = 5, H = 3*(local median) = 224125.5.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rcbk.721.fits: injecting signal of W = 5, H = 1.5*(local median) = 78807.785.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rcbk.721.fits: injecting signal of W = 5, H = 2*(local median) = 136184.844.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rcbk.721.fits: injecting signal of W = 5, H = 3*(local median) = 231160.43.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP75809
#     file rbep.223.fits: injecting signal of W = 5, H = 1.5*(local median) = 47763.706.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbep.223.fits: injecting signal of W = 5, H = 2*(local median) = 78787.586.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbep.223.fits: injecting signal of W = 5, H = 3*(local median) = 132340.406.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbep.221.fits: injecting signal of W = 5, H = 1.5*(local median) = 45642.451.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbep.221.fits: injecting signal of W = 5, H = 2*(local median) = 75443.773.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbep.221.fits: injecting signal of W = 5, H = 3*(local median) = 126789.094.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbep.222.fits: injecting signal of W = 5, H = 1.5*(local median) = 47386.33.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbep.222.fits: injecting signal of W = 5, H = 2*(local median) = 78981.031.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbep.222.fits: injecting signal of W = 5, H = 3*(local median) = 131655.035.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP75829
#     file rbzf.083.fits: injecting signal of W = 5, H = 1.5*(local median) = 52022.695.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbzf.083.fits: injecting signal of W = 5, H = 2*(local median) = 89608.273.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbzf.083.fits: injecting signal of W = 5, H = 3*(local median) = 152239.676.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbzf.082.fits: injecting signal of W = 5, H = 1.5*(local median) = 52599.662.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbzf.082.fits: injecting signal of W = 5, H = 2*(local median) = 90816.328.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbzf.082.fits: injecting signal of W = 5, H = 3*(local median) = 153668.871.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbzf.084.fits: injecting signal of W = 5, H = 1.5*(local median) = 81773.039.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbzf.084.fits: injecting signal of W = 5, H = 2*(local median) = 141751.672.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbzf.084.fits: injecting signal of W = 5, H = 3*(local median) = 239891.438.
#                      : injecting at center point 5593.298646595918 A, order 41
# Star: HIP76219
#     file rbex.236.fits: injecting signal of W = 5, H = 1.5*(local median) = 44724.911.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbex.236.fits: injecting signal of W = 5, H = 2*(local median) = 72520.602.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbex.236.fits: injecting signal of W = 5, H = 3*(local median) = 122373.34.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbex.237.fits: injecting signal of W = 5, H = 1.5*(local median) = 47194.075.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbex.237.fits: injecting signal of W = 5, H = 2*(local median) = 76615.234.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbex.237.fits: injecting signal of W = 5, H = 3*(local median) = 129210.973.
#                      : injecting at center point 5593.298646595918 A, order 41
#     file rbex.238.fits: injecting signal of W = 5, H = 1.5*(local median) = 45227.027.
#                      : injecting at center point 5461.813824900171 A, order 39
#     file rbex.238.fits: injecting signal of W = 5, H = 2*(local median) = 73694.289.
#                      : injecting at center point 5526.772619756325 A, order 40
#     file rbex.238.fits: injecting signal of W = 5, H = 3*(local median) = 123983.039.
#                      : injecting at center point 5593.298646595918 A, order 41
