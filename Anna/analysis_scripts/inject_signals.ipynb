# %%
# inject high intensity signals to verify that we can recover them after they go through SM-Emp 
# in the shifted spectra and the residuals.
# Then should check that they are recovered by the search algorithm, of course.

import numpy as np
import os
import matplotlib.pyplot as plt
from astropy.io import fits
import pandas as pd
import math
from scipy.interpolate import interp1d
from mpmath import mp
mp.dps=100
exp_array = np.frompyfunc(mp.exp, 1, 1)

# %%
# make a directory for the injected spectra -- only run this once
#if not os.path.isdir('/mnt_home/azuckerman/BL_APF_DAP/APF_spectra/injected_spectra'):
#    os.mkdir('/mnt_home/azuckerman/BL_APF_DAP/APF_spectra/injected_spectra')

# %%
# function to insert simulated gaussians
def insert_gaussian(spectrum, gaussian_params, midpoint, numpoints):
    height = gaussian_params[0]
    position = gaussian_params[1] #position within segment, not index in spectrum
    FWHM = gaussian_params[2]
    offset = gaussian_params[3]
    x = np.linspace(0,numpoints-1,numpoints) # numpoints must be odd
    gauss = gaussian(x,height,position,FWHM/(2*np.sqrt(2*np.log(2))),offset)
    new_spect = spectrum
    new_spect[midpoint - math.floor(numpoints/2):midpoint + math.floor(numpoints/2)] = spectrum[midpoint - math.floor(numpoints/2):midpoint + math.floor(numpoints/2)] + gauss
    return new_spect
    
def gaussian(x,a,b,c,d): # a = height, b = position of peak, c = width, x = numpy array of x values
    f = a*exp_array((-(x-b)**2)/(2*c)**2) + d
    return f

# %%
test_stars = ['GJ1002', # -> cool (T ~ 3100K)
              'HIP115562', # -> relatively cool (T ~ 3700K)
              'GJ144', # -> medium temperature (T ~ 5000K)
              'HIP13834'] # -> hot (T ~ 6300K)

star_list = os.listdir('APF_spectra/all_apf_spectra_highest_SNR')[:100]

heights = [1.5, 2, 3] # times the 98th percentile of order 40


#if not os.path.isdir('APF_spectra/injected_spectra_' + str(height)):
#   os.mkdir('APF_spectra/injected_spectra_' + str(height))
apf_wave = fits.open('apf_wav.fits')
j = 0
injected_peak_photons = np.zeros(len(star_list)*3) # *3 becuase three different inejctions in each star
median_photons_100_pix = np.zeros(len(star_list)*3)
injection_wl = np.zeros(len(star_list)*3)*np.nan
stars = []
if not os.path.isdir('APF_spectra/injected_spectra'):
    os.mkdir('APF_spectra/injected_spectra')
    
for star_name in star_list:
    star = star_name.split('_')[0]
    for m in range(3): stars += [star] # want three entries for this star: one for each injection
    dir_path = 'APF_spectra/all_apf_spectra_highest_SNR/' + star + '_spectra'
    i = 0
    print('Star: ' + star)
    for file in os.listdir(dir_path):
        hdu = fits.open(dir_path + '/' + file)# , mode='update')
        spectrum = np.copy(hdu[0].data)
        color = 'C' + str(i)  
        n = 0
        orders = [39, 40, 41]
        y = hdu[0].data
        for height in heights:
            order = orders[n] # inject the 1.5 hieght into order 39, 2 into order 40, etc
            y_order = y[order]
            h = height - 1 # becuase in the above implementation we add to the baseline, so ie. h = 1 injects a guassian whose peak is at twice the pixels value of the 98th percentile
            print('    file ' + file + ': injecting signal of W = 5, H = ' + str(height) + 
                  '*(98th pct level of order) = ' + str(np.round(height * np.percentile(y_order,98),3)) + ' into order 40.')  
            median_100 = np.median(y_order[int(len(y_order)/2 - 50): int(len(y_order)/2 + 50)])
            y_new = insert_gaussian(y_order, [height*np.percentile(y_order,98), 49, 20, 0], int(len(y_order)/2), 100)
            injection_center_wl = apf_wave[0].data[order][int(len(y_order)/2)]
            print('                     : injecting at center point ' + str(injection_center_wl) + ' A')
            #y[int(len(y)/2)] = 10 * np.percentile(y,99)
            #x = apf_wave[0].data[order]
            #plt.plot(x, y[:-1], '.', c = color)
            #plt.xlim([5553,5557])
            injected_peak_photons[3*j + n] = injected_peak_photons[3*j + n] + height * np.percentile(y_order,98) # sum over each file
            median_photons_100_pix[3*j + n] = median_photons_100_pix[3*j + n] + median_100 # sum over each file
            injection_wl[3*j + n] = injection_center_wl # same for each file (and each star)
            spectrum[order,:] = y_new
            n += 1
        #plt.figure(star + ', ' + file)
        #for order in np.arange(38,43,1):
        #    plt.plot(apf_wave[0].data[order], spectrum[order,:-1])
        #    plt.title(star + ', ' + file)
        i += 1

        new_header = hdu[0].header # get header
        new_header.set('Injected', 'YES','Spectrum contains injected gaussian for testing.')
        data_hdu = fits.PrimaryHDU(spectrum, new_header) 
        hdu_new = fits.HDUList([data_hdu])
        out_path = 'APF_spectra/injected_spectra/'
        if not os.path.isdir(out_path + star + '_spectra/'):
            os.mkdir(out_path + star + '_spectra/')
        #hdu_new.writeto(out_path + star + '_spectra/' + file + '_injected' + '.fits')
        hdu.close()
    save_data = list(zip(stars, injection_wl, injected_peak_photons, median_photons_100_pix))
    df = pd.DataFrame(save_data,
              columns = ['Star_name', 'Injection_wavelength', 'Injected_peak_photons', 'Local_median_photons'])
    df.to_csv('Injection_key.csv', index = False)
    j += 1
# Out:
# Star: GJ1002
#     file rbhr.214.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 151.303 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbhr.214.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 153.809 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbhr.214.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 298.692 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbhr.215.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 155.19 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbhr.215.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 163.734 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbhr.215.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 301.976 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbhr.216.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 149.981 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbhr.216.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 154.008 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbhr.216.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 304.453 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: GJ144
#     file rcep.611.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 50091.204 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rcep.611.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 69271.473 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rcep.611.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 105653.398 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rcep.612.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 92043.736 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rcep.612.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 127514.276 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rcep.612.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 194720.085 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rcep.613.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 82911.99 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rcep.613.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 114996.83 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rcep.613.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 175408.001 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: GJ234
#     file rbum.682.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 909.212 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbum.682.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 955.006 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbum.682.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 1716.574 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbum.683.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 1447.334 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbum.683.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 1471.637 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbum.683.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 2761.145 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbum.684.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 1735.734 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbum.684.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 1765.525 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbum.684.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 3248.32 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: GJ244
#     file ranw.242.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 250724.036 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file ranw.242.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 333779.439 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file ranw.242.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 497953.464 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: GJ280
#     file rbqx.481.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 87868.707 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbqx.481.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 118483.275 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbqx.481.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 179685.224 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbqx.483.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 155797.629 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbqx.483.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 209916.268 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbqx.483.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 318661.31 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbqx.485.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 101374.768 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbqx.485.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 137248.14 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbqx.485.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 208640.07 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbqx.479.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 79420.79 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbqx.479.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 107650.677 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbqx.479.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 163653.351 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbqx.487.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 140097.041 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbqx.487.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 189267.194 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbqx.487.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 287564.51 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbqx.486.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 133572.603 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbqx.486.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 180394.487 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbqx.486.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 273533.256 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbqx.484.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 125985.229 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbqx.484.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 170267.704 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbqx.484.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 258677.584 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbqx.482.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) =
fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 53793.202 into order 40.
#                      : injecting at center point 5622.229264717167 A
# ...
#                      : injecting at center point 5555.36527738973 A
#     file rcag.498.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 8710.77 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP109427
#     file rbnx.104.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 46728.075 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbnx.104.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 62351.233 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbnx.104.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 93165.905 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbnx.106.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 53019.58 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbnx.106.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 70790.458 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbnx.106.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 105857.581 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbnx.109.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 46767.623 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbnx.109.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 62357.46 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbnx.109.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 93214.498 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbnx.105.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 47806.742 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbnx.105.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 63836.981 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbnx.105.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 95376.525 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbnx.107.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 45997.134 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbnx.107.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 61411.42 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbnx.107.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 91884.942 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbnx.108.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 45748.97 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbnx.108.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 61125.919 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbnx.108.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 91399.053 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP109474
#     file rbbo.236.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 61030.509 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbbo.236.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 82246.229 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbbo.236.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 124074.158 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbbo.237.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 60647.71 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbbo.237.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 81861.422 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbbo.237.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 123262.362 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbbo.235.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 62897.46 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbbo.235.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 84824.366 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbbo.235.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 127924.379 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP109527
#     file rbgs.242.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 46036.991 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbgs.242.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 62797.92 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbgs.242.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 95050.791 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbgs.243.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 40887.191 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbgs.243.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 55863.583 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbgs.243.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 84606.811 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbgs.241.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 41896.431 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbgs.241.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 57141.362 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbgs.241.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 86512.629 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP109555
#     file rbps.418.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 2190.882 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbps.418.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 3007.406 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbps.418.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 4381.273 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbps.416.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 2106.065 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbps.416.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 2869.779 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbps.416.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 4194.662 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbps.417.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 2161.253 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbps.417.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 2941.761 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbps.417.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 4322.969 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP109638
#     file rbxp.704.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 1287.008 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbxp.704.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 1654.644 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbxp.704.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 2650.68 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbxp.705.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 1317.287 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbxp.705.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 1714.471 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbxp.705.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 2705.176 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbxp.706.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 1475.707 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbxp.706.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 1938.791 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbxp.706.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 2959.265 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP109822
#     file rbnx.103.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 14121.237 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbnx.103.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 19501.456 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbnx.103.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 29800.408 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbnx.101.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 13855.388 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbnx.101.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 19171.422 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbnx.101.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 29363.853 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbnx.102.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 14861.744 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbnx.102.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 20531.39 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbnx.102.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 31431.476 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP109857
#     file rzex.797.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 69549.963 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rzex.797.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 93622.965 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rzex.797.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 140217.675 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rzex.800.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 67208.05 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rzex.800.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 90551.821 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rzex.800.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 135389.764 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rzex.801.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 63703.657 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rzex.801.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 85778.457 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rzex.801.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 128078.49 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rzex.799.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 67013.162 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rzex.799.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 90302.917 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rzex.799.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 135188.227 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rzex.798.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 67658.68 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rzex.798.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 91174.053 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rzex.798.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 136473.582 into order 40.
#                      : injecting at center point 5622.229264717167 A
# Star: HIP109926
#     file rbbw.217.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 35391.112 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbbw.217.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 48580.419 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbbw.217.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 73720.189 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbbw.216.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 34935.06 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbbw.216.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 47851.645 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbbw.216.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 72598.583 into order 40.
#                      : injecting at center point 5622.229264717167 A
#     file rbbw.215.fits: injecting signal of W = 5, H = 1.5*(98th pct level of order) = 35765.906 into order 40.
#                      : injecting at center point 5490.07413621209 A
#     file rbbw.215.fits: injecting signal of W = 5, H = 2*(98th pct level of order) = 49041.547 into order 40.
#                      : injecting at center point 5555.36527738973 A
#     file rbbw.215.fits: injecting signal of W = 5, H = 3*(98th pct level of order) = 74418.313 into order 40.
#                      : injecting at center point 5622.229264717167 A

# %%
test_stars[0]
# Out:
# 'GJ1002'

# %%
hdu = fits.open(dir_path + '/' + file)# , mode='update')
np.shape(hdu[0].data)
# Out:
# (79, 4608)

# %%
hdu.info()
# Out:
# Filename: APF_spectra/all_apf_spectra_highest_SNR/HIP13834_spectra/rceq.102.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     237   (4608, 79)   float32
