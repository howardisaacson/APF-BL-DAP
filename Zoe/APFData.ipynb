# %% [markdown]
# ## Explore APF data and data reduction

# %%
from astropy.io import fits
import matplotlib.pylab as plt
import numpy as np
import scipy.interpolate
from scipy.interpolate import splev, splrep
import os
import pandas as pd

# %%
directory = '/mnt_home/azuckerman/APF_spectra/NDR_corrected_wl_scale'

# every file in Anna's NDR_corrected_wl_scale folder
list_of_files = []
for filename in os.listdir(directory):
    if filename.endswith(".fits"): 
        file_path = os.path.join(directory, filename)
        list_of_files = np.append(list_of_files, file_path)

# %%
print(len(list_of_files))
# Out:
# 5868

# %%
print(list_of_files.tolist().index('/mnt_home/azuckerman/APF_spectra/NDR_corrected_wl_scale/rbbn.202.NDR.fits'))
# Out:
# 1910

# %%
for which_star in np.arange(2):
    
    APF_flux_path = list_of_files[which_star]

    file = fits.open(APF_flux_path)
    flux = file[0].data
    wl = file[1].data
    
    print(which_star)
    header = file[0].header
    star = header['OBJECT']

    print('File path: ' + APF_flux_path)
    print('Star: ' + star)
    
    plt.figure()
    plt.plot(wl, flux)
#     plt.ylim(0, 1.5)
#     plt.xlim(5880, 5920)
    plt.show()
    
    # 14, 21, 24, 26, 27
    # 20, 28
    # weird 38



#     spect = flux
# Out:
# 0
# File path: /mnt_home/azuckerman/APF_spectra/NDR_corrected_wl_scale/ramq.233.NDR.fits
# Star: HIP12444
# 1
# File path: /mnt_home/azuckerman/APF_spectra/NDR_corrected_wl_scale/ramq.252.NDR.fits
# Star: HIP19855

# %%
for file in list_of_files[2000:2001]:
    fl = fits.open(file)
    header = fl[0].header
    star = header['OBJECT']
    print(star)
    
    fl_image = fl[0].data
    flux = fl_image
# Out:
# HIP111169

# %%
APF_wavelength_path = '/mnt_home/zoek/code/APF-BL-DAP/Zoe/APFTutorial/apf_wav.fits'
APF_flux_path = '/datag/blpd0/datax/apf/rarj.224.fits'

order = 45

wl_file = fits.open(APF_wavelength_path)
wl_image = wl_file[0].data
wl = wl_image[order]


fl_file = fits.open(APF_flux_path)
fl_image = fl_file[0].data
flux = fl_image[order][:-1]

plt.plot(wl,flux)

plt.title('Raw APF Spectrum of ' + star + ': Order ' + str(order))
plt.xlabel('Wavelength [A]')
plt.ylabel('Flux')
plt.show()

# %%
plt.rcParams["figure.figsize"] = (6,3)

order = 45 # 32 to 45
wl = wl_image[order]

for fl in flux_arrays:
    flux = fl[order][:-1]
    plt.plot(wl,flux)

# plt.title('Raw APF Spectrum of ' + star + ': Order ' + str(order))
# plt.xlabel('Wavelength [A]')
# plt.ylabel('Flux')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-52-d543dba919bc> in <module>
#       5
#       6 for fl in flux_arrays:
# ----> 7     flux = fl[order][:-1]
#       8     plt.plot(wl,flux)
#       9
#
# IndexError: invalid index to scalar variable.

# %%
cd /home/azuckerman/APF_spectra/NDR
# Out:
# /mnt_home/azuckerman/APF_spectra/NDR

# %%
# ramq.233.NDR.fits  rayr.215.NDR.fits  rbie.203.NDR.fits  rbqo.720.NDR.fits
# ramq.252.NDR.fits  rayr.216.NDR.fits  rbie.204.NDR.fits  rbqo.721.NDR.fits
# ramr.228.NDR.fits  rayr.217.NDR.fits  rbie.206.NDR.fits  rbqo.722.NDR.fits
# ramu.211.NDR.fits  rayr.218.NDR.fits  rbie.207.NDR.fits  rbqo.730.NDR.fits

# %%
order = 21

star = 'test'
APF_wavelength_path = '/mnt_home/zoek/code/APF-BL-DAP/APFTutorial/apf_wav.fits'
APF_flux_path = '/home/azuckerman/APF_spectra/NDR/ramq.233.NDR.fits'

wl_file = fits.open(APF_wavelength_path)
fl_file = fits.open(APF_flux_path)
wl_image = wl_file[0].data
fl_image = fl_file[0].data

wl = wl_image[order][4:-3]
flux = fl_image[order]

# %%
plt.plot(wl, flux)

# %%
cd /home/azuckerman/APF_spectra/NDR
# Out:
# /mnt_home/azuckerman/APF_spectra/NDR

# %%
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7fd91f879050>, <astropy.io.fits.hdu.image.ImageHDU object at 0x7fd91f8714d0>]

# %%
file = fits.open('ramq.233.NDR.fits')
wl_image = file[1].data
print(len(wl_image))
flux_image = file[0].data

# print(len(wl_image))
# print(len(flux_image))


# fl = fl_file[0].data

# wl = fl_file[1].data


# fl.data[5]

# wl = fl_file[1].data
# header = fl_file[0].header
# star = header['TOBJECT']
# print(header)
# Out:
# 69886
